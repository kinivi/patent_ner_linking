# %% [markdown]
# # Inforet 2022: Project

# %% [markdown]
# ## Imports

# %%
import re, regex, timeit, gzip, random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from tqdm.notebook import tqdm
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import spacy
from spacy.lang.en import English
from spacy.matcher import PhraseMatcher
from sense2vec import Sense2Vec
from collections import Counter
from nltk.tokenize import MWETokenizer
from nltk.util import Trie
tqdm.pandas()
spacy.__version__
# Out:
# '3.2.4'

# %% [markdown]
# ## Read and preprocess data

# %%
# if you've already unzipped the file
patent_data=open('G06K.txt').read().strip()

# split into patents texts | 1 entry = 1 patent
patent_texts = patent_data.split('\n\n')

# split each patent into lines
patent_lines = patent_data.split('\n')

# %%
print(len(patent_lines),'patent lines')
print(len(patent_texts),'texts of patents')
# Out:
# 288792 patent lines
# 2003 texts of patents

# %% [markdown]
# ## Extract features

# %%
cvectorizer = CountVectorizer(ngram_range=(2, 3), min_df=10, stop_words="english")
X=cvectorizer.fit_transform(patent_lines)

Xdf = pd.DataFrame(np.sum(X, axis=0), columns=cvectorizer.get_feature_names()).T.sort_values(by = 0, ascending = False)
Xdf.head(25)
# Out:
# /home/gaetan_serre93_gmail_com/miniconda3/envs/NLP/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                             0
# present disclosure      17882
# present invention       17244
# image data              16898
# electronic device       16280
# according embodiment    14713
# image processing        12214
# embodiment present      11881
# shown fig               10904
# control unit             9263
# mobile terminal          9165
# according claim          8840
# processing unit          8668
# illustrated fig          8632
# information processing   7723
# processing apparatus     7403
# neural network           6734
# embodiments present      6602
# diagram illustrating     6442
# method according         6352
# user interface           6162
# computer readable        6103
# fingerprint sensor       5980
# captured image           5888
# device according         5838
# vehicle 100              5792

# %% [markdown]
# ### Manyterms

# %%
# here are the potential terms
mwes = open('manyterms.lower.txt').read().lower().strip().split('\n')
print(mwes[44444:44456])
print(len(mwes),'mwes')
# Out:
# ['antonio superchi', 'antonio tarver', 'antonio torres jurado', 'antonio valdes', 'antonio valdes y fernandez bazan', 'antonio valdez', 'antonio valdés y bazán', 'antonio valdés y fernández bazán', 'antonio valente', 'antonio vitali', 'antonio vivaldi', 'antonio xavier machado e cerveira']
# 743274 mwes

# %%
# Here lowercase=False option is used to keep the original case of the terms, since we possibly could have term abbreviations. Like API, CAT, etc.
cvectorizer = CountVectorizer(ngram_range=(1, 4), stop_words="english", vocabulary=mwes, lowercase=True)
X=cvectorizer.fit_transform(patent_texts)

# Show top-25 most frequent terms
termdf_cv = pd.DataFrame(np.sum(X, axis=0), columns=cvectorizer.get_feature_names()).T.sort_values(by = 0, ascending = False)
termdf_cv.head(25)
# Out:
# /home/gaetan_serre93_gmail_com/miniconda3/envs/NLP/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:1322: UserWarning: Upper case characters found in vocabulary while 'lowercase' is True. These entries will not be matched with any documents
#   warnings.warn(
# /home/gaetan_serre93_gmail_com/miniconda3/envs/NLP/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                              0
# electronic device        16280
# image processing         12224
# control unit              9263
# mobile terminal           9165
# information processing    7732
# neural network            6734
# user interface            6177
# computer readable         6103
# fingerprint sensor        5980
# display device            5666
# light source              5014
# block diagram             4597
# image sensor              4421
# computing device          4407
# road surface              4398
# storage medium            4377
# fingerprint recognition   3848
# machine learning          3778
# control device            3714
# point cloud               3713
# threshold value           3705
# data processing           3366
# real time                 3353
# wireless communication    3338
# computer program          3206

# %% [markdown]
# - [EXPERIMENT] Longer words - more specific terms?

# %%
# Count vectorizer with vocabulary
# Here lowercase=False option is used to keep the original case of the terms, since we possibly could have term abbreviations. Like API, CAT, etc.
cvectorizer = CountVectorizer(ngram_range=(3, 4), stop_words="english", vocabulary=mwes, lowercase=False)
X=cvectorizer.fit_transform(patent_lines)

# Show top-25 most frequent terms
term_cv_long = pd.DataFrame(np.sum(X, axis=0), columns=cvectorizer.get_feature_names()).T.sort_values(by = 0, ascending = False)
term_cv_long.head(25)
# Out:
# /home/gaetan_serre93_gmail_com/miniconda3/envs/NLP/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                   0
# point cloud data               1593
# convolutional neural network   1005
# printed circuit board           816
# central processing unit         698
# deep neural network             636
# light emitting diode            626
# liquid crystal display          574
# local area network              479
# machine learning model          478
# mobile computing device         470
# unmanned aerial vehicle         470
# electronic control unit         421
# neural network model            400
# machine learning algorithm      372
# red green blue                  345
# event data recorder             331
# programmable gate array         313
# artificial neural network       302
# optical character recognition   278
# light guide plate               278
# functional block diagram        274
# hard disk drive                 273
# power supply unit               262
# digital signal processor        255
# training data set               250

# %% [markdown]
# ## 🪄 SpaCy NER

# %% [markdown]
# Instead of using EntityRuler, we can use the built-in PharaseMatcher and Span for annotation and saving it to the binary `.spacy` format

# %% [markdown]
# Let's start from understanding. Here is an example of showing part of text on one patent with default NER

# %%
from spacy.util import filter_spans
from spacy import displacy
from spacy.tokens import DocBin
from spacy.tokens import Span


nlp = spacy.load("en_core_web_lg")
doc = nlp(patent_texts[0][18000:20000]) # 
displacy.render(doc, style="ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> PC
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     503
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  example of the communication device and may also be other various devices such as, for example, a smart phone, a camera, a digital television set, various digital consumer electronics, and a wearable device.</br>It should be noted that the setting device is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  type of the communication device, but according to the present embodiment, a communication device provided with a function for obtaining a public key of another communication device by a specific obtaining method that does not use the wireless
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will be referred to as a setting device to be distinguished from the communication device that is not provided with such a function. On the other hand, a communication device that is not provided with such a function will be simply referred to as a communication device. As described above, according to the present embodiment, the smart phone
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     501
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  example of the setting device, and the printer
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     502
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and the laptop PC
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     503
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  example of the communication device. In addition, according to the present embodiment, the public key obtaining method using the QR code is an example of the above-described particular obtaining method. In this case, a function for reading the QR code is an example of a function for obtaining the public key of the other communication device by the particular obtaining method. Other examples of the particular obtaining method may also be
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bluetooth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (registered trademark), or a wireless communication other than the wireless
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . In this case, an example of the function for obtaining the public key of the other communication device by the particular obtaining method includes an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reader/writer function.</br>According to the present embodiment, the smart phone
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     501
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  serving as the setting device has the configuration of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  described before. In addition, the printer
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     502
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and the laptop PC
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     503
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  serving as the communication device have the configuration of
# <mark class="entity

# %% [markdown]
# ### Create DataSet

# %% [markdown]
# We need to create propper dataset that is compatible with SpaCy 3.0

# %%
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
patterns = [nlp.make_doc(text) for text in termdf_cv.index]
matcher.add("Tech", patterns)

# %%
# split train and test patent_lines with sciki-learn
from sklearn.model_selection import train_test_split
train_lines, test_lines = train_test_split(patent_lines, test_size=0.3, random_state=42)

# %% [markdown]
# We are using PharsesMatcher to find entities similar to one from mayterms.txt
# Then Span is labeled and saved into the binary `.spacy` format

# %% [markdown]
# Training data

# %%
LABEL = "TECH"
doc_bin_train = DocBin() # create a DocBin object

# nlp.max_length = 2000000
for training_example  in tqdm(train_lines[:40000]): #~50 patents
    doc = nlp.make_doc(training_example) 
    ents = []
    
    for match_id, start, end in matcher(doc):
        #print(i,"Matched based on lowercase token text:", doc[:10], '::::::::',doc[start:end],start, end)
        span = Span(doc, start, end, label=LABEL)
        #print(span, span.label_)
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)

    filtered_ents = filter_spans(ents)
    print(filtered_ents[:3])
    doc.ents = filtered_ents 
    doc_bin_train.add(doc)
# Out:
#   0%|          | 0/40000 [00:00<?, ?it/s]
# [the present, the image]
# [wide angle, high resolution]
# [the image, for every]
# []
# [in parallel, laser beams, laser beams]
# [execution unit]
# [autonomous driving, wireless network]
# [image processing, image processing, image quality]
# [the normal, exposure time, exposure time]
# [Driver assistance, Driver assistance, driver assistance system]
# []
# []
# []
# [index matrix, index matrix]
# [the image, machine learning, machine learning]
# [The system, the matrix, rejection rate]
# []
# []
# [rechargeable battery]
# [light sources]
# []
# []
# [color image, number of, image analysis]
# [computer system, The normal, the normal]
# []
# []
# [fuel consumption, traffic congestion, a vehicle]
# []
# [surgical instrument, data collection, the cloud]
# []
# [there exists, data storage, data storage]
# []
# []
# [graphics pipeline, inter-thread communication, in service]
# [information display, number of, number of]
# []
# []
# [the image]
# [machine learning, nasal cavities, machine learning]
# []
# []
# [the envelope]
# []
# []
# []
# [The present]
# []
# [STORAGE MEDIUM]
# [The system, high quality, medical imagery]
# [dielectric constant, human skin]
# [the normal, first class]
# [the present]
# [information processing, information processing, information processing]
# [element 12, command unit, command unit]
# []
# [automatic operation]
# [data capture, data capture, data capture]
# [electronic document, electronic document, plain text]
# [fingerprint sensor, function key]
# []
# [the present]
# [The system]
# [The image]
# [high quality, medical images, medical images]
# [optical axis, optical system, image sensor]
# [printer driver, print job]
# [the present, learning machine, the present]
# []
# []
# [electromagnetic wave, object based, electromagnetic wave]
# [prior art]
# [the present]
# []
# []
# [data type, number of, data type]
# [the image, the image]
# []
# [electronic device, computer readable, the image]
# [the monitor, the monitor]
# [square wave, the present, time constant]
# [light beam, lighting equipment, light beam]
# [mobile terminal]
# []
# [head-up display, personal computer, tablet device]
# [the image, the culture]
# [electronic device, computer readable, recording medium]
# [block diagram, electronic device]
# [main memory, network camera]
# []
# []
# [data feed, the image, data feed]
# [the present, the computer, electronic device]
# [identification number, identification number]
# [point cloud data, threshold value, number of]
# [vertical axis, visible region]
# [the Internet, the image, the Internet]
# []
# []
# []
# [Network Access, network access]
# [The image, spatial filter]
# [the system, storage medium, the image]
# [information processing system, information processing system, electronic pen]
# [flow diagram]
# [the image, region of interest, degree of freedom]
# [more than]
# [the present]
# [the system, the system, the image]
# [forensic video]
# [vehicle body, the present, the present]
# []
# [spatial dimension, spatial dimension, coordinate system]
# [data encoding]
# [wafer thinning, optical sensing]
# []
# [the window, the window, the window]
# [curved lens, curved lens, curved lens]
# []
# [display screen, printing system, touch panel]
# [light source, electronic device, light source]
# [magnetic resonance, magnetic resonance, the image]
# [the image, the features, threshold value]
# []
# []
# []
# [field operator, the field, electronic mail]
# [the image]
# [number of, IT infrastructure]
# [storage device, random access, read-only memory]
# [The computer, the image, results of]
# [product management, the owner, product management]
# []
# []
# [number of, the height, the height]
# [portable devices, block diagram, multifunction device]
# []
# [set of data, set of data]
# [convolution operation, in parallel, sliding window]
# [image recognition, signal processing]
# [the image, the image]
# [machine learning model, conditional random field, structured perceptron]
# []
# [the present, computer readable, storage medium]
# [POSITIONING SYSTEM, COORDINATE SYSTEM, IMAGE COORDINATE]
# [road surface, the resistance, road surface]
# [polyethylene terephthalate, polyethylene naphthalate]
# [spectrum line, the signal, spectrum line]
# []
# [neural network model]
# [one piece]
# [the system, the image]
# [electronic device, light source, the image]
# []
# [the image, transmission coefficient, transmission coefficient]
# [computing device, image information, computing device]
# [the human heart, neural networks, convolutional neural network]
# [the image, mobile terminal, mobile terminal]
# []
# [historical information, the warehouse, the warehouse]
# [the present, laser beam, laser beam]
# []
# [fingerprint sensor, triangular prism, triangular prism]
# []
# []
# [The system, parking space, the entry]
# []
# [parallel parking, parking area, the following]
# [pressure wave]
# [wireless Internet, Wireless LAN, Wireless Fidelity]
# [the present, eye tracking, eye tracking]
# [real time, on the fly, real time]
# [field of view, field of view, field of view]
# []
# [a vehicle, linear polarization, camera lens]
# [deep learning, neural network, neural network]
# []
# [display screen, smart phone]
# []
# [monitoring system, monitoring system]
# [display device, a vehicle, a vehicle]
# [the present, the image, the image]
# [wireless communication, barcode reader]
# [candidate list, network interface]
# [image processing, vertical direction, coordinate axis]
# [a vehicle, vehicle body, vehicle body]
# [the Cloud]
# [the image]
# []
# [optical device, optical device]
# [electronic devices, blood glucose monitoring, measuring device]
# []
# [neural network]
# []
# [the present]
# [machine learning, road surface, Deep Learning]
# [camera module]
# [distributed Bragg reflector, distributed Bragg reflector, number of]
# [regular expression]
# [power monitor, power management, power monitor]
# [The present, a vehicle, daytime running lamp]
# []
# [The image, the image, real object]
# [control operation, the field]
# [the present, the present]
# [touch panel]
# []
# [light source]
# [the security, advanced peripheral bus]
# []
# [parking lot, parking lot, parking lot]
# [the other side, face recognition]
# []
# [data structures, data structures]
# []
# [The image, number of]
# []
# [laser light, laser light, LED light]
# []
# [distance measurement]
# [pedestrian crosswalk, control device, the signal]
# [number of, digital data, remote system]
# [diffusion layer, normal mode, analog signal]
# [load control, load control, load control]
# [in parallel]
# []
# [a vehicle, on the side, vehicle body]
# []
# [real space]
# [point cloud data, point cloud data, point cloud]
# [the spirit, the present]
# []
# [deep learning]
# [the shapes]
# [control bus, input device, The system]
# [blind spot, blind spot, blind spot]
# [RF module, integrated circuit, RF module]
# [the power, the power, the power]
# []
# [virtual object, virtual object, 3D models]
# [encryption algorithm, encryption algorithm, encryption algorithm]
# []
# [halftone process]
# [color Doppler, the sound, the image]
# [Hu moments, Hu moments, the present]
# [computer system, computer system, computer system]
# []
# [the following, function key]
# [The units, physical units, the units]
# []
# []
# [A vehicle, the present]
# [video surveillance, block diagram, computing device]
# []
# []
# [mobile payment, electronic device, mobile payment]
# [a vehicle, the present]
# [number of, magnetic field, the present]
# [electronic pen, electronic pen, electronic tag]
# []
# [color filter array, training set]
# [computer program]
# []
# []
# [electronic device]
# []
# [the image, the times]
# [neural network]
# [flow diagram, medical imaging, the present]
# []
# []
# [raw image, raw image, image processing]
# []
# [The image, the image, the image]
# []
# [information processing system, virtual object, the movement]
# []
# []
# [road surface, road surface, optical resolution]
# [the image, color image]
# []
# [block diagram, the present, the present]
# []
# [information management system, information processing, base station]
# [the present, the signal, period of time]
# [processing power]
# [the present, the present]
# [electronic device, power source, rechargeable batteries]
# [user experience]
# [data compression]
# [magnetic strip]
# [storage medium, storage media, removable media]
# []
# [fully rigged]
# [electronic device, the image, electronic device]
# [time unit]
# [the environment, the environment, the environment]
# [the present, the present, the present]
# [the image, the image, the image]
# [driver's seat]
# [block diagram, control unit, control unit]
# [second sound, space boundary, second sound]
# []
# [direction of travel, a vehicle, open Patent]
# []
# []
# [electronic device, electronic device, visual light]
# [the present, the present, the present]
# [high speed, compressed air]
# [the image, reference plane, the image]
# [the present, lane line, lane line]
# []
# [power supply unit, mobile terminal, power supply unit]
# [the image]
# [control unit, the image]
# [data structure, the image, the image]
# [The image]
# [mobile device, electronic device, mobile device]
# []
# [the present, the present, the present]
# [the following, road surface, road surface]
# []
# [parking assist, parking assist, the present]
# [autonomous vehicle, the present, fuel efficiency]
# []
# [photo sensor]
# [drip chamber, drip chamber, drip chamber]
# [training method]
# [the image, network camera]
# []
# []
# [input and output, input device, output device]
# [digital camera, video camera, face recognition]
# [store data]
# []
# [medical image processing, medical image processing]
# []
# [the image]
# [service provider, mobile communication, mobile communication]
# [electrical connection]
# [the present, image processing, the present]
# [information processing, the image, number of]
# [lattice filter]
# []
# []
# [The image, control unit, automated driving]
# []
# [The sphere, table tennis, the sphere]
# [control device]
# []
# [two-dimensional code, two-dimensional code, number of]
# []
# [the present]
# []
# [neural network, neural network, The static]
# [probability distribution]
# [The present, data processing system, machine learning]
# [visible light, visible light, fill light]
# [two-dimensional code, mobile terminal, two-dimensional code]
# [the security, the security]
# [The image, field of view, direction of travel]
# [decision process]
# [automated warehouse]
# []
# [social network, digital image, the social network]
# [the environment]
# [frame rate]
# [cross-sectional area, unit cell, unit cell]
# []
# [the message, the message]
# [data integration, the present]
# [convolution operation, convolution operation, convolution operation]
# [the present, surveillance video, electronic device]
# [the master, brightness value, the image]
# [functional units, the present, more than]
# []
# [communication network, communication network, communication network]
# [The computer, environmental conditions]
# [oscillating motion, plastic packaging]
# [electronic tag, temperature sensor, electronic tag]
# [POS terminal, control unit]
# [the features]
# [block diagram, fingerprint recognition, the present]
# [feature data, feature data, feature data]
# [the entry, authorization code]
# [information display, information display, the field]
# [mobile computing device, computing device, the hotel]
# [monitoring system]
# [head unit, head unit, head unit]
# [cover slip, cover slip]
# []
# []
# []
# [control system, monitoring system, welding power supply]
# [process block]
# [number of, the image, number of]
# [the present, threshold value]
# [program file, the present, the following]
# [power transmission, control unit, control unit]
# [upper limit, reading rate]
# [video signal, video signal]
# [control unit]
# [Dynamic Time Warping, measurement of distance, lane change]
# [convolution operation, number of, number of]
# [light source, the image]
# [region of interest]
# []
# [optical filter, refractive index]
# [card association, card association]
# []
# [The image, optical system, the image]
# [flow diagram]
# [personal computers, cell phones, personal computers]
# [user input, input device]
# [lowest density]
# [application-specific integrated circuit, field-programmable gate array, logic device]
# [the filter, the filter]
# [the order]
# [light source, light source, position information]
# [user interfaces, biometric authentication, user interfaces]
# []
# [a vehicle]
# []
# []
# [computer readable, flash memory, read-only memory]
# [the image, the original, the image]
# [the present]
# []
# [block diagram]
# [block diagram, tracking device, tracking device]
# [fingerprint recognition, fingerprint detection]
# [control unit]
# [interaction information, interaction information, interaction information]
# [electronic device, electronic device, electronic device]
# [movement control]
# [Field-Effect Transistor]
# [number of]
# [data processing, moving image, field of view]
# []
# []
# [the world, the software, low memory]
# [point cloud data]
# [the environment]
# [electronic device, proof of identity, medical prescriptions]
# [the present, the present, the present]
# []
# []
# []
# [electronic file, binary file, Microsoft Word]
# [image processing, object recognition, control system]
# [SMS messages, the Internet, tablet computers]
# []
# [a square, design choice]
# [card reader, the present, electrical conductivity]
# []
# [neural network]
# [light sources, light source, light sources]
# [Application Programming Interface, Operating System]
# [the following, food composition]
# [mobile robot]
# [the image, feature extraction, multiple images]
# [the power, electronic device, wireless charging]
# [mobile platform, mobile platform, mobile platform]
# [the system, point cloud, point cloud]
# []
# [the present, color calibration, color calibration]
# [front end, front end, front end]
# [I/O interface, home button, start button]
# []
# [crime prevention, image processing, the image]
# [the present, object storage, object storage]
# []
# [recording medium]
# [the present, the present, the present]
# [the order, in parallel]
# []
# [the present, the image, the image]
# [computer network, virtual private network, local area network]
# []
# [iris recognition, terminal equipment, iris recognition]
# [the emergency, collision avoidance system, automatic braking]
# [computer program, radio signal, computer readable]
# [management system, the spiral, the spiral]
# []
# [image information, turn signal]
# [object recognition]
# []
# [the following]
# [supervised learning, training data, training data]
# [The system, raw image, The system]
# [block diagram, data structure, user identifier]
# [indoor environment]
# [radio tag]
# [place marker, place marker, signature Record Type Definition]
# [the height, the height, the height]
# [the present]
# [composite image, of components, composite image]
# [schematic diagram, eye tracker, eye tracker]
# [shopping basket]
# []
# []
# [execution unit, graphics engine, operating system]
# [mobile terminal, the present]
# [image analysis, machine learning, the image]
# [The present]
# [angular velocity, vertical axis]
# []
# [the present, the present]
# [threshold value, threshold value, threshold value]
# [image conversion]
# [The present]
# [operating system]
# []
# []
# [The image, spatial frequency, spatial frequencies]
# []
# []
# []
# [the present, the image, specific area]
# [Euclidean distance, and circuit, electrical circuits]
# []
# [code words, for all practical purposes, code words]
# [numerical data]
# [articulated trucks, rail transport]
# [road surface, utility pole, road surface]
# [drive shaft, drive shaft]
# [the following]
# [control unit]
# []
# []
# []
# [distributed computation, the present]
# [data anonymization, number of]
# []
# []
# [monitoring system, number of]
# [user interface, multifunction device, user interfaces]
# [more than, number of]
# []
# [the arrow]
# []
# [the change, door switch, door switch]
# []
# [wireless communication, control device, wireless communication]
# []
# [number of]
# [the image, the present, the image]
# [central processing unit, graphics processing unit, accelerated processing unit]
# [image recognition, the present, Image recognition]
# [medical images]
# [broadcast signal]
# []
# []
# [software modules, functional unit]
# []
# [learning algorithm, random forest]
# []
# [real time, real time, video toll]
# []
# []
# [the system, the system]
# [home button, fingerprint sensor, electronic device]
# [The present, measuring device, control system]
# []
# []
# []
# []
# [training method, deep neural network, transfer learning]
# [information processing, the present]
# [The system, coordinate system, coordinate system]
# [the present]
# []
# []
# [field of view, field of view]
# [the image, the image]
# [Integrated Circuits, the patch, user interaction]
# []
# []
# [number of, machine learning, number of]
# []
# [the following]
# [The system, robot arm, virtual image]
# [pressure sensor]
# []
# [The present]
# []
# [training data]
# [physical object]
# []
# [on the road, laser light, road surface]
# []
# [robot arm, robot hand, position information]
# [the present, information processing, self-driving car]
# [the present, focal distance, object type]
# []
# [mobile terminal]
# [power supply unit, mobile terminal, power supply unit]
# []
# [The system, location data]
# []
# [mobile terminal, the following]
# [position information]
# [recording medium]
# []
# [functional units, the present]
# []
# [the present]
# [the present, data processing, electric power consumption]
# [one piece, control unit]
# []
# [lifting device, control unit, crime prevention]
# [Deep learning, machine learning]
# [medical imaging, control unit, input device]
# [the image]
# [public transportation, the consumption]
# [AERIAL VEHICLE]
# [the present, index finger, the present]
# [the present, the present]
# [internal diameter]
# [the image, the image, prior art]
# []
# [The present]
# [the present]
# [white list]
# [data integration]
# [The system, Bezier curves]
# [compact fluorescent, object recognition]
# [the present, the present, the following]
# [region of interest, region of interest, region of interest]
# []
# [A vehicle, a vehicle, electronic control unit]
# [the present, the present, the present]
# [in contact, water pump, water supply]
# [mobile terminal, flexible circuit, piezoelectric actuator]
# [The present, the present]
# [spatial audio, spatial audio, spatial audio]
# [perceptual hash, discrete cosine transform, two dimensional]
# [the present, user interface, composite image]
# [the present, refractive index]
# [identification system, object space]
# []
# []
# [the image, the image, the image]
# []
# [the Present]
# [management system, position information, management system]
# [The present]
# [relational database, database table, input data]
# [The following, the present, the present]
# [block diagram, control system, user interface]
# []
# [intravascular imaging, intravascular ultrasound, optical coherence tomography]
# [The security]
# []
# []
# []
# []
# []
# [vehicle brand, vehicle brand, vehicle brand]
# [number of]
# []
# [groups of people]
# [The image, light source]
# []
# [signal processing]
# [laser light, road surface, shape changes]
# [the following]
# [electronic device, visible light, visible light]
# []
# [a vehicle]
# [threshold value, wireless power]
# [focal length, focal length, focal length]
# []
# [navigation system, parking lot]
# [unique identifier, the signal, the message]
# [the present, injection molding, electrical connection]
# []
# [mobile terminal]
# []
# [the present, control module, AC voltage]
# [restraint device, restraint device, visible light spectrum]
# [communication circuit]
# [quality management, with high probability, product management]
# [vertical direction, vertical direction, horizontal direction]
# [electromagnetic wave]
# [face recognition, face recognition, face recognition]
# [low temperature]
# [the image, black level, the image]
# [security checkpoint]
# [time series, low power, mobile phones]
# []
# []
# []
# [the culture]
# []
# [payment platform]
# [network service, the image, the service]
# []
# []
# [the present, electronic map]
# [the present, mobile terminal, fingerprint recognition]
# [vanishing point]
# [the system, communication network, geographic database]
# [Security Domain]
# []
# [shopping site, the address, credit card]
# []
# [mobile device, electronic devices, electronic devices]
# [threshold value, home screen, fingerprint authentication]
# []
# [the present, the present, the present]
# []
# [the present, the present, the spirit]
# [the security, the security]
# [ground truth, ground truth]
# [reflected light, CMOS sensor, CMOS sensor]
# [parking space]
# []
# []
# []
# []
# [jog wheel, electrical signal]
# []
# []
# [gradient of a line]
# [the present, the image, the present]
# [The present, storage medium, The computer]
# [the image, the image, the image]
# [HTTP requests, the spirit]
# [movement control]
# [gradient descent method, gradient descent method, the following]
# [there exist]
# []
# [neural network]
# []
# [infrared ray, electronic device, electronic device]
# [user interface]
# [information display, the image, object based]
# []
# [user input]
# [near future, life expectancy, the elderly]
# [license plate, license plate, the image]
# [input and output, input and output]
# [the present, the present, signal generator]
# [storage device, storage device]
# [user information, user information, user information]
# [first shift, high voltage, high voltage]
# [the present, the units]
# [road traffic, orthographic projection]
# [the system]
# [display device, the present]
# [computer program, computer control]
# [ELECTRONIC DEVICE]
# [number of, number of]
# [the present, monitoring system, monitoring system]
# []
# [fingerprint sensor, fingerprint sensor, fingerprint sensor]
# [the image, the image, skin color]
# [the signal, examination unit, examination unit]
# [the image, the image, horizontal direction]
# []
# [heart rate, motion data, motion sensor]
# []
# [the image, the image]
# [number of]
# []
# [no communication]
# [tamper indicating]
# [information processing]
# [number of, threshold value]
# [ultrasound probe, image analysis]
# [for every, for every]
# []
# []
# [the present, internal combustion engine, power source]
# [electronic device, fingerprint sensor, fingerprint sensor]
# []
# [principal component analysis, principal component analysis, factor loading]
# [mixing ratio]
# [the image]
# [display device, the image, display device]
# [the image]
# []
# [optical system, the present, optical system]
# [The system]
# [magnetic strip, magnetic strip, the original]
# [block diagram, the image]
# []
# [fingerprint recognition, the entry]
# []
# [the security]
# [control unit]
# [BIRD Navigation]
# [unit cell, unit cell, unit cell]
# [computer program, non-volatile storage, software product]
# [data store, representation learning, machine learning model]
# []
# [number of, number of]
# [stereo camera, viewing angle]
# [the image, video stream]
# [In parallel]
# [The present, autonomous vehicles, the present]
# [period of time, period of time, period of time]
# []
# [credit card issuer, online transactions, mobile wallet]
# [electronic device]
# [image processing, gamma correction, frame rate control]
# [training data set, image analysis, image analysis]
# []
# [the present]
# []
# []
# []
# []
# [organic semiconductor]
# []
# [rate of change, instruction unit, slow down]
# [a search, a search, search term]
# [the image, stray light, the image]
# [electronic device, electronic device, user information]
# []
# [the present, the system, the present]
# [image analysis, the baker]
# []
# [block diagram, system bus, wireless communication]
# [start point]
# []
# []
# [position information, position information, face recognition]
# [parking space, external device]
# []
# [the present, the present, the present]
# [mobile device]
# [neural network, neural network, neural network]
# [optical communication, external device, optical communication]
# [party service, party service]
# [induced current, magnetic flux, magnetic flux]
# []
# []
# [monitoring system, location information, field of view]
# []
# [anomaly detection, the normal]
# [computer system, The system, computer system]
# [blind spot monitor, blind spot, blind spot]
# [the present, mobile phone, fingerprint sensor]
# []
# [imaging system, focal plane array, nose cone]
# [left block, left block]
# [the energy, power supply, Energy Harvesting]
# [yet another, computer program, computer readable]
# [point cloud, the environment]
# [the present, skin care, standard time]
# [position information]
# [the present, the power]
# []
# [image denoising, exposure time, the image]
# [index matrix, gradient vector]
# []
# [raw image, raw image]
# [porous materials]
# [plain text, plain text, electronic document]
# []
# [electronic device, the image, the image]
# [electrical signal, electrical signal]
# [radio frequency identification, microcontroller unit, front end]
# [free-viewpoint video]
# []
# [data extraction, quality data]
# []
# [computing device]
# [schematic diagram, unit cell, unit cell]
# []
# []
# [face recognition, mobile communication, the system]
# [the present, computer program, the present]
# [the master, the master, the master]
# [wearable device, wearable device, wearable device]
# []
# [the image]
# [the present, virtual model]
# []
# [from the top, the window, the window]
# [the present]
# []
# [control device]
# []
# [the image]
# [the message, fingerprint sensor, home button]
# []
# [electronic device, electronic device, electronic device]
# [user interface, the other side, the street]
# [biometric authentication, biometric authentication, user interface]
# [steering wheel]
# [license plate, the image, the image]
# [storage device, data structures, main memory]
# [natural language]
# [biometric authentication, electronic device, electronic device]
# [display examples]
# []
# [the image, display device]
# [program code, Web Services, application server]
# [data transmission]
# [processing information]
# [the system, virtual reality, motor vehicle]
# []
# []
# [PTZ camera, the image, PTZ camera]
# []
# [vehicle platform, light detection and ranging, motion detection]
# [thumbnail image, thumbnail image, still image]
# [user interface, printing system, print job]
# [optical system, test pattern, optical system]
# [schematic diagram, information collection, the present]
# [automated driving, automated driving, automated driving]
# [specific time, the order, time interval]
# [the field, image processing, image processing]
# []
# [period of time, the image, eye tracking]
# []
# [the image, the image, image processing]
# []
# [control unit]
# [onboard camera]
# [blind spot, blind spot, on the road]
# []
# [straight line, optical axis, straight line]
# []
# [number of, number of, virtual reality]
# [display device, liquid crystal display, light emitting diode]
# []
# [semiconductor device, the image, frame rate]
# [variable speed limit, speed limit, variable speed limit]
# [the button, electronic device, electronic device]
# [the present, the software, the following]
# [communication network, wireless network, communication network]
# [start point, moving picture, moving picture]
# []
# []
# [field of view, field of view, the field]
# [second detection, blind spot, blind spot]
# [the present, the order]
# []
# [System model, Data model, system model]
# [stereo images, the image, stereo images]
# [high resolution, high resolution]
# [Digital Signal, Random Access, I/O interface]
# []
# [electronic device, the following, electronic device]
# []
# [video file, the original]
# [fingerprint sensor, the present, fingerprint sensor]
# [CO2 lasers, CO2 laser]
# [motor vehicle, the motor, a vehicle]
# [mobile device, mobile device, mobile device]
# [second processor, second processor]
# []
# []
# [point in time, autonomous driving, autonomous driving]
# [user interaction, close coupling, electromagnetic radiation]
# []
# [the image, the image, the image]
# [information processing, edge detection]
# [management system, game token, the present]
# []
# [point cloud, principal component analysis, point cloud]
# [The signal, the traffic, signal lamp]
# []
# []
# [electromagnetic energy]
# []
# [the image, the image]
# []
# []
# [position and orientation, line of sight, the system]
# [MOBILE DEVICE]
# []
# [the present, the original, the image]
# [the present, a vehicle]
# [information processing, real space, real space]
# [gate electrode, gate electrode, gate electrode]
# []
# []
# []
# [information processing]
# [5th column, 5th column]
# []
# [the following]
# []
# []
# [credit card number, Luhn check]
# [shopping basket, the image, the image]
# [real time, first stage, second stage]
# [A vehicle, lifting device]
# [convex lens]
# [the following]
# [self-organizing map, self-organizing map, self-organizing map]
# []
# [the image, dynamic range, sum of absolute differences]
# [plantar pressure, the present, force plate]
# [fingerprint recognition, wall plate]
# []
# []
# [the traffic, a vehicle, position information]
# [navigation system, location information]
# [a vehicle]
# [light reflection]
# [the system, number of, the cause]
# []
# [explanatory diagram, image recognition, 90 degrees]
# [the present, Young's modulus, fingerprint sensor]
# [electronic document, data gathering]
# []
# []
# [number of, the order]
# [the present, the public]
# [a vehicle, optical axis, reference state]
# [object detection]
# [block diagram, the image]
# [remote control, remote control, remote control]
# []
# [the present, optical coupler, in parallel]
# [medical image, data processing system, medical image]
# [information processing, position information, position information]
# [the present, crop residue, The system]
# [information processing]
# [data conversion]
# [touch panel, display device]
# []
# [number of, the shapes, the FOLLOWING]
# [number of]
# [index finger]
# []
# [learning algorithm, ground truth, ground truth]
# []
# [power supply]
# [readable code, access control, version number]
# []
# [sensitive information]
# []
# [object detection]
# [the present, fingerprint recognition, fingerprint recognition]
# [the present, control operation, smart home]
# [the present]
# [field-effect transistor, the source]
# [the alarm, threshold value, threshold value]
# [the present, digital device]
# [optical receiver, electromagnetic waves]
# []
# [data structure, data structure, code conversion]
# [time series]
# []
# []
# [sensitive information, secure information, secure information]
# [region of interest, region of interest, region of interest]
# [the image, the image, the image]
# [the library, error rate, bit error rate]
# []
# [the present]
# []
# [character recognition]
# [parking space]
# []
# [optical character recognition, vertical axis, lookup table]
# [the present]
# [information table]
# [the image, phase shift, colour component]
# [The present, a vehicle, daytime running lamp]
# [still image]
# []
# []
# [the following]
# [the window]
# [number of, convolution operation, number of]
# [stereo camera, control unit, image processing]
# [Document Scanning]
# [user interface, user interface, mode of operation]
# [the image, image analysis, the image]
# []
# [heart rate]
# []
# []
# []
# [intensity of light, light sensor]
# [The units, physical units, the units]
# [chip package, solder ball]
# [the present]
# []
# [The units, physical units, the present]
# [the following]
# []
# []
# []
# []
# [facial expression, facial expression, facial expression]
# [the features]
# []
# [The present, the field]
# [information processing, the sport, information processing]
# [light sensor]
# []
# [electronic device, electronic device, electrical path]
# [number of, production process, number of]
# [the computer, the computer]
# [chip package]
# [radio wave, optical system]
# [electronic signature, digital signature]
# []
# [electronic device, electronic device, electronic device]
# []
# []
# [the weather, the atmosphere]
# [image processing, image information, image information]
# []
# [binary image, binary image]
# [the image, the image, information storage]
# [the present, audio signal, time domain]
# [The environment, distance measurement, distance measurement]
# []
# [the present, degree of freedom]
# []
# [the order, number of, number of]
# [radio tag]
# [On the side, on the side]
# [location information, location data]
# [binary number]
# []
# [the image, the image, the image]
# [video surveillance]
# [the present]
# []
# [key generation, pull-up resistor, pull-up resistor]
# []
# []
# [process state, luminance value, process state]
# [time tracking, the enterprise, time tracking]
# [mobile robot]
# [Data Type]
# [schematic diagram]
# [flat surface]
# [computer readable, storage device, the change]
# []
# [forage harvester]
# [Online Training]
# [control unit, central processing unit, the image]
# [electronic device]
# [the original]
# []
# [data processing, data processing, data processing]
# [position information, control unit]
# []
# [the image]
# [composite image, composite image, composite image]
# [mass storage device, machine-readable medium, data structures]
# []
# []
# [the following, rotation angle]
# [The present, electronic tag, electronic tag]
# [MAGNETIC STRIPE, DATA TRANSMISSION]
# [the system, the system]
# [The image]
# []
# []
# []
# [threshold value, the movement, threshold value]
# []
# []
# [fingerprint identification, high precision, mobile phones]
# [front-facing camera, front-facing camera]
# []
# [electronic device, infrared ray, infrared sensor]
# [the image]
# [object recognition, object recognition]
# [The system, test pattern, threshold value]
# [period of time]
# [weather radar, cross section, display device]
# [time-series data, the system, CPU usage]
# []
# [the normal]
# [mobile phone application, mobile phone, mobile phone]
# [reference point, Polar coordinate system]
# [the image, upper limit]
# []
# [electronic tag]
# []
# []
# [programmable devices, integrated circuits, state machines]
# [halftone process, the image, the image]
# [calibration target]
# [storage medium, time series, time series]
# [the Internet, the present]
# [The system]
# [the change, two-dimensional code, error correction]
# [position sensor, tracking system, coordinate system]
# [mobile terminal]
# [the present, element 111, physical quantity]
# []
# [universal integrated circuit card, the present, the following]
# [number of]
# []
# []
# []
# [facial expression, the image]
# []
# [A vehicle]
# [the image]
# [first system]
# []
# [LED light, LED light, LED light]
# [the present, identification system, The system]
# []
# [external device]
# [object type, object type]
# []
# [driving license, birth certificate]
# [the present]
# [computer storage, the computer, storage medium]
# [volatile storage, random access, non-volatile storage]
# []
# [neural network, weighted sum, neural network]
# [skin color, skin color, transition state]
# [The present, computer program, The computer]
# []
# [the resistor, parallel circuits, the resistor]
# []
# [delivery system]
# [autonomous vehicle, autonomous driving, autonomous vehicle]
# [control unit]
# [low resolution, high resolution, high resolution]
# []
# []
# []
# []
# [The present]
# [number of, digital processing, processing power]
# []
# [number of, the worker, mobile terminal]
# [the image, the image, network camera]
# []
# [specific area, the worker, the worker]
# [spectral sensitivity, the image, data storage]
# [fuzzy logic]
# []
# []
# []
# []
# [the following, driving direction, driving direction]
# [point of sale]
# [front-facing camera]
# [the present, the present]
# []
# [travel lanes, travel lane]
# [data stream, data stream, memory device]
# []
# []
# [parallel processing, software product]
# [the image]
# [neural network, neural circuit, human learning]
# []
# [the features, refresh rate, image processing]
# [azimuthal angle]
# []
# [the present]
# [vertical space, vertical direction, horizontal space]
# []
# [the present]
# [facial expression, facial expression, facial expression]
# [cooking utensil, the present, cooking utensil]
# [user input]
# []
# []
# [translation device, background color]
# [the computer, radio signal, computer readable]
# [mobile terminal, biometric data, mobile terminal]
# []
# [electrical connection, conductive trace]
# [the system]
# [the change]
# [the image, the image, the image]
# [cooking utensil, two-dimensional code, cooking utensil]
# [location information]
# []
# [deep convolutional neural network, deep convolutional neural network, number of]
# [intelligent terminal, wearable device]
# [the image, the image, electronic system]
# [user information, user information, information processing]
# []
# []
# [monitoring system, user interaction, monitoring system]
# [more than]
# [plan view, fingerprint sensor]
# [number of, number of, number of]
# []
# [autonomous vehicle]
# [raster image, information processing, the image]
# [the image, the window, the window]
# [the present, the present, the movement]
# [radio tag, radio tag, radio tag]
# [the image, transfer function, data transfer]
# [computer device, computer program]
# []
# [the normal, analog-to-digital converter, measurement unit]
# []
# [The present, image processing, the image]
# [Samsung Pay, Apple Pay, the present]
# [radio frequency, RF signal, structural integrity]
# [The present, iris recognition, schematic diagram]
# []
# []
# [form factor, field of view, thermal imaging cameras]
# [field of view]
# [the human face, electronic device, the ratio]
# [electrical connection, circuit board, circuit board]
# [the system]
# [image processing, number of, convolution operation]
# [user interface, time series, time domain]
# [The image]
# [information device, touch panel, information device]
# [security system, the security, memory device]
# [time of day, acceleration sensor, time of day]
# []
# [the image, the image]
# [dermal ridge, dermal ridge, dermal ridge]
# []
# [the following]
# [the image]
# [POS Terminal]
# [mobile terminal]
# [the image, data storage]
# [the image, control unit, the image]
# [input device, computer system, display device]
# [field of view, one camera]
# [eXtreme Digital, Read-Only Memory, Secure Digital]
# [The image, data management system]
# [the following, 30 seconds, threshold value]
# []
# [the present, passive RFID, integrated circuit chip]
# []
# []
# [ACTIVITY DETECTION]
# [capacitive coupling, fingerprint recognition, fingerprint recognition]
# [edge detection, edge detection]
# [the movement, the movement, the movement]
# [electronic device, user interface, user interface]
# [a vehicle, the shadow, camera lens]
# [the image, the image, the image]
# [mobile terminal]
# []
# []
# [image processing, image information, image information]
# [the present]
# []
# []
# []
# [parking space]
# [information collection, information transmission, information transmission]
# [the present]
# [the present, computer code, recording medium]
# [data processor, data processor, data processor]
# [number of, imaging system]
# []
# []
# [number of, single user, user interface]
# [personal cloud]
# [number of]
# [the image, the bridge, vertical line]
# [circuit schematic, Transmission line, cutoff frequency]
# [moire pattern, moire pattern, moire pattern]
# [moving unit, rotation angle]
# [control operation, control module, smart home]
# [prior art, the present, the present]
# [the present, the following, the present]
# [iris recognition, iris recognition, iris recognition]
# [artificial neural network, artificial neural network, object class]
# [internal memory, storage medium, internal memory]
# [distance sensor]
# []
# [the image, object based, the image]
# [information processing, virtual object, virtual object]
# [white balance, the image, the image]
# [in parallel, the image, the computer]
# [tracking and tracing, product cycle, is missing]
# [the image]
# [electronic device, infrared camera, infrared light]
# [control unit, control unit]
# [cinder blocks, the present]
# [data encryption, data encryption, data encryption]
# [electronic device, the following]
# []
# [the cloud, the filter, the filter]
# []
# [The present, wireless transmission, Passive Entry]
# [external device]
# [printing system, the system, the system]
# [low resolution]
# []
# [image sensor, network interface, The image]
# [motor vehicles, central computer, alarm systems]
# []
# [transparent display, transparent display, thin film]
# [the present, electronic device, electronic device]
# [neural networks]
# [personal computers, laptop computers, tablet computers]
# [the following]
# [schematic diagram, mobile terminal, the present]
# [the present, A vehicle, Electronic Control Unit]
# [issue number, information processing, the present]
# []
# [light source, light emitting diode, light-emitting diode]
# [the present]
# [electronic device, the present, electronic device]
# [Prior Art]
# [the image, traffic sign, autonomous driving]
# []
# [computer readable, the image]
# [the image]
# []
# [electronic device, printed circuit, printed circuit board]
# [the present, resonant frequency, resonant frequency]
# [number of, number of, the image]
# []
# [floor plan, floor plan, the system]
# []
# [air pressure, water pressure, surface pressure]
# []
# [image processing, reference surface, reference surface]
# [the image, computer vision, number of]
# []
# [electronic device, fingerprint recognition, fingerprint detection]
# []
# [user information]
# []
# [time sequence, the change]
# [reference plane]
# []
# [raw image, raw image]
# [the system, the image, dot density]
# [readable code, readable code, electronic computing]
# [the image, the image, the image]
# [Video copy detection, copyright protection, the following]
# []
# []
# [10 seconds]
# [The present]
# []
# [straight line]
# [wireless communication, wireless communication]
# []
# []
# [the order, number of]
# []
# [fingerprint region, position information, fingerprint region]
# [contact type, contact type, optical system]
# [local storage, digital video recorder, local storage]
# []
# [the image]
# [the following]
# [number of, number of, number of]
# [moving image, still image, moving image]
# [data processing unit, display controller]
# [color difference, color difference]
# []
# []
# [information processing, information processing, moving image]
# [the present, video object, video object]
# [mobile device, mobile device, the cloud]
# [information device, information device]
# [steering angle, steering angle, steering angle]
# []
# [the image, the image, the image]
# [blind spot, blind spot, blind spot]
# [the image, image processing, the image]
# []
# [The image]
# []
# [unique identifier]
# []
# [communications device, communications device, communications device]
# [control device, a vehicle]
# [fingerprint recognition, the present, smart terminal]
# []
# [multiple users, computing device, computing device]
# []
# []
# [configuration model, configuration model, configuration model]
# [the present]
# [electromagnetic field, electromagnetic field, user input]
# []
# []
# [the image]
# []
# [electronic device, light source, image sensor]
# []
# [wave radar, dimensional space, wave radar]
# [virtual world]
# [first light, first light, reference plane]
# [quarter-wave plate]
# []
# [the image, the image, the motor]
# [vertical axis]
# [IMAGE PROCESSING, IMAGE PROCESSING]
# [the present, the system]
# []
# [travel lane, travel lane, travel lane]
# [number of, the image, number of]
# []
# []
# [control module, user input]
# [A vehicle, the image, the image]
# [the image, the movement, the movement]
# [parallel processor, external memory, parallel processor]
# []
# [The field, the present, the image]
# []
# [user input, IEEE Transactions on Pattern Analysis and Machine Intelligence, European Conference on Computer Vision]
# [the system, the present]
# [the present, electromagnetic induction, magnetic field]
# [cost function, gradient method, neural network]
# [information processing, the present, the present]
# []
# []
# [first system]
# [to be determined]
# [the following]
# [edge detection, edge detection]
# [printed circuit board, printed circuit board, optical technology]
# [the present, storage device]
# []
# []
# []
# [tracking device, tracking system, Mobile Industry Processor Interface]
# [neural network, neural network, neural network]
# [the image, period of time]
# [electronic devices, electronic device]
# [autonomous vehicles]
# []
# [infrared sensor]
# []
# [data model, the present, the following]
# [the environment, the present, 3D modelling]
# []
# []
# [the image, color difference, third column]
# [face recognition]
# []
# []
# [convolution operation, the signal]
# []
# []
# [information processing system, the present]
# []
# []
# []
# [parking space]
# [user mode, user mode, user mode]
# [parking area, parking area, parking area]
# [electronic device, main processor, fingerprint identification]
# [the present, object recognition, object recognition]
# [computing architecture, parallel processing, neural networks]
# []
# [mobile phone, mobile phone, the software]
# [The alarm]
# [The artificial intelligence, mobile terminal, machine learning]
# [control unit, medical imaging]
# [input data, Input data, biometric data]
# []
# [expected value]
# []
# [schematic diagram, a vehicle, information processing]
# [mobile terminal, information collection, information collection]
# []
# [artificial neural network]
# [rotation angle]
# [Driver Assistance System]
# [the present]
# []
# []
# []
# [may issue, electronic device, readable code]
# [progress indicator, fingerprint sensor, home button]
# [the present, air conditioning, air conditioning]
# [the original, the original, display device]
# []
# []
# [region of interest, the image, the image]
# []
# []
# [information analysis]
# [conceptual diagram, frame interpolation, information processing system]
# [electronic device]
# []
# []
# []
# []
# [the present, Base64 encoding, HTML code]
# [HDR image]
# [3D imaging]
# [The present, a vehicle, light source]
# []
# []
# []
# [the filter, number of, number of]
# []
# [video frame]
# [type of gesture, type of gesture, the change]
# [The following]
# [scattered radiation, scattered radiation, content distribution]
# [version number, the software, electronic device]
# []
# [building blocks]
# [the height]
# [The present, frequency domain, frequency domain]
# [one camera, field of view, one camera]
# []
# []
# [information collection]
# []
# []
# [the present]
# [the image]
# []
# [user interface, recording medium, recording medium]
# []
# []
# [control unit, the original, the original]
# []
# []
# []
# []
# [the present]
# [Time of day]
# [of components]
# []
# [the image, in parallel]
# [the present, electronic terminal, electronic terminal]
# [communication system, communication network, communication system]
# [the patch]
# [external device, external device]
# []
# [the present, strength training, the brain]
# [raw image, control system, the master]
# [road surface, road surface, distance measurement]
# []
# [contactless smart card]
# [the power, ascending and descending, up and down]
# [fingerprint sensor]
# [vertical take-off and landing, block diagram, aircraft control]
# [The signal, The signal]
# [user interface, object detection, a vehicle]
# []
# [two-dimensional code, two-dimensional code, two-dimensional code]
# [horizontal direction, vertical direction, the image]
# [location information]
# []
# [fingerprint identification]
# [Data store, relational database, dimensional database]
# [yet another, the present]
# [real time]
# []
# [industrial controller, input data, input device]
# []
# []
# [mobile robot, mobile robot, mobile robot]
# [in contact]
# []
# []
# []
# [the present]
# []
# [functional unit, more than, long distance]
# [the present, computer program, computer programs]
# []
# []
# [the present]
# []
# []
# []
# []
# [information device, parity check, information device]
# [travel lane, travel lane, the image]
# []
# [internal network, flash memory, The Power]
# [image processing, the ratio, the ratio]
# [suction force]
# [mirror image]
# [electronic device, electronic device, electronic devices]
# [embedded software, flight control laws]
# []
# [gaming chip, radio tag, radio tag]
# [image conversion]
# [the energy]
# []
# []
# [storage medium]
# [biometric authentication, biometric authentication, biometric authentication]
# [fingerprint sensor, fingerprint sensor]
# [neural network, neural network, neural network]
# [the system, tracking device, operating table]
# []
# [reflected light]
# [the following]
# []
# [the image, coordinate system, the image]
# [mobile device, control function, electronic device]
# [carrier signal]
# [electronic device, password hint]
# [object recognition, infrared sensor, ultrasonic sensor]
# []
# [straight line]
# [the image]
# [decision table, logical relations, decision table]
# [right lane]
# [the present, computer system, the computer]
# []
# []
# [road signs, video camera]
# [computer software, code segment, software package]
# [the image, the image, user interface]
# []
# [information distribution, wireless communicator, a vehicle]
# [specific area, the worker]
# [mobile device]
# []
# [the computer, registered user, biological data]
# [the height, the height, the height]
# []
# [biometric data, more than, threshold value]
# [two-dimensional code, two-dimensional code, two-dimensional code]
# [geographic database, geographic database, geographic database]
# []
# []
# [control module]
# [the field, the field, the field]
# [laser beam]
# [print job]
# [graphics processor, graphics pipeline, display engine]
# [feature extraction, coordinate transformation, image registration]
# [universal serial bus, communication networks, storage server]
# [road traffic, point cloud, inertial navigation]
# [neural network, neural network, neural network]
# []
# [a vehicle, radar system, radar system]
# [circuit board]
# [learning process]
# [glass bottle]
# []
# []
# [field of view, the system]
# [intensity level, threshold value, intensity level]
# [high resolution, low resolution, reading speed]
# [emergency response system, the general, the emergency]
# [equal time]
# [number of]
# [display device, near field, near field]
# [electronic device, image stabilizer, the image]
# [the present, mobile terminal, feature data]
# [The signal, The signal, The filter]
# [noisy data, data center, disk space]
# [the present, the following]
# []
# []
# [road vehicle, road vehicle, road vehicle]
# []
# [the present, the system]
# [the present, the spirit, the present]
# [data storage]
# [computing device]
# [functional block diagram, a vehicle, autonomous vehicle]
# []
# [management system, party service]
# [time signal, pulse sequence, the change]
# [infrared light, infrared light, infrared light]
# [the present, electronic device, blood sugar]
# []
# [audio and video, the voice, voice recognition]
# [electric current, electric current, electric current]
# ...
# [convolution operation, convolution operation, convolution operation]
# [number of, on the road, number of]
# [skin color, hair color, the worker]
# []
# [drug classification, label printer, label printer]
# [vertical axis]
# [the present, file format]
# [moving picture, the present, prior art]
# [the present, computer storage, the computer]
# [the image]
# []
# []
# [connecting rod]
# [the image, rough surface, rough surface]
# []
# [road surface, road surface, stereo camera]
# []
# [point of view]
# [the system, design and architecture, the internet]
# []
# []
# [a vehicle]
# [mobile terminal, cargo container]
# [a collision, system 250, system 250]
# [blind spot, blind spot, blind spot]
# []
# [the optic, the optic]
# [first position, second position, first position]
# [the image]
# []
# []
# [Portable Document Format, Portable Document Format, the image]
# [electronic device]
# [operation chart, vertical coordinate, arrival time]
# []
# [location information, location information, location information]
# [training system, training system, electronic communication]
# []
# [a vehicle, traffic accidents]
# [first state]
# [number of]
# []
# [data protection, data access, gaze tracking]
# [drip chamber, number of, low level]
# []
# [electromagnetic interference, the original, magnetic strip]
# [signal processing, threshold detector, threshold detector]
# [binary image, binary image]
# [The system, pressure sensor]
# [blind spot, blind spot]
# []
# [a search]
# [display device, metal oxide]
# [touch sensor, touch sensor, Samsung Pay]
# []
# []
# [a vehicle, a vehicle]
# [video feed, video feed, video feed]
# [the present, point of interest, the image]
# [external device]
# [The present, REAL TIME, OPTIMAL SOLUTION]
# [the worker, the worker]
# [360 degrees, scene graph, virtual model]
# [training data, The system, training data]
# [computing device, computing device, results of]
# [the present, programmable gate array, the present]
# [the present, autonomous driving]
# [functional block diagram, control system, the image]
# [the present, data processing, reflective prism]
# [control system, the present, coordinate system]
# [fingerprint authentication, fingerprint authentication, electronic device]
# [region of interest, region of interest]
# [90 degree angle]
# [the present, number of, number of neurons]
# [computing device, single user, multiple users]
# [Mohs hardness, number of, silicon dioxide]
# []
# []
# [two-dimensional code, two-dimensional code, data backup]
# []
# [ground plane, 90 degree angle]
# [a vehicle, head unit, flow diagram]
# [the artificial intelligence, mobile terminal]
# [video processor]
# [store data]
# [silicon dioxide, silicon nitride, chemical vapor deposition]
# [control system, the present, control system]
# [monitoring system, user interaction, user interaction]
# [more than]
# [progress indicator, progress indicator]
# []
# []
# [a vehicle, camera system]
# [data storage, data storage, virtual SIM]
# []
# [input data, input device, input data]
# [control unit, wired communication, radio communication]
# []
# [storage medium, video encoding]
# []
# [driving license]
# []
# []
# [application server, video streams, Video streams]
# [TAMPER EVIDENT]
# []
# []
# []
# [program memory]
# [biometric data, the present, biometric data]
# []
# []
# []
# [the present, the present, on the Internet]
# [number of]
# []
# [image information, electronic device, the image]
# []
# []
# [a vehicle]
# [the present]
# [touch panel]
# [information processing, information processing, depth map]
# []
# [the image, convolution operation, the image]
# []
# []
# [electronic device, electronic device]
# [mobile terminal, mobile terminal, mobile terminal]
# []
# [depth map]
# [control device, mobile terminal, mobile terminal]
# []
# [360 degrees]
# [the computer, computing device, the computer]
# []
# [the present, process of reading, information management]
# [tracking system, tracking system, 3D polygonal]
# []
# [mobile terminal]
# []
# [display device, display device]
# [augmented reality, computing device, video camera]
# []
# []
# []
# [dual camera]
# []
# [objective function, gradient descent]
# []
# [image processing, control unit, the image]
# [the present, storage medium, mobile device]
# [the present, the system, white blood]
# []
# [image processing, input data, store data]
# [ROC curve, receiver operating characteristic curve, false-positive rate]
# [information processing, the present, information processing]
# []
# []
# []
# []
# [control unit]
# []
# [object detection, training data, the order]
# []
# [object detection]
# []
# []
# [image processing, information processing, the image]
# [front-facing camera, low power, low power]
# [virtual object]
# [intra prediction, motion compensator, tree structure]
# [vertical orientation, page orientation, vertical orientation]
# [iris recognition, iris recognition]
# []
# [storage medium, storage medium, Random Access]
# [day and night, unmanned aerial system, flight control]
# []
# [vehicle body, vehicle body, vertical direction]
# [medical image processing, neural network, medical image]
# [the following]
# [The system]
# [information device, information device, results of]
# [region growing, threshold value]
# [vehicle body, vehicle body, horizontal direction]
# [the features, the features]
# [control unit, control unit]
# [vertical axis, the following]
# []
# [barycentric coordinates]
# []
# [the field, the image, The image]
# [conceptual diagram, the present, block diagram]
# []
# [instruction unit, stop signal, instruction step]
# []
# [information processing]
# [silicon oxide, silicon nitride, silicon oxynitride]
# []
# []
# [electronic device, the window]
# [eye tracking]
# []
# []
# [time series, number of]
# [audio signal, frequency band, Fast Fourier Transform]
# [convolutional layer]
# [the computer, the computer, location area]
# [user information, user information, user information]
# [linear least squares]
# []
# []
# [graphic element, electronic device, facial capture]
# [digital image, the image, the image]
# [radar sensor, a vehicle, rooster tail]
# []
# [monitoring system, the image, the image]
# []
# [natural language processing, Voice to text, Machine learning]
# [the system, virtual object, virtual object]
# [GEOPHYSICAL SURVEY, REGION OF INTEREST, COMPUTER PROGRAM]
# [decision tree]
# [conceptual diagram, graphical representation, user input]
# [yet another, the system]
# [mobile terminal, mobile terminal, mobile terminal]
# [visual cues, display device, PDF format]
# []
# []
# []
# []
# [number of]
# [interaction information]
# [the shapes]
# [period of time, time frame, current time]
# []
# [control system]
# []
# [autocorrelation function, coordinate axis, polar coordinate system]
# [The image, computerized tomography, data file]
# []
# [neural network, object classes, neural network]
# [the image]
# [facial expression, control device, facial expression]
# [control unit, control unit, body surface]
# [the present]
# [the order]
# [the present, non-volatile memory, digital signal processing]
# [degrees of freedom]
# [fingerprint sensor]
# []
# [the service, distribution network, mobile application]
# [fluorescent light, tungsten lighting]
# []
# []
# [data exchange, data exchange, data exchange]
# [data transmission, point cloud, point cloud]
# [incident angle, incident angle, optical axis]
# []
# [the pitch]
# []
# [Signal Processing, Neural Network, digital signal processing]
# []
# []
# []
# [information processing system]
# [tracking system, have three or more, wireless signals]
# [the system, a vehicle]
# []
# [fingerprint sensor, fingerprint sensor]
# [the image, data extraction, moving image]
# []
# [Image Processing]
# []
# [print job, user information, print job]
# [management system]
# [The present, image processing, image processing]
# [block diagram, the present]
# [electronic device, storage medium, The computer]
# [audio signal processing, A conversion, audio data]
# []
# [PASSENGER TRANSPORT]
# [control unit, coordinate system, control unit]
# [electronic tag, tablet device, electronic tag]
# [the present, the present, the present]
# [dimensional space]
# [The computer, storage medium, the following]
# [light source]
# [electronic device, smart home, smart home]
# [control device, left-hand traffic, control device]
# [the image, the image]
# [steering wheel, up and down]
# [object detection, coordinate transformation, road surface]
# []
# [the present, virtual object, real time]
# []
# []
# [field of view, the image, imaging system]
# [Raw material, pharmaceutical products, raw material]
# [information processing, the present, information processing]
# [electronic control unit, automotive vehicle, a vehicle]
# [object detection, image sensor, image processing]
# [the present, the shapes, road signs]
# []
# [object detection]
# [identity verification, the present, identity verification]
# [electronic device, storage device, storage device]
# [The image, toner cartridge, toner cartridge]
# [mobile system, imaging system, Mobile system]
# [fingerprint recognition, success rate, fingerprint recognition]
# [a vehicle, the following, convolutional neural network]
# [mobile device, tablet computer, information storage]
# [block diagram]
# []
# [the circle, major axis, minor axis]
# []
# []
# []
# [the present, the following]
# []
# [image sensor, point group, point group]
# [computer readable, the system, the system]
# [print media, print media]
# []
# []
# [Structure from Motion, side product, inertial measurement units]
# []
# [near field, near field, near field]
# []
# []
# [packaging box, external device, near field]
# [power management]
# [forensic video]
# [text area]
# []
# [object recognition, unit sphere]
# [mobile network, global navigation satellite system, mobile network]
# [resonance frequency, upper sideband, lower sideband]
# [person in charge]
# [static line, static line, Static line]
# [rotation angle, the present, location information]
# []
# [image quality, the image]
# []
# [number of]
# [digital signature, electronic signature]
# [the image, data conversion, the image]
# [display screen]
# []
# []
# [information processing]
# []
# [face recognition, fill light, infrared light]
# [The present, The present, user experiences]
# [facial expression, facial expression, facial expression]
# [monitor system]
# [image processing, network interface, network interface]
# [The sound, warning sound, The sound]
# [the present]
# [threshold value, threshold value, threshold value]
# [angle of view, aspect ratio, angle of view]
# []
# [neural network, the crack, the crack]
# [Haptic feedback, software components]
# [the score, the normal, threshold value]
# [object detection, computer device, semi-supervised learning]
# [level shifter, level shifter, level shifter]
# []
# [object recognition, object recognition, object recognition]
# [rounded rectangle]
# [the child, field of view, the image]
# []
# [skin condition, skin condition, characteristic value]
# []
# []
# [tracking system]
# [data processing, message authentication code]
# [resonant frequencies, in parallel]
# [online social network, communication channel, online social network]
# [on demand, computer network, the computer]
# [the present, information processing, storage medium]
# [different meaning]
# [the environment, the environment]
# [the image, the image]
# []
# [information display, the present, user interface]
# [focal length, camera center, camera center]
# [the present]
# [readable code, electronic device, electronic device]
# [circuit board]
# []
# [feature detection]
# [Track 2 data, the present]
# []
# [read-only memory, read-only memory, static storage]
# [four elements]
# [rear view camera, up and down]
# [reference point, reference point, reference point]
# [number of, convolution operation, number of]
# [the present]
# [fingerprint recognition]
# [storage medium, electronic device, the button]
# [mobile terminal, the original, mobile terminal]
# [information table, information table, upper limit]
# [coin mechanism, the power]
# [the image, the present, optical device]
# []
# []
# []
# [be incorporated, association table, control device]
# [computing device, traffic light, the height]
# []
# [proximity sensor, mobile terminal]
# [plan view]
# [help manual, help manual]
# []
# [electrical charge, number of, the count]
# [the system, The system, a vehicle]
# [the image, the image]
# [fingerprint sensor, pressure sensor, integrated circuit]
# []
# [The present, image understanding, machine learning]
# [the present, the image, display device]
# [eye tracking, region of interest, the image]
# [the system, display driver, the original]
# [card reader, card reader, transfer roller]
# [user information]
# []
# [position information]
# [straight line, fingerprint identification]
# []
# []
# []
# [The window, the window, The window]
# [distribution network, distribution network, distribution network]
# [a vehicle]
# [user identifier]
# [the system, number of, the system]
# [the present, the image, the image]
# [the image, the order, the order]
# []
# [mobile terminal]
# [reference point]
# [the present, more than, of components]
# []
# [optical character recognition, license plate]
# [The present, video camera, video camera]
# []
# [first dimension, first dimension, passive RFID]
# [fingerprint identification, flexible circuit, flexible circuit]
# []
# [the image, image recognition, results of]
# []
# [display device, display device]
# [image processing, the image, image processing]
# [support vector regression]
# []
# []
# [the present, image segmentation]
# [tracking system, visible light]
# [ignition switch, parking brake, display device]
# [pixel center, pixel center, pixel center]
# []
# [virtual SIM, data storage, data storage]
# []
# [the image, the sound]
# []
# []
# [the present]
# []
# [information processing technology, the image, high speed]
# []
# [the system, the image, coordinate system]
# []
# []
# []
# []
# []
# [electronic control unit, to be decided, a vehicle]
# [the image]
# [The present, recording medium, storage medium]
# [the service, mobile device, service provider]
# [detection threshold]
# [public key certificate, wafer testing, private key]
# [fingerprint sensor]
# []
# []
# []
# [two-dimensional code, two-dimensional code, two-dimensional code]
# [The image]
# [the present, mobile communication, the system]
# []
# [external device, the Internet, cloud server]
# []
# [image reconstruction, image enhancement]
# [physical laws]
# [block diagram, mobile phone, electronic device]
# []
# [road surface]
# [identification number, identification number]
# []
# []
# [gray level, the image, results of]
# []
# [flow rate, refractive index, flow rate]
# [wiring harness, resonance frequency, resonant frequency]
# []
# [the artificial intelligence, the image, the image]
# []
# []
# [data communication, local network, Internet Service Provider]
# [electronic device, the present]
# [The following, cathode ray, liquid crystal display]
# [household robot, household appliance, rechargeable battery]
# []
# [warning system, warning system, self-organizing map]
# [the image, object recognition, the normal]
# [mode of operation, global shutter, The image]
# [unit cell, equal to 2]
# [light sources, data capture, array processing]
# []
# [data model, data type, composite data type]
# [iris recognition]
# [the image]
# [binary image, binary image, binary image]
# [organic dye, pure water, room temperature]
# [electronic device, electronic device, electronic devices]
# [the present, information storage, information storage]
# [magnetic flux density]
# []
# [the present, fire damper, real time]
# []
# [mobile computing device]
# [warning signal, warning signal]
# [the present, machine-readable medium]
# []
# []
# [the image, the image, the present]
# [The present, field of view, the image]
# [translation device, user input, user input]
# []
# [user interface]
# [computer readable, storage medium, computer readable]
# []
# []
# [color difference]
# [the original, second detection]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [a vehicle, driving force, autonomous vehicle]
# [the present, travel drive, control unit]
# [laser scanner, laser scanner, three-dimensional model]
# []
# [software code, the system, desktop computer]
# []
# [region of interest, region of interest]
# [the present, the present]
# [image sensor, the image, image sensor]
# [power supply, power supply, the image]
# [infrared camera, frame rate, the present]
# []
# [motion blur, motion blur, processing mode]
# []
# [mobile phone, power supply, mobile phone]
# [the image, the original, the image]
# [blue light]
# [live broadcast, live broadcast, mobile terminal]
# []
# [the system, the system, the system]
# [the present, wireless communication, road surface]
# [current status, red light, green light]
# [fingerprint sensor]
# [the image, ground truth]
# [block diagram, block diagram, the image]
# [the movement, the movement]
# []
# [permanent magnet, permanent magnet, vertical direction]

# %% [markdown]
# Validation

# %%
LABEL = "TECH"
doc_bin_valid = DocBin() # create a DocBin object
nlp = spacy.blank("en")
# nlp.max_length = 2000000
for training_example  in tqdm(test_lines[:12000]): #~15 patents
    doc = nlp.make_doc(training_example) 
    ents = []
    
    for match_id, start, end in matcher(doc):
        #print(i,"Matched based on lowercase token text:", doc[:10], '::::::::',doc[start:end],start, end)
        span = Span(doc, start, end, label=LABEL)
        #print(span, span.label_)
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)

    filtered_ents = filter_spans(ents)
    print(filtered_ents[:3])
    doc.ents = filtered_ents 
    doc_bin_valid.add(doc)
# Out:
#   0%|          | 0/12000 [00:00<?, ?it/s]
# [one-dimensional array, one-dimensional array, one-dimensional array]
# [display screen, display screen, first generation]
# []
# [communication network, a wireless local area network, Long Term Evolution]
# [mobile device, mobile device, mobile device]
# [image processing, the traffic, second detection]
# [general-purpose computer]
# [the image, topographic map, the image]
# [biometric data, the computer, acquisition process]
# [Network Access, network access]
# [white balance]
# []
# [TRACKING DEVICE]
# [the image, the image, video content]
# [real time]
# [user data, the security]
# [the present, computation time]
# [the present]
# [neural network, input data]
# [the present, electronic device, wireless communication]
# [display device, the image, the image]
# [error message]
# [the present, the cockpit, flight deck]
# [the image, the transition, the image]
# [digital communications, parallel interface, binary number]
# []
# [the plant]
# []
# [mobile phone, mobile phone]
# [data pre-processing, the following, acceleration sensor]
# [focal distance, object type, the image]
# [control unit, red light, road sign]
# []
# [streaming server, separate system, display device]
# []
# []
# []
# [the filter]
# [computing device, number of, personal computer]
# []
# [potential difference, parasitic capacitance]
# [fingerprint sensor, pressure sensor, electronic device]
# []
# [dimensional space, reference surface, reference surface]
# [elevator car, the following]
# [image recognition, state vector, particle filter]
# [the present, electromagnetic waves]
# [image processing, image processing, the image]
# []
# [mobile computing device, user interface, mobile computing device]
# []
# [period of time]
# []
# []
# []
# [the present, number of, number of]
# [The system]
# []
# [image processing, video stream]
# []
# []
# []
# [Thin-Film Transistor, Liquid Crystal Display, Organic Light Emitting Diode]
# [a search]
# [tracking device, the following]
# [computer readable, storage medium, computer programs]
# [light sources]
# [user input, input interface, user input]
# [prior art, prior art, prior art]
# [the present, image processing]
# []
# [the present, the crack, the crack]
# [the following]
# [wind speed, calculated risk]
# []
# [literal language, literal language]
# [control system, the image, stereo camera]
# []
# [solder ball, injection molding, injection molding]
# [The resistance, rectangular wave, straight line]
# [general-purpose computer, dedicated circuit, application-specific integrated circuit]
# []
# [The image, control device]
# [the image, the image, convolutional neural network]
# []
# [packaging material, packaging material, magnetic field]
# [Video camera, the environment, frames per second]
# [number of, number of, the spirit]
# [number of, angular acceleration]
# [component failure, physical object, control theory]
# [floor plan, Image Segmentation]
# [the present, control device, surveillance system]
# []
# [number of, chronological order]
# [display device, POS terminal, display device]
# [object detection, collision avoidance system, vision processing unit]
# [mobile terminal, mobile terminal, mobile terminal]
# []
# []
# [The image, signal value, the filter]
# []
# [The computer, text field, text field]
# [the image, the image, the image]
# [medical image processing, medical image, medical image]
# [surgical navigation, input interface]
# [unit vector, the following, the sphere]
# []
# [focal point, virtual environment, virtual object]
# []
# []
# [multidimensional time, vertical axis, vertical axis]
# [logic block, application-specific integrated circuit]
# [Field of View, Eye Tracking, Laser Speckle]
# [turning radius]
# []
# [program memory, making up]
# [digital conversion, first stage, sense amplifier]
# [The present, the present, the present]
# [upper limit, the following]
# [the present]
# [image information, the image, the human face]
# [test method, test method]
# [hardware acceleration, the present, hardware acceleration]
# [wireless connection, data security]
# [The computer, data processing, the computer]
# []
# []
# [the power]
# [the street, traffic sign]
# []
# []
# [depth map]
# []
# []
# [spatial information, the image, display device]
# []
# [object model, object model, facial expression]
# []
# []
# []
# [the system]
# []
# []
# []
# [vertical position relative, random laser, speckle pattern]
# []
# [the image, image processing]
# [data extraction, natural language processing, data extraction]
# [training ground]
# [block diagram, electronic device, control unit]
# [automated analyzer, mirror mount, mirror mount]
# [BIRD song]
# [object type]
# [electronic device, load balancing]
# [the image, the image, the image]
# [the present, the field, electronic protection]
# [the present, the present, the present]
# [point cloud, parking lot, coordinate system]
# [First pass]
# []
# [the worker, number of, the image]
# []
# []
# []
# [block diagram, I/O interface, I/O interface]
# [geometric transformation]
# [more than]
# [the following, the image, position information]
# [image processing]
# [air conditioner, air conditioner, air conditioner]
# [laser sensor, physical object, stereoscopic image]
# []
# [horizontal plane, azimuth angle]
# [schematic diagram, smart device, schematic diagram]
# [semiconductor memory, information processing, control unit]
# [image sensor, I/O interface, control module]
# []
# []
# [functional block diagram, information management, management method]
# [the present]
# []
# [data signal]
# []
# []
# []
# [depth sensor, high dynamic range, one-way traffic]
# [the present, technological improvements]
# [time tracking, the service, the system]
# [reflected light, control unit]
# [Weather conditions, stray light]
# [ice cream, ice cream, ice cream]
# [overhead view, line of sight, display screen]
# []
# [the owner, image search, digital image]
# []
# [the present, electronic device, electronic device]
# [biometric data, biometric authentication, electronic device]
# []
# [smart card, electromagnetic field, electronic device]
# [in contact, in contact]
# [the present]
# [pattern detection]
# []
# [the image, the present]
# [the system, road marking, the system]
# [signature block, position information, position information]
# [central processing unit, random access, hard disk drive]
# [The system, communication circuit]
# [the present, point in time, Deep Learning]
# [the present]
# [the present, optical device, laser beams]
# []
# []
# [the image]
# []
# [the system, position information, point of interest]
# [the ratio]
# [hard disk, hard disk drive, CD-ROM drive]
# [the original, the filter, transmission medium]
# [road surface, the matrix]
# [the present, electronic device]
# []
# [data transfer, recording medium, recording medium]
# []
# []
# [the image, the image]
# [the present]
# []
# [notification system]
# [The system, control unit]
# []
# [intelligent terminal, intelligent terminal, mobile phones]
# [electronic map, autonomous driving, electronic map]
# [index finger]
# [the present, a vehicle]
# []
# [the system]
# [the image, color vision]
# [communication channel]
# [wireless communication, radio tag, radio tag]
# [embedded processor, central processing unit, memory device]
# [the present]
# [the rescue, fire department, fire department]
# [the image, data management system, the present]
# [optical system, signal processing, optical system]
# [wireless communication, the artificial intelligence, mobile terminal]
# [STEREO CAMERA]
# []
# [game token, game token]
# [touch sensor]
# [convolution operation, the patch, convolution kernel]
# [software component, Component Object Model, software engine]
# []
# []
# [the present, fingerprint sensor]
# [results of]
# [tracking system]
# [results of]
# []
# [the present, the present]
# [element 122, element 122, element 122]
# [user interface, mobile device, user interface]
# []
# [control unit]
# [data transmission]
# [The features, fingerprint sensor, display device]
# [The features, the following]
# [camera sensor, camera sensor, depth camera]
# []
# [game character, ghost car]
# [entropy coding]
# [transfer function, the following]
# []
# [electronic pen, the signal]
# [time series, the worker, the change]
# [number of, radio interference]
# [the present]
# [web-based application]
# []
# [motion data, angular velocity, angular acceleration]
# []
# []
# [user interface, man-machine interface]
# [live view, control unit, live view]
# []
# [eye tracking device, eye tracking device, eye tracking device]
# []
# [the present, the present, automated system]
# [car-pool lane, carpool lane, car-pool lane]
# [the source, flat panel, The x-rays]
# [the image, aircraft body]
# [the present, side wall, side wall]
# [transparent display, transparent display, Thin Film]
# [number of, frequency domain, number of]
# []
# [lane marker, direction of travel, in parallel]
# [fingerprint recognition, the present, mobile terminal]
# [conceptual diagram, the present]
# [sensor array, sensor array]
# [explanatory diagram, information processing, the present]
# [the present]
# [display device, a vehicle, distance sensor]
# [The present]
# [the present, coenzyme A, cluster of differentiation]
# [two-dimensional code]
# []
# [the count, the count]
# [input device, display screen]
# [fingerprint recognition]
# [virtual environment]
# [the present, the system, the system]
# [connected devices, pulse width]
# [block diagram]
# [compressed video]
# [the software, recording medium]
# [digital electronic, computer software, computer program]
# []
# []
# [document processing system, the system, structured document]
# [stream buffer, stream buffer, transport stream]
# [the image]
# []
# [mobile terminal]
# [intelligent terminal, intelligent terminal, intelligent terminal]
# [wireless device, the train, the image]
# []
# [the present]
# []
# [autonomous driving, autonomous vehicle, autonomous vehicle]
# [the image]
# [virtual reality]
# [the present, the present, the present]
# [electronic device, number of, wireless charging]
# [the clock]
# []
# [image quality]
# [brake pedal, brake pedal]
# [touch sensor]
# [the image, the image, the image]
# [wearable device, wearable device]
# []
# []
# []
# [free-viewpoint video]
# []
# []
# [secondary memory, computer programs, computer system]
# [feature extraction, on the road, on the road]
# []
# [global network]
# [the present]
# [the movement, time difference, steering angle]
# [the image, the message]
# [data storage]
# [control unit, information processing]
# []
# [image line, vanishing point, the image]
# [schematic diagram, the present, vertical coordinate]
# [ELECTRONIC TAG]
# [computer readable, data signal, executable code]
# [electronic device, the present, tablet personal computer]
# [the features]
# []
# []
# [the system, HVAC system]
# []
# [moving image, time series]
# [analog-to-digital converter]
# [signature block, signature block, signature block]
# [machine learning algorithm, training data, to be determined]
# []
# []
# [Redistribution Layer]
# [visible light, pass filter, visible light]
# [Digital Signal Processor]
# [information processing, the cloud, information processing]
# []
# []
# []
# [communication network, network interface, network interface]
# [receptive field]
# [route taxi]
# [The image, the image, image processing]
# [electronic device, low resolution, low resolution]
# [password hint]
# [object recognition, object recognition, object recognition]
# [dimension reduction, dimension reduction, dimension reduction]
# [image processing, a conversion]
# [display screen, image gallery, image gallery]
# [the present, the present, digital authentication]
# []
# [external device, external device, electronic device]
# [the present, the present, the master]
# [VIRTUAL REALITY]
# [the present, the image, the image]
# []
# [side wall]
# []
# [The system, storage device, neural network]
# [time-series data, walking speed]
# []
# [composite image, set of data]
# [feature data, feature data, feature data]
# [the environment]
# []
# [The system]
# [electronic device, fingerprint sensor, fingerprint sensor]
# [position information, coordinate system, the image]
# [The system, the image, the image]
# [number of]
# [object detection, the present]
# [the present, the present, the spirit]
# []
# []
# [laser scanner, light emitter, beam of light]
# []
# [control unit, control unit, control unit]
# [computing device, time interval, the image]
# []
# [blind spot monitor, control unit, blind spot]
# [data anonymization, number of]
# []
# [The system]
# [object identification, the movement, the movement]
# [wireless communication, wireless communications, mobile terminal]
# [the window, The window, the window]
# []
# []
# []
# []
# [feature data, feature data, heart rate]
# [the present, safety device, optical unit]
# [near field, mobile terminal, touch panel]
# [luminance value, number of, luminance value]
# [autonomous robot, image analysis, robot motion]
# [the present, the present]
# [main frame, main frame]
# []
# [fingerprint sensor]
# [text segment]
# []
# []
# [template matching, functional unit, template matching]
# [Optical System]
# [vertical axis, the present]
# []
# [vector processing, vector processing unit, vector processing unit]
# []
# []
# [neural network, the features, number of]
# []
# []
# [image sensor, eye tracking, eye tracking]
# [point cloud, by convention, principal axis]
# [image analysis, user interface, training data]
# []
# []
# []
# []
# [head-up display, a vehicle, virtual image]
# [the movement]
# []
# [spatial frequency, signal processing]
# [information processing system]
# []
# [video processor]
# [feature data, feature data, feature data]
# [facial expression]
# [image sensor, computer program, training data]
# []
# []
# [the present, start point]
# []
# []
# []
# [video monitoring, smart home, local storage]
# [the system]
# []
# [blind spot, blind spot]
# []
# [the image, slide glass, slide glass]
# []
# []
# [schematic diagrams]
# []
# [optical sensor, optical sensor, intensity of light]
# [Security Domain]
# [mobile robot, moving on, freedom to]
# [image quality, the image, quality improvement]
# []
# [computer programs, functional units, functional units]
# [The traffic]
# []
# []
# [the present]
# [number of, number of, number of]
# []
# [wireless communication, storage device, storage device]
# [vertical position]
# [the window, time of flight, the image]
# []
# []
# [dialog boxes, BIRD Navigation]
# []
# [The signal, the signal, image units]
# []
# [line width]
# [Data Storage, data storage, mainframe computer]
# []
# [electronic tag, electronic tag, location information]
# []
# [plan view]
# [mobile phones, secure element, secure element]
# [data processing unit, the following, data storage]
# [batch processing]
# []
# []
# []
# []
# [data processing unit, data integration]
# [stereo imaging, stray light]
# [The following, the present, the present]
# [display device, optical image]
# [position information, control unit]
# []
# [human readable, credit card number, human readable]
# [ground truth]
# [mobile terminal, GPS receiver, mobile communication]
# [prior art]
# [identity verification, the service, user data]
# [electronic device, skin type, skin type]
# []
# []
# [Central Processing Unit, Random Access, information processing]
# [call center, single source, call centers]
# [depth of field, depth of field, depth of field]
# [smart terminal, smart home, smart terminal]
# []
# []
# [vice versa]
# [the present, the image, movement mechanism]
# []
# [mobile terminal, display device, flexible display]
# [radio frequency identification, data storage]
# [object class, red traffic light, stop sign]
# []
# []
# [object detection, the image, the image]
# [mobile robot]
# [computer program, the computer, radio signal]
# [convolutional layer, convolutional layer, convolutional layer]
# []
# [recording medium, recording medium, recording medium]
# [the present, threshold value, threshold value]
# []
# [physical properties, number of, thermographic camera]
# []
# [information extraction, the image, the image]
# [millimeter wave]
# [autonomous vehicle, pixel mapping]
# [block diagram, the present, location data]
# []
# [wireless communication]
# []
# [the present, data transmission, data rate]
# [road surface]
# []
# [The image, real time, natural world]
# [The artificial intelligence, the power, mobile terminal]
# [the following, centre of symmetry, line of symmetry]
# []
# [region of interest, region of interest]
# [video signal, video streams, video stream]
# []
# [number of, number of, image quality]
# []
# [the image, data storage, the image]
# [the present, the present, the present]
# []
# [the present]
# [information storage]
# [deep neural network, neural network, hardware acceleration]
# [neural network]
# []
# []
# [time frame, ambient temperature, current time]
# [electronic pen, the signal, electronic tag]
# [the image, smart mirror]
# [spatial coordinates, the image, the image]
# [mobile phones]
# [communication system, electronic equipment, data structure]
# [number of, threshold value]
# []
# []
# []
# []
# [light emitting diode, light emitting diode, light emitting diode]
# [usage data, usage data, usage data]
# [The present, digital information, physical device]
# [electronic device, body measurements, autonomous vehicle]
# [number of]
# [free-viewpoint video]
# [neural networks, Neural Networks, Pattern Recognition]
# []
# []
# [the mirror, the mirror, the mirror]
# [the normal]
# [statistical dispersion]
# [steering wheel, steering wheel]
# []
# []
# [network server, the image]
# [the service, vice versa]
# [the present, parking space, the present]
# [control device, control device]
# [block diagram, electronic device]
# []
# [line of sight, the present, read more]
# [the image]
# [computing device, technological improvements]
# [electronic device, display screen, electronic device]
# [the following, blind spot, lane change]
# [the image]
# [RF module, RF module]
# []
# [resonant frequency, network analyzer]
# [the present, prior art, prior art]
# []
# [Tracking System, Tracking System, Tracking System]
# []
# [the present, packet switched network]
# [image processing, the image, the image]
# []
# [query processing]
# []
# []
# [the present, image segmentation, test image]
# [BIRD navigation]
# []
# [the following, road vehicle, turn signal]
# [removable storage, magnetic disk, optical disk]
# [user input, magnetic stripe, data transmission]
# []
# [control device, mobile terminal, mobile terminal]
# [wireless signals, wireless communication, radio frequency identification]
# [visual odometry, a vehicle, global positioning system]
# [electronic device, circuit board, power supply]
# []
# [straight line, straight line, straight line]
# [software implementation]
# [color difference, the shadow, threshold value]
# [two-dimensional code]
# [results of, decision tree, prediction models]
# [number of, number of, number of]
# [light sources]
# []
# [the image, data processing, time frame]
# []
# []
# []
# []
# [bagging area, handheld scanner, yet another]
# [of components, of components, number of]
# []
# [language model, reinforcement learning, language model]
# [the present]
# []
# [control system, object recognition, object recognition]
# [the image, the image, the image]
# []
# [the image, the image]
# []
# []
# []
# [data processing, the present, schematic diagram]
# [image processing]
# [the present]
# [getting on]
# []
# [training set, validation set, training set]
# [the daily, the image, image conversion]
# [the original]
# [visual line]
# [the present]
# []
# [the present, information processing, information processing]
# [the heart, the change, the heart]
# [longitude and latitude, longitude and latitude, longitude and latitude]
# []
# [two-dimensional code]
# [the security, the security, the security]
# [The system, user interface, user interface]
# []
# [resonant frequency, resonant frequency, resonant frequency]
# [data acquisition, data acquisition, data acquisition]
# [measuring instrument, data processing, the image]
# []
# []
# [display screen, display screen, the image]
# [optical filter, incidence angle, optical filter]
# []
# []
# [fingerprint identification, fingerprint recognition, fingerprint identification]
# [flexible printed circuit, flexible printed circuit]
# []
# []
# [CONTROL DEVICE]
# [The artificial intelligence, facial expression, The artificial intelligence]
# []
# [high dynamic range, depth image, success rate]
# [light source, green light, green light]
# [fingerprint recognition, fingerprint recognition, wall plate]
# []
# [the button, electronic device, biometric authentication]
# [light emitter, mechanical system]
# [electronic ticket, the present, magnetic field]
# [reference data, the image, the image]
# [The image, The image, the image]
# [on the road]
# [Radio Frequency Identification, RFID chip, RFID chip]
# [mobile terminal, the present, mobile terminal]
# []
# []
# [A VEHICLE]
# []
# [light sources, first position]
# [the present, lens array, liquid crystal display]
# []
# []
# [printing system, print job]
# [sound exposure, Fourier analysis, wavelet analysis]
# []
# [information processing, data acquisition, data acquisition]
# []
# [Driver Assistance System, a vehicle, region of interest]
# [results of, the monitor, angle of view]
# [the present]
# [The image, The image, the image]
# [the movement]
# []
# [The image, overlap area, overlap area]
# [the image, the system, fingerprint identification]
# [logic program, the following]
# [semiconductor memory, random access, flash memory]
# []
# [the filter, light sources, light sources]
# [optical sensing]
# []
# [vibrational energy, acoustic energy, impact energy]
# [the present, the traffic, image recognition]
# []
# []
# [electronic map, mobile terminal]
# [number of, the height, threshold value]
# [a vehicle, a vehicle, lane change]
# []
# [yet another, loop antenna, loop antenna]
# [cross section]
# [fingerprint sensor, in contact, adhesive force]
# [computer program, computer program, computer program]
# [mobile phone, real time, real time]
# []
# []
# [the present, the present, the present]
# [heart rate, heart rate, heart rate]
# []
# [reference system, reference system, natural environment]
# [electronic device, electronic device]
# [secondary antibody, Thermo Fisher Scientific, secondary antibody]
# [the button, user interface, user interface]
# [the present, information content, real time]
# []
# [biometric authentication, electronic device, biometric authentication]
# []
# [The present, machine learning, big data analysis]
# [The present, tagging system, the present]
# [electronic device, user interface, user interface]
# [more than]
# [welding power source, welding power source, the present]
# []
# [object recognition, object recognition, traffic signal]
# []
# [schematic diagram, the present, the image]
# []
# [visual recognition]
# [The stage, the image, cell culture]
# [fingerprint sensor, private information, reading messages]
# [electronic pen, wireless communication, registered trademark]
# [more perfect, image information, location information]
# []
# [bright spot, bright spot, flight control]
# [magnetic field, permanent magnets]
# []
# [light barrier, electronic device, light barrier]
# []
# [data processing, data processing, host system]
# [the image, virtual object, the image]
# [the force, second channel, fingerprint recognition]
# [wireless connection, display screen, wireless connection]
# [computer system, The computer, information systems]
# []
# [structural equation]
# []
# []
# []
# [the present, camera module, camera module]
# [the present, fingerprint recognition, fingerprint recognition]
# [the image, the image, projection plane]
# [HTML code, the following, scripting language]
# [user interface, user interface, the image]
# [medical imaging, Positioning System, medical image]
# [user information, user information, user information]
# [mobile robot, storage device, program code]
# [range finder, computer system, the following]
# [Mobile phone, spatial information, wireless devices]
# [contrast agent, the image, principle component analysis]
# []
# [free space, free space]
# []
# [the image]
# [personal information]
# [the order]
# [the present]
# [high resolution, 3D point clouds, neural networks]
# [parking area, the following]
# [facial expression, facial expression, facial expression]
# [more than, the following]
# [weighting function, weighting function, weighting function]
# [schematic diagram, block diagram, block diagram]
# [the following, block size, hand training]
# []
# [system unit, central processing unit, graphics card]
# [the present, received data]
# [threshold value, control module, control module]
# []
# []
# [in contact, the movement, the movement]
# [autonomous vehicle]
# [analog-to-digital converter, executable program, fingerprint recognition]
# []
# [the image, white line, curb stone]
# [management system]
# []
# [computer program]
# []
# []
# []
# [the message, the present, the present]
# [the following]
# []
# [Radio Frequency, digital circuits, international standard]
# [be incorporated, the present, vice versa]
# []
# [external storage device, input interface, secondary storage]
# [The following, number of, age spots]
# [wireless devices, wireless devices]
# [cloud computing, original video, in parallel]
# [the present, elastic scattering, the atmosphere]
# []
# [mobile terminal, fingerprint sensor, piezoelectric actuator]
# [monitoring system, monitoring system]
# [light pipe, light pipe, thermal management]
# []
# [computer graphics, audio content, video content]
# [the present, wireless connection]
# [user interface, user interface, first state]
# [light source, collimated light, collimated light]
# [control unit, the service, the message]
# []
# [the present, a collision]
# [automated threat, the security]
# [virtual reality]
# []
# []
# []
# [electronic device, the present, electronic device]
# [region growing, threshold value]
# [iris recognition, the following, iris recognition]
# [A vehicle, light source, laser light]
# [the present, hardware platform, the present]
# [number of]
# [electronic device, the image]
# [training data, schematic diagram, the present]
# []
# [the image, a search, the image]
# []
# [artificial neural network, artificial neural network]
# [reference document]
# [road surface, cross section, road surface]
# [data communications]
# [data processing, data processing, data storing]
# [the present, prior art, prior art]
# [the counter, the counter, surveillance system]
# [the image, the image]
# [The image, object based]
# [temperature control, the environment, the environment]
# []
# [edge device, on the road, edge device]
# [operating environment, data processing, video streams]
# [low level]
# [text image, text image, text image]
# [number of, number of]
# [The system, the system]
# []
# []
# [the present, threshold value, cluster analysis]
# [computing device, the image, computing device]
# [autonomous driving]
# [Control System]
# [The present, the present]
# [mobile communication, mobile communication, location information]
# []
# [the present]
# [control device, currency tray, the change]
# [wireless power, wireless power, The power]
# []
# [electronic device, electronic device, biometric data]
# [the image, data loading, storage server]
# [feature group, feature group, feature group]
# [development of the Internet, shop online, high security]
# [state change, state change, a vehicle]
# [the present, electronic device, electronic device]
# [data processing, POS terminal, the image]
# [warning sound, the speaker, warning display]
# [Security Tags]
# [video call]
# [remote controller, the voice, the voice]
# [management system, currency tray, currency tray]
# [block diagram, computer system, the present]
# [through holes, through holes]
# [road network]
# []
# [image processing, data management system]
# [the present, the present, the present]
# []
# []
# [the image, the image, the image]
# []
# []
# [the present]
# []
# [cache coherency, cache lines, cache snooping]
# []
# [circular road, the image, the image]
# [differential interference contrast, phase contrast microscope, fluorescence microscope]
# [the system, steering wheel, steering wheel]
# [the present, the present]
# []
# [electronic device, input interface, electronic device]
# [position information, time difference, time difference]
# []
# [reference point, field of view, reference point]
# [number of]
# []
# [program code, program code]
# [a vehicle, a vehicle, image quality]
# [mobile terminal]
# [the present, the present, machine learning]
# [air pressure, air pressure, air pressure]
# [facial recognition, the present, fingerprint scanner]
# [a collision, a collision]
# []
# [hydraulic pump, hydraulic oil, control valve]
# [word boundary, word boundary, word boundary]
# []
# []
# [the present, N terminal, voltage difference]
# [the present, readable code]
# [number of, sensor array]
# [mobile robot, control module, control unit]
# [confidence interval, number of]
# [wireless network, communication link, communication link]
# [character recognition, character recognition]
# [network model, network model, number of]
# [yet another, the present]
# [number of, remote control]
# [the present, the order, the present]
# []
# [information processing]
# [operating system]
# [the present, color correction, spectral sensitivity]
# [fingerprint sensor, NMOS transistor, NMOS transistor]
# [The present, display screen, image sensor]
# []
# [the present]
# [control unit, field of view]
# [the present, program code, electronic device]
# [period of time]
# [signal processing, the environment]
# [video streaming, high quality, video content]
# [The change, the change, the change]
# [the present]
# [training data, training data, the image]
# [the present, input box, input box]
# []
# []
# [dialog box, data sharing]
# [more than, the matrix]
# [to be determined]
# [number of, data processing unit, reference data]
# [executable code, the following]
# [control data]
# [the present, the present, the following]
# []
# []
# [the present, the window]
# []
# [fingerprint sensor]
# []
# []
# [electric motor, electronic speed controller, rotor aircraft]
# [a vehicle, monitor system, the following]
# [cell phone, cell phone, cell phone]
# []
# []
# [The present, the following]
# [distance sensor, control device, distance sensor]
# []
# []
# [thermal radiation, thermal radiation, thermal radiation]
# [the present, mobile terminal, mobile terminal]
# [character recognition, character recognition, state transition]
# [white balance, storage medium, Automatic White Balance]
# []
# [one piece, control unit, one piece]
# [heart rate, heart rate, heart rate]
# [the environment]
# []
# []
# [computer program, training data set, neural network]
# [fingerprint sensor, motion sensor, motion data]
# [data conversion, data format]
# []
# []
# [computer program, computer program, computer storage media]
# [electronic device, external device, external device]
# [virtual reality]
# [photo sensor, photo sensor, scanning line]
# [dialog box]
# [image processing]
# []
# []
# [facial expression]
# []
# [artificial intelligence, volumetric reconstruction]
# [the present, the original, the original]
# [control unit, control unit, control unit]
# []
# [the entry, type of gesture]
# []
# [the breast]
# [electronic tag, signal strength, the signal]
# [the present]
# []
# [popup window, start screen, popup window]
# [system administrator]
# []
# []
# [optical fiber, schematic diagram, decision tree]
# []
# [autonomous driving]
# [pressure sensor, the environment]
# [touch panel, stereoscopic image, light interference]
# [control unit, flow of control, the image]
# [field of vision, a vehicle]
# []
# [camera module, camera module, camera module]
# []
# []
# []
# [the image]
# [electronic device, fingerprint sensor, fingerprint sensor]
# [block diagram, weather conditions, program code]
# [the present, data management, data management]
# []
# [travel lane, lane change, travel lane]
# [software components]
# [user interface control, getting on, the image]
# [the system]
# [driver assistance system, visual appearance, the static]
# [face detection, in parallel]
# [Hierarchical Structure]
# [the present]
# []
# []
# [The traffic]
# [The image]
# []
# [branch points]
# []
# [the present]
# [video processing unit]
# [mobile terminal, mobile terminal, the present]
# [feedback loop]
# [in parallel, computing device]
# [point cloud data]
# [blind spot, blind spot]
# []
# [Computing resource, personal computers, workstation computers]
# [wide-angle lens]
# [computer program code, computer readable, executable code]
# [the present, electronic device]
# [second case, number of, number of]
# []
# [rule extraction, read code]
# [reference dataset]
# []
# []
# []
# [gas stations, the system, gas station]
# [display device, flexible substrate, adhesive tape]
# []
# [electronic device, mobile communications]
# [control unit, control unit, control unit]
# [power supply unit, power supply unit, wireless power]
# []
# []
# []
# [Chinese characters, state transition, state transition]
# [The system]
# [network interface, The image, the image]
# [single instance, the order]
# []
# []
# [electrical power, power source, lever arm]
# [video signal, video signal]
# [the following, copyright library, copyright library]
# [box filter, location information]
# [The traffic, the traffic]
# [electronic device, multifunction device, electronic device]
# []
# [knowledge acquisition, machine learning, flight dynamics]
# []
# [the present, English letters, English letters]
# [data acquisition, The owner, data acquisition]
# [results of, training set, validation set]
# [facial recognition, the image, structured data]
# [The following]
# [data type, extensible markup language]
# [single user]
# [slot antenna, feed line, ground plane]
# [the system, coordinate system]
# [fingerprint sensor, low level]
# [two-dimensional code, a square]
# [scanned image]
# [the image, image information, game console]
# []
# []
# [self-organizing map]
# [vertical direction]
# [the following, the following, lane change]
# [two-dimensional code, feature detection, two-dimensional code]
# [frame rate, compression ratio]
# [medical image, medical image, region of interest]
# []
# [the present, electronic device, electronic device]
# [the present, the following, the present]
# [light source, light guide plate, degree of freedom]
# [mobile terminal, control unit, control unit]
# []
# [hard disk, magnetic disk, optical disk]
# [surveillance cameras, the security, the security]
# [the following]
# [genetic code, manual time, cell culture]
# []
# [the normal, the normal, the normal]
# [Communication controller, secure communication, communication controller]
# [the field]
# [computer program, driver monitoring system, the computer]
# [the following]
# [control unit, recording medium, recording medium]
# []
# [the present, user information, the security]
# [mobile terminal, mobile terminal, user interface]
# [a search, Natural Language Processing, more than]
# []
# [infrared light, infrared light]
# [electronic device]
# [code generation, code generation]
# [electronic device, feature recognition, electronic device]
# []
# []
# []
# []
# [point cloud, point cloud, point cloud data]
# []
# [the image, input interface, wireless transmission]
# [a vehicle, the present]
# [the present, occupancy grid, occupancy grid]
# [the present, computer storage]
# [schematic diagram]
# [the present, optical chip, the present]
# [User Interface Specification, Image Recognition, NEC Corporation]
# []
# []
# [single user]
# [Department of Energy]
# [two-dimensional code, two-dimensional code, two-dimensional code]
# [motor vehicle]
# []
# [the present, traffic rules, number of]
# [the image]
# [gradient vector, the present]
# [information processing, explanatory diagram, information processing]
# [cooling system, one piece, the present]
# [the power, the power, the power]
# []
# [number of]
# [the image, data classification, fault detection]
# []
# [the present, the present]
# []
# []
# []
# [electrical circuit]
# []
# []
# [wearable device, license plate, the image]
# []
# []
# [FLEX CIRCUITS, SURGICAL INSTRUMENT, SURGICAL INSTRUMENT]
# [The computer]
# [the image]
# []
# [the present, audio signal, the present]
# []
# []
# [electronic device, display device]
# []
# [surveillance camera, Infrared Ray, surveillance camera]
# [positioning system, GPS system, position information]
# [usage data, environmental conditions, usage data]
# []
# [training data set]
# []
# [deep learning, network model, convolutional layer]
# []
# []
# [The flash, the flash]
# [input and output, transition probability, POS terminal]
# [external device]
# [light source]
# []
# [access point, access point]
# [wireless connection]
# []
# [number of, number of, number of]
# []
# [the present, air quality, air purifier]
# []
# []
# []
# []
# [error message]
# [object recognition, pattern matching]
# []
# []
# [inkjet printer, memory device, print media]
# []
# [The system, the signal, the signal]
# []
# [specific area, specific area]
# [stereo camera, digital image, digital image]
# []
# []
# [information processor, input data, information processor]
# [the present, mobile device, motion sensor]
# [stereo camera, field of view, stereo images]
# [ultraviolet light, ultraviolet light, the present]
# [stereo camera]
# [The artificial intelligence, mobile terminal, remote control]
# []
# []
# [communication circuit, object identification, electric power]
# [the image, number of, aspect ratio]
# [the image, neural network, neural network]
# [the field, processing technologies, data processing]
# [electrical signal, image processor, electrical signal]
# []
# [electronic device, electronic device, electronic device]
# [luminance value, brightness value, brightness value]
# [object detection, object detection]
# []
# []
# []
# []
# []
# [current time, the image]
# [side wall, electronic tag, ultrasonic welding]
# [Computer system, random access, dynamic storage]
# [the image, halftone process, time loss]
# []
# []
# []
# []
# []
# [digital device, radio interference, digital device]
# [name card]
# [number of, gaming chip, number of]
# []
# []
# []
# [the present, capacitive sensing, capacitive sensing]
# [motion video, image processing, image processing]
# [intelligent terminal, intelligent terminal, intelligent terminal]
# [lane line, lane line, winding road]
# []
# [geometric optics, optical aberration, single camera]
# [The system, digital camera]
# []
# []
# [free space, light sources, the train]
# [The present, high resolution]
# [input device, input device, display device]
# [supervised machine learning, supervised machine learning, training data]
# [medical images]
# [dot matrix, dot matrix, dot matrix]
# [information processing, information processing, video signal]
# [face width, face width]
# []
# [electronic identification, high frequency]
# []
# [feature group, feature group, feature group]
# [the system]
# []
# []
# [the present, the present, monitoring system]
# [block diagram, electronic device]
# [the present, second processor, second processor]
# []
# []
# [computer system, the present, the present]
# []
# []
# [wireless device, the image, the image]
# [ambient sound, ambient sound]
# [block diagram, flow graph, a vehicle]
# []
# []
# [computing device, computing device, data anonymization]
# [the present, the features, screen door]
# [number of]
# []
# []
# [cell determination]
# []
# []
# [The image, the image, dark object]
# [position information, position information, position information]
# [the score]
# [display device]
# [computer storage media, computer program, storage media]
# [smart home, smart window, the following]
# []
# []
# [computer readable, the present, the present]
# [display device, acceleration sensor]
# [time series]
# []
# [image information, the image, number of]
# [neural network]
# [road signs, road furniture]
# [for every]
# [embedded system, mobile terminal, navigation system]
# []
# [The system]
# [hierarchical structure, hierarchical structure]
# [the present, visual recognition]
# []
# [digital signal processor, graphics processing unit, vector processor]
# [in parallel]
# [the image, facial expression, user information]
# []
# [image analysis]
# []
# [shortest path, shortest path, shortest path]
# []
# [electronic device, electronic device, electronic device]
# [the image, The image, exposure time]
# [the image]
# []
# [the image]
# []
# [mobile terminal]
# [out of focus, the image]
# [high resolution, digital camera, document identifier]
# []
# []
# [one camera, one camera, digital image sensor]
# [fingerprint identification, power supply, floating ground]
# [the image, the Sentinel, number of]
# []
# [the following]
# [the present]
# [FINGERPRINT SENSOR]
# [the present, feature data, the heart]
# []
# [wireless power, printed circuit board]
# [position and orientation, head tracking, eye tracking]
# []
# [facial expression, facial expression, information processing]
# []
# [electronic device, electronic device, electronic device]
# [the present, gaming chip, gaming chip]
# [operating system, input data, input data]
# [the present, the present]
# [the present, reading speed]
# [the movement, the movement, the movement]
# []
# [personal information]
# [computer readable, storage medium, the computer]
# [the present, information storage, the present]
# [the system]
# [light emission, Light emission]
# [the movement, number of, the movement]
# [user interface, the cause]
# [input device]
# [user interface]
# [the present, printed circuit board, screen printer]
# [non-volatile memory, volatile memory, Hard Disk Drive]
# [LED light, light source]
# []
# [INFRARED LIGHT, ELECTRONIC DEVICE]
# [making up, electronic pen, state estimation]
# [Texas Red, melamine resin, room temperature]
# [first position, second position]
# [number of]
# [the present, acute angle]
# []
# [information processing, information processing]
# [input device, electronic pen, touch panel]
# [object detection]
# []
# [electronic device]
# [the present, The system, electrical signal]
# [background noise]
# [first position, second position, first position]
# [monitoring system, pressure sensor, signal processing]
# [user information]
# [the greatest, 360 degrees]
# [the present, the following]
# [the image]
# [shape changing, shape changing]
# [schematic diagram]
# [the environment, real time, the system]
# []
# [video surveillance, control device, video surveillance]
# []
# [time series forecasting]
# [training data, training data, training data]
# []
# [external device, parking lot]
# []
# [physical system, physical system, similarity measure]
# [binary number, binary data]
# []
# [user interface]
# []
# [facial expression, facial expression, facial expression]
# [the following]
# [The present]
# []
# [convolutional layer, number of, single output]
# []
# [information processing, running out]
# [the envelope]
# [road surface]
# [visual feedback, the system, welding arc]
# [electronic signature]
# [magnetic storage, hard disk drive, storage device]
# [the present]
# [recording medium, hard disk, floppy disk]
# []
# [the original, image processing, the original]
# []
# [object based, the alarm, association table]
# [the explanation, the power]
# [hour meter]
# []
# [control module, control module, user input]
# []
# []
# [number of]
# []
# [store data, learning machine]
# [thin film, thin film]
# []
# [the annual]
# []
# [beam pattern, repetition rate]
# []
# [the present, service robot]
# [display device]
# []
# [threshold value, threshold value]
# []
# [machine learning, machine learning]
# [the image, right lane, the image]
# [prior art, road sign, prior art]
# [image processing, number of, the image]
# [the image, the image]
# []
# [biometric identification, circuit board, biometric identification]
# [tracking device]
# []
# [compressed air, compressed air]
# [user interface, user interface, user interface]
# [mobile computing device, neural network, neural network]
# [magnetic stripe]
# [light source, electromagnetic wave, spatial light modulator]
# [location information, rotation angle, rotation angle]
# []
# [sequence of events, sequence graph, the image]
# [block diagram]
# [Euclidian distance]
# [The computer, clinical decision support]
# [The image, electric charge, electric charge]
# []
# [The system]
# []
# [block diagram, mobile terminal, the present]
# []
# [computer readable, computer program]
# [information analysis]
# [The present, wired communication, wired communication]
# [the system, vehicle manufacturer, advertising revenue]
# [autonomous vehicle]
# []
# []
# [real time, transportation systems, computer vision systems]
# [the image, the normal]
# []
# [block diagram, display device, display device]
# []
# [vertical line]
# [acoustic model]
# [electric current]
# [coordinate transformations]
# [The present, the present, the following]
# []
# [control operation, control operation, smart home]
# []
# []
# [electronic device, electronic device, smart card]
# [electronic hardware, computer software, the software]
# [fingerprint recognition, fingerprint recognition, the present]
# [the present, first data, first data]
# []
# [vertical direction]
# [the present, the environment, The system]
# [the present]
# [empty space, information processing, dialog box]
# [field of view, the field]
# [mobile terminal, face recognition, face recognition]
# [mobile terminal, mobile terminal, mobile terminal]
# [infrared light, optical path, infrared light]
# [element 111, element 111, element 111]
# [camera interface, input device, input device]
# [the present]
# [security system, more than]
# [block diagram, mobile terminal, the present]
# [the original, personal information, the original]
# [the present]
# []
# [video call, facial expression]
# [the environment, new production, body surface]
# [The present]
# [the Future]
# [HEART MUSCLE, COMPUTER PROGRAMS]
# []
# [optical character recognition, the spirit]
# [the present]
# [object detection, a vehicle, a vehicle]
# []
# [the system, control unit, the image]
# []
# [the present, display device, display device]
# [the image]
# []
# [prior art, magnetic resonance imaging, myocardial infarction]
# [the order, color chart]
# [The present]
# []
# []
# [fingerprint sensor, fingerprint sensor, touch sensor]
# [digital electronic, computer software, computer program]
# []
# [more than, electronic device, more than]
# [DC offset, high-pass filter]
# [external device, external device, wired communication]
# []
# [camera module, still image, moving images]
# [the present]
# [The system, license plate]
# [display device, pressure-sensitive adhesive, Young's modulus]
# [print media, corrective actions, corrective action]
# [optical character recognition, the image, the image]
# [fingerprint recognition, display type, mobile terminal]
# [number of, improve sensitivity]
# [parallel computation, high speed, number of]
# [stray light, stray light]
# [the present, electronic device]
# []
# []
# []
# [point cloud, point cloud, high resolution]
# [side wall]
# [image information, image information]
# [lane line, optical axis, the original]
# [real time, LED light]
# []
# []
# [electronic device, external device, external device]
# [computing device, ray tracing, the image]
# []
# []
# [road construction, the present]
# [scan line]
# [acceleration sensor]
# []
# [angular resolution, incident angle, the image]
# [the following]
# []
# []
# [Batch normalization, data augmentation, batch normalization]
# [electronic device, electronic device]
# [the present]
# []
# [cooking utensil, the present, long grain]
# [control device]
# [the environment, the environment, the environment]
# [the voice, threshold value, threshold value]
# [yet another, camera system, camera system]
# [the robots, storage device, the environment]
# []
# [traffic system, the traffic, the traffic]
# []
# [information analysis]
# [user information]
# [mobile device, electronic device, mobile device]
# [image processing]
# []
# [air conditioner, more than, air conditioning units]
# [number of]
# [display device, the image, laser beams]
# [video signal, the image, noise reduction]
# [the following]
# []
# [code generation]
# []
# [the present, function key, fingerprint sensor]
# [mathematical model]
# []
# []
# [electronic device, electronic device, progress indicator]
# [intelligent terminal, the computer, the following]
# [tracking system, tracking device, optical sensing]
# [The present]
# [the image, the image, image information]
# [more than, number of, more than]
# [optical communication, external device, optical communication]
# [relative speed, relative speed]
# []
# [recording medium, the order, the image]
# [information processing, information processing, information processing]
# [functional model, the order, ground truth]
# [the following]
# [control unit, central processing unit, semiconductor memory]
# [geometric transformation, geometric transformation, geometric transformation]
# [data selector, data selector, the image]
# [the present, data mining, the security]
# [plan view]
# []
# [RFID chip, RFID chip, semiconductor material]
# [connecting rod]
# [electronic tag, electronic pen, electronic pen]
# [binary data]
# [the present]
# [the message, the voice]
# []
# [non-volatile memory]
# []
# [a vehicle, a vehicle]
# [the following, Touch Sensitive, Touch Sensitive]
# []
# [reference data, reference data, threshold value]
# []
# []
# [location data]
# []
# [fingerprint recognition, the button, still pictures]
# [autonomous vehicle]
# [position information, audio processing, the signal]
# [location information]
# []
# [the image]
# []
# []
# [the present, the present, Young's modulus]
# [physical interaction]
# []
# []
# [instruction set, storage medium, number of]
# [high-performance computing]
# []
# [RF signal]
# [electronic device, image quality]
# []
# [first light, specularly reflected, glossy display]
# []
# [AUTONOMOUS VEHICLE]
# [The features, the present, the following]
# [training data, the image, image information]
# [desktop computer, notebook computer, tablet computer]
# []
# [field-programmable gate array, integrated circuit, storage medium]
# []
# []
# [check boxes]
# []
# [display terminal]
# []
# [The image, The image, the height]
# []
# []
# [The present, computer program]
# [image processing, block diagram, image processing]
# [information processing, the present, display device]
# [information processing]
# []
# [silicon nitride, silicon oxide, silicon oxynitride]
# []
# []
# []
# [mobile device]
# [object recognition]
# []
# [control unit]
# []
# [rotation speed]
# [rotation matrix, least squares method]
# []
# []
# [first light, light source, the present]
# []
# [generative adversarial network]
# [angular velocity, angular acceleration, results of]
# [electric power, secondary battery, electric power]
# []
# [light source, light source]
# [blood pressure, systolic blood pressure, systolic blood pressure]
# [information storage]
# ...
# [number of, number of]
# [video surveillance, the image, the image]
# [data acquisition, data acquisition, data acquisition]
# [number of]
# [control module, control module, user input]
# [the present]
# [HTML code, scripting language, scripting language]
# []
# [the present, medical image]
# []
# [invisible ink, the present, inkjet printing]
# []
# [pulse width, duty cycle, duty cycle]
# [yet another, computer program, computer readable]
# [number of, number of, number of]
# [soft keyboards]
# []
# [data store, data store, training data]
# []
# []
# []
# [mobile terminal]
# []
# [AUTOMATED DRIVING SYSTEM]
# [video monitor, monitoring system]
# [the field, image processing]
# [navigation system]
# []
# [start button, the original, control unit]
# []
# []
# [optical system, the image, view angle]
# [computer vision, machine learning]
# []
# [the alarm, threshold value, threshold value]
# [the present, electronic device, the power]
# [steering wheel, second position, steering wheel]
# []
# [control device, control device]
# [the Internet, information sharing]
# [electronic device, electronic device, electronic device]
# [user input, the movement, user interface]
# [body posture, line of sight]
# []
# []
# [computer program, computer program, computer storage media]
# [the present]
# [acknowledgement of receipt, acknowledgement of receipt, computing device]
# [the present, Control loop, upper limit]
# [the image, the image, the image]
# [electronic device, input interface, input interface]
# []
# []
# [number of, number of, number of]
# []
# []
# [the present]
# [a vehicle, image plane, the image]
# [the present, the present]
# []
# [measurement unit]
# [the present]
# []
# [threshold value, luminance value, luminance value]
# [mobile terminal, proximity sensor]
# []
# []
# []
# [card reader, card reader, electric current]
# [optical system, phase contrast microscope, the image]
# [the field, energy saving, mobile telephones]
# []
# [information processing, wireless router, information processing]
# [second difference]
# [communications network, the Internet]
# []
# []
# [number of, laser scanner, laser scanner]
# [barcode reader, barcode reader, barcode reader]
# []
# [from the outside]
# [optical fiber]
# []
# []
# [MOTOR VEHICLE]
# []
# [movement control, the image, optical system]
# [high resolution, the image, high resolution]
# []
# [low dynamic range, high dynamic range]
# [rotation axis, rotation axis, rotation axis]
# []
# []
# [computer system, The system, storage medium]
# [The present, imaging system]
# [a vehicle, a vehicle]
# [the present, driver's seat]
# [second stage]
# [control device, electrically driven, hybrid vehicle]
# [mechanical engineering]
# []
# [first light]
# []
# [average distance, average distance]
# [electronic device, the present, electronic device]
# [the movement, the movement]
# [control module, foot traffic, foot traffic]
# []
# [COMPUTER PROGRAM]
# []
# [the monitor]
# [external memory, storage device, storage device]
# [field of view]
# [functional block diagram, object detection, object detection]
# [user information, user information, user information]
# []
# [information device, information device, information device]
# [physical environment, onboard camera, field of view]
# [average speed, spatial audio]
# [reprojection error]
# []
# [the general, mobile terminal, mobile terminal]
# [mobile robot]
# [control unit]
# [electronic circuit, the image, mobile device]
# [ground truth, types of road]
# [3D display, 3D monitor, surgical navigation]
# []
# []
# [The present, results of]
# []
# [point cloud, point cloud]
# [travel lane, travel lane, a vehicle]
# []
# [color image, binary image, color image]
# [threat assessment, threat assessment, the present]
# []
# [the present, communication network, the Internet]
# []
# []
# [ground truth, ground truth, ground truth]
# []
# [mobile terminal, the present, fingerprint sensor]
# [plate electrode, plate electrode, plate electrode]
# [virtual space, number of, virtual space]
# [feature detection]
# [mobile device, mobile device, input interface]
# []
# [focal distance, array camera, array camera]
# [frontal area]
# [the present, optical sensing, feature detection]
# [processing power]
# [the arrow]
# [in parallel, elevator car, dimensional space]
# [the order]
# [plain text]
# [two-dimensional code, the following, two-dimensional code]
# []
# [data storage device, training data set]
# [flat panel, head-up display, display device]
# [RF module, integrated circuit, conductive trace]
# [Computer system, the computer, network interface]
# [fingerprint authentication, user interface]
# [neural network, neural network, adaptive machine learning]
# [number of, the Internet, number of]
# [reflected light, white light, from the top]
# []
# []
# []
# [heart rate, heart rate, heart rate]
# [The computer, laser scanner, laser scanner]
# [mobile robot, mobile robot, mobile robot]
# []
# [network device, traffic flow, network device]
# [data processing, message authentication code, session key]
# []
# [fingerprint sensor, fingerprint detection]
# [the entry]
# [mobile robot, base station, location information]
# [training data, machine learning model, Convolutional Neural Network]
# [fixed point]
# [monitoring system]
# []
# []
# []
# [The window, the window, The window]
# [the original, the original, the original]
# [parameter estimation, three-dimensional model, coordinate system]
# [registered user, registered user, registered user]
# [query processing]
# [fingerprint recognition]
# [linear least squares]
# [the heart, the heart, heart rate]
# [the image, object type]
# [electromagnetic field, vertical axis, vertical axis]
# [ANOMALY DETECTION]
# []
# [fingerprint sensor]
# [Information processing, The present, information processing]
# []
# []
# [the present, drowsiness detection system]
# [the present, processing power]
# [storage device, machine-readable medium, data structures]
# [the library]
# [The present, dot matrix]
# []
# [semantic analysis, latent semantic analysis]
# [field of view, angle of view, angle of view]
# [the system]
# []
# [threshold value, road surface]
# [near field, wireless communication]
# [Kalman Filter, Particle Filter, real time]
# [character recognition, character recognition]
# [payment system, electronic device, POS terminal]
# [human-machine interface, dialog window, communication system]
# [data storage, mobile terminal, data storage]
# [aspect ratio, the change, aspect ratio]
# []
# [the monitor]
# [Laser marking, laser marking, the order]
# [the computer]
# [information processing]
# [floor plan]
# [electromagnetic induction, radio wave]
# [virtual environment, a collision]
# [A/D converter, signal generator, light emitter]
# [the present, the present, the present]
# [the present, the present, the present]
# [training method]
# []
# [display device, blood circulation, number of]
# [the present, the spirit, the present]
# [unit cell, unit cell, unit cell]
# [electrical signal, depth map]
# [threshold value, the image]
# [mobile terminal]
# [The present, the present, the present]
# []
# [real object, real space, by extension]
# [the express, for any reason, electronic device]
# [side wall, in contact, mobile terminal]
# []
# [The image, number of, ascending order]
# [dimensional space, the original, multidimensional time]
# [optical system, optical system, optical system]
# [transfer station, in the Mix]
# []
# [information storage, wavelet transform, machine learning]
# [the sound, audio processing, audio signal]
# []
# [facial expression, facial expression, facial expression]
# [fingerprint sensor, the present, fingerprint sensor]
# []
# []
# [Electronic Control Unit]
# [the future, number of]
# [information processing, information processing, image information]
# []
# [visible light]
# [video file, security system]
# [autonomous vehicle, autonomous vehicle, point cloud]
# [the following]
# []
# [blind spot, blind spot, blind spot]
# [FAX number, data transfer, electronic mail]
# [signal strength, signal strength, mobile computing device]
# [The present, the general]
# [through the line, number of]
# [block diagram, hand held]
# [IMAGE RECOGNITION]
# [mobile phone]
# [dynamic range, HDR images]
# [the present, electronic device]
# [fingerprint sensor, function key]
# [the image, field of view, the image]
# []
# []
# [start point, signature block]
# [vertical axis, the system, the system]
# [reference data, the image, the image]
# []
# [refractive index, flow rate, refractive index]
# [the traffic, traffic light, the image]
# []
# [focal length, focal length]
# [the human face]
# [vertical direction, vertical direction, horizontal direction]
# []
# [road surface, road surface, start point]
# [the present, the present]
# [the present, computer readable, text segment]
# [machine learning, deep learning, machine learning]
# [Security Domain]
# []
# [pattern detection]
# []
# [two-dimensional code]
# [schematic diagram, the present, lane line]
# []
# [information content]
# [feature extraction]
# [position information, the traffic, position information]
# []
# [the image, IR radiation]
# [mobile terminal, the present, mobile terminal]
# [key generation, process variation, threshold value]
# [external force, frictional force, external force]
# [information processing, position information]
# [the following, the present, eye tracking]
# []
# [image processing, the image, The image]
# [hard disk, communications system, vendor neutral archive]
# [electrical connection]
# [the present, number of, the image]
# []
# [first difference, first difference]
# []
# [input and output]
# [the system, the image, the image]
# [parking space]
# [number of, wave frequency, wave frequency]
# [the image]
# [volatile storage, POS terminal, display device]
# []
# [storage device, registered trademark, Secure Digital]
# [state estimation]
# [information processing]
# []
# [face recognition]
# []
# [angle measurement, graphics processors, the height]
# [mobile terminal, liquid crystal display, organic light-emitting diode]
# [personal information, personal information, personal information]
# []
# [X-ray detector, data transmission, power supply]
# []
# []
# [BIRD song]
# [the present, data extraction, moving image]
# [navigation system]
# []
# []
# [The present, magnetic stripe, the present]
# []
# [The system, The system, computer vision]
# [information storage]
# []
# []
# [the original]
# []
# [number of, number of, the system]
# []
# []
# [mobile phone, mobile phone, mobile phone]
# []
# [feature detection, the features]
# []
# [side wall, side wall, fingerprint identification]
# [object recognition, Neural Network, deep learning]
# [the present, polyethylene terephthalate]
# [the following]
# [region of interest]
# []
# [image processing, a vehicle, The image]
# [of components, electronic device, external device]
# []
# [the present]
# [Inverse reinforcement learning]
# [storage medium, autonomous vehicle, The image]
# [external device, external device]
# [Open Patent]
# []
# [analog signal, digital signal, analog signal]
# []
# [local storage, security key]
# [The present, computer readable, storage medium]
# []
# [on the road]
# []
# []
# []
# [infrared light, infrared light, infrared light]
# [the image]
# [biometric authentication, biometric authentication, electronic device]
# [the present, the present, electronic device]
# [number of, the image, contrast enhancement]
# []
# [mobile terminal, facial expression, display screen]
# [light emitter, mechanical system, light emitter]
# [sound system]
# [control unit, block diagram]
# [the advent, digital file, visual effects]
# [convolutional layer, input data, The following]
# [mobile robot, mobile robot, mobile robot]
# [The present, the movement]
# [the present]
# []
# [fingerprint identification]
# [Object Recognition]
# [traffic signal, traffic control, traffic management]
# [heat transfer, heat insulation, heat insulation]
# []
# [image processing, image processing]
# []
# []
# [computer program]
# [The image, the image]
# []
# [Control Device, User Interface]
# [location data]
# [background color, background color, background color]
# []
# [the image, high speed]
# [elevator control, call signal, call signal]
# [level shift, first shift, high voltage]
# []
# [the sound]
# [video streams, video encoder, field of view]
# [local storage, data loss, storage device]
# [the power]
# [image processing, the image]
# [road surface, road surface]
# [The following, electronic device, electronic device]
# [yet another, the traffic]
# []
# [point cloud, laser sensor, point cloud]
# [The image, road surface, the image]
# [control device]
# [dimensional space, probability density function, anomaly detection]
# [image element, image element, the image]
# []
# []
# [the general, the general, the general]
# [neural network]
# [Kalman filter, The filter, Horizontal position]
# [vice versa]
# []
# []
# []
# []
# []
# [time signal]
# []
# [not found, not found]
# [audio data, moving picture, moving picture]
# [the image, the image, the image]
# [number of, the environment, computing device]
# [the crown, the crown]
# [glass sheet, glass sheet, number of]
# [the present, the present, the present]
# []
# [electronic device, image sensor, fingerprint authentication]
# [coordinate system]
# [the filter, the filter, the filter]
# [neural net, user information, associative memory]
# [video production, Internet video]
# [Low level]
# []
# [region of interest, region of interest, region of interest]
# []
# [electronic device, the button, home button]
# [flow cytometry, polymerase chain reaction]
# [the present, the movement, the image]
# [the security, the security, the security]
# [automatic parking]
# [Computing device, extrinsic parameters, intrinsic parameters]
# [microelectromechanical system, magnetic sensor, computer readable]
# [visible light, visible light]
# [number of, number of, current time]
# [the following, traffic light, the traffic]
# []
# []
# [ultrasonic sensor, infrared sensor]
# [The image, measurement system, light emission]
# [license plate, the image, license plate]
# [system model, data model]
# []
# [the present, information processing, information processing]
# [direction of travel]
# [object recognition]
# [touch panel]
# [control device]
# [information processing, information processing]
# [the image, the signal]
# [control unit]
# [number of]
# [the present, the image, the image]
# [light source]
# [management information]
# [two-dimensional code]
# [second duration]
# []
# [measurement device, the computer, a vehicle]
# [image forming device, control unit, image forming device]
# [loss function]
# [artificial neural network, autonomous vehicle, autonomous vehicle]
# [the security, the security, the security]
# []
# [The present, claims the priority, Intellectual Property]
# [rounded corner, a square, the circle]
# []
# [schematic diagram, mobile terminal, the present]
# [life sciences, two dimensional]
# [content delivery network]
# [operating system]
# [optical character recognition, vertical line, vertical line]
# [the image, the following, the image]
# [electronic device, mobile payment, electronic device]
# [an equation, the image, the image]
# []
# [management system, information processing, information processing]
# [the image, tail light, street light]
# [the image]
# [direction of travel]
# []
# [display device, center console, center console]
# [the score, census transform]
# [the heart]
# [The present]
# [image processing, the image, stereo camera]
# [the image]
# []
# [I/O Interface, I/O interface, engineering drawings]
# [cooling system, the Internet, physical environment]
# [electronic device]
# []
# []
# []
# []
# [image element, video frame, image element]
# [communications system]
# [mobile device, hardware logic, graphics processor]
# [object recognition]
# []
# [the movement]
# []
# []
# []
# [the following]
# [computer system, computer systems, computer systems]
# [light reflection, the image, the image]
# [user information, user information, the image]
# [computer program, a vehicle, start point]
# [The image]
# []
# [mobile device, the environment]
# [location information, true North, data storage]
# []
# [obstacle avoidance, obstacle avoidance]
# [the present]
# [the present, software component]
# [electronic device, storage medium]
# [Computing device, storage device, storage device]
# [functional block diagram, control unit]
# []
# [information graphic, price tag, price tag]
# [monitor system, the image, the image]
# [sound intensity, sound intensity, sound intensity]
# [latent image, refractive index, latent image]
# [fingerprint sensor]
# [the present]
# [the image, the image, the image]
# [machine learning]
# [The following, the present]
# [the present]
# []
# [feature group, feature group, feature group]
# [touch panel, the change, physical quantity]
# [a vehicle, a vehicle, a vehicle]
# [mobile terminal, radio transceiver, radio transceiver]
# []
# [reflected light, observed information]
# []
# [the system, prior art]
# []

# %% [markdown]
# Test

# %%
LABEL = "TECH"
doc_bin_test = DocBin() # create a DocBin object
nlp = spacy.blank("en")
# nlp.max_length = 2000000
for training_example  in tqdm(test_lines[12000:24000]): #~5 patents
    doc = nlp.make_doc(training_example) 
    ents = []
    
    for match_id, start, end in matcher(doc):
        #print(i,"Matched based on lowercase token text:", doc[:10], '::::::::',doc[start:end],start, end)
        span = Span(doc, start, end, label=LABEL)
        #print(span, span.label_)
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)

    filtered_ents = filter_spans(ents)
    print(filtered_ents[:3])
    doc.ents = filtered_ents 
    doc_bin_test.add(doc)
# Out:
#   0%|          | 0/12000 [00:00<?, ?it/s]
# [machine learning]
# [first light, first light, the image]
# [The reference frame, the reference frame, the reference frame]
# [spatial frequency]
# [the following]
# []
# [the present]
# []
# [magnetic strip]
# [PET scanner, positron emission tomography, physical properties]
# [classification problem, classification problem, input data]
# [the present, the spirit, the present]
# [yet another, number of, frequency domain]
# [threshold value, threshold value, threshold value]
# []
# []
# [feature extraction, image enhancement, edge detection]
# []
# [input device]
# []
# [user interface, sensor fusion]
# [the power]
# []
# []
# []
# [computer readable, recording medium, malicious code]
# [collision avoidance, velocity vector, video frame]
# [the present]
# [data extraction]
# [driver circuit, the present, resonant circuit]
# [calibration target]
# [vehicle lane]
# [primary cell, secondary cell, fuel cell]
# [the novel]
# [smart home, smart home, smart home]
# [dielectric material, polyethylene terephthalate]
# [Augmented reality display, user interface, video stream]
# []
# []
# []
# [data management, credit card company]
# [the power]
# [bit error, color space, the shapes]
# [Video Processor]
# []
# []
# [control device]
# [information processing, source code, source code]
# [machine learning]
# []
# [spherical cap, spherical cap, input device]
# [the image, hard disk]
# [the present, probability density function]
# [The following, the following, the present]
# []
# [user interface]
# []
# []
# []
# [information processing, storage medium]
# [information processing]
# []
# [The image, augmented reality, real time]
# [fingerprint detection, fingerprint recognition, fingerprint recognition]
# [the resistance, the resistance, the resistance]
# [magnetic tape, soft magnetic material, hard magnetic material]
# [hyperspectral imaging, the image, the image]
# [guide rail, guide rail]
# [computer readable, storage medium, software product]
# [Single Instruction Multiple Data, Intel compatible]
# []
# [photo album, photo album, photo album]
# []
# []
# [The image, a vehicle]
# [center frequency, front end, front end]
# []
# [optical image, display device, display device]
# [computer program, electronic device]
# []
# []
# [computer device, the image, computer device]
# []
# [computing device, to be arranged]
# [on the Internet, image recognition]
# [smart card, power supply, smart card]
# [the record]
# [yet another, yet another, the height]
# [raw image, image processing, the diamond]
# [optical system, the verifier, the verifier]
# []
# []
# []
# [IMAGE PROCESSING, ELECTRONIC DEVICE]
# [the present, the present, the present]
# [block diagram, electronic device, external device]
# [electronic device, electrical path, electrical path]
# []
# []
# [fingerprint sensor, optical sensor, imaging technology]
# [vacuum cleaning]
# [call signal, missed call]
# [computer readable, The computer, flash drive]
# [the image, the image, the image]
# [a collision, a vehicle, the image]
# [the image, liquid crystal display]
# [in motion, in motion, in motion]
# [first stage, the image, photo sharing websites]
# [the present, navigation system, mobile terminal]
# [intelligent terminal, digital device, tablet computer]
# [the present]
# []
# [the present, mobile terminal, mobile terminal]
# []
# []
# [results of, decision tree, prediction models]
# [plastic film]
# []
# []
# [depth conversion]
# [vertical axis, vertical position, road surface]
# []
# [the present, vertical axis, the image]
# []
# [light sensor, light source, more than]
# []
# []
# []
# [the envelope, start point]
# []
# []
# [active ingredient, active ingredient]
# [number of, computer systems, computer system]
# [training data]
# []
# [PRICE TAG, The system, color mapping]
# [the following]
# []
# [current balance]
# [control system, the present, the present]
# [mobile device, personal computer, application-specific integrated circuit]
# [electronic signature, the image, identity verification]
# [control unit, control unit, the movement]
# []
# []
# [the computer, the computer, inertial system]
# [the present, acoustic wave, acoustic wave]
# [the image, license plate, the image]
# []
# [digital camera, testing device, testing device]
# [image processing, upper lip, lower lip]
# [control device, image processing, control device]
# [coordinate system]
# []
# []
# []
# []
# [navigation system]
# [windowed frame, image sensor, windowed frame]
# [The present, number of, standard library]
# [solid state, image processor, image registration]
# [photo sharing, the image, the image]
# [The present, The present]
# [fingerprint recognition]
# [The image, The image, data acquisition]
# []
# [start button, a vehicle, start button]
# [optical instrument, light detection and ranging, light sources]
# [mobile terminal]
# [degrees of freedom, degrees of freedom, azimuth angle]
# [image signal processor, data signal, analog signal processor]
# [display device, a vehicle, display device]
# [user interface, user interface, the image]
# [the present, the present, the present]
# [scale-invariant feature transform, the image]
# [the matrix, number of, Planck constant]
# []
# [search image]
# [mail carrier, near real time, the enterprise]
# [on the table, number of, number of]
# []
# [composition material]
# []
# [infrared camera, infrared camera, stereo camera]
# [User interface]
# [database management, information processing]
# []
# []
# []
# []
# [control device, artificial intelligence, image analysis]
# [environmental conditions, environmental conditions, continuous spectrum]
# [ground plane, 90 degree angle]
# [fingerprint recognition, fingerprint recognition, parasitic capacitance]
# [data processing, data processing, principal component analysis]
# [road surface, in contact, road surface]
# [prior art, the present, the following]
# []
# [in the cloud]
# [The button, the button]
# [the present, upper limit, the present]
# [the patch, vehicle battery]
# [feature data, feature data, neural network]
# [The window, the window, the window]
# [the present, circuit board, printed circuit board]
# [storage medium, The computer, lane line]
# []
# []
# []
# [the present, the following, mobile terminal]
# [carrier wave, carrier wave, carrier wave]
# [computer readable, the track, relative motion]
# [biometric authentication, biometric authentication, confidential information]
# [The master]
# [security tag, the security, data storage]
# [a vehicle, car accidents, lack of sleep]
# []
# []
# [auxiliary storage]
# [number of, real space, information processing system]
# [electronic pen, electronic pen]
# []
# [electronic device, electronic device, electronic devices]
# [digital image, digital image]
# [integrated circuit card, mobile communication, mobile terminal]
# [the power]
# [geometric model, process variation]
# [the present, road surface]
# []
# [main board, main board]
# []
# [transfer learning, medical images, medical images]
# []
# [classification system]
# []
# [information processing system, control unit]
# [the present, the present]
# [traffic signs, deep learning, a vehicle]
# [ADOBE FLASH, web interfaces, search results]
# [object classes, object classes, the system]
# [input device, input device, input device]
# []
# [and circuit, dedicated circuit]
# [of components, geometric model, of components]
# []
# [the present, The present]
# [visible light, visible light]
# [control module]
# [mobile terminal, normal mode]
# [the security, the security]
# [world view]
# [computing device, computing device, free space]
# [the present]
# [vertical direction, vertical direction, vertical direction]
# []
# [electronic device, electronic device, electronic device]
# [mobile terminal, mobile terminal, mobile terminal]
# [display device, light sources, light sources]
# [the system, jet printing, the following]
# []
# [the image, the image]
# []
# []
# [management system, control device, the following]
# [data storage device, medical image, image reconstruction]
# []
# []
# [information processing, information storage, compact disc read-only memory]
# [state estimation, empty space, empty space]
# [results of, personal computer, embedded system]
# []
# [The image, straight line]
# []
# [parking lot, high resolution, low resolution]
# [display device, fingerprint sensor, fingerprint sensor]
# [the force, the strain, the present]
# [the present, the present, the present]
# []
# [the following]
# [The present, close position]
# []
# [computer readable, storage media, the computer]
# [mobile terminal, iris recognition]
# []
# [laboratory test, laboratory test, laboratory test]
# [license plate, license plate, license plate]
# []
# [price tag, price tag, human factor]
# [training data]
# [mobile device]
# []
# [image information, frequency conversion]
# []
# [machine learning]
# [the present, copyright protection]
# []
# []
# [defective pixel, defective pixel, spatial filtering]
# [the system]
# [the present, the present]
# [first dimension, second dimension, first dimension]
# []
# [the present, cooking utensil, two-dimensional code]
# [reference point, reference point]
# [separate system]
# []
# []
# []
# [control device, control unit]
# []
# []
# [user interface, user interface, user input]
# [straight line, integrated circuit, central processing unit]
# [The image]
# []
# [the system, machine learning, the system]
# []
# [image information, the present, image information]
# []
# [the image]
# [solenoid coil, solenoid coil, communication circuit]
# [biometric authentication, biometric authentication, biometric authentication]
# []
# [information storage]
# []
# []
# [data analysis]
# [electronic device, electronic device]
# [angle of incidence, the present, a vehicle]
# []
# [display screen, mobile terminal]
# [time series, number of, number of]
# []
# []
# []
# [surveillance system, the present, surveillance system]
# []
# [data processing]
# [upper limit]
# [image stitching, robot navigation, stitching via]
# []
# [image processing, image processing, image processing]
# [the image, The system, object space]
# []
# [electronic device]
# []
# []
# [shoulder pads, range of motion]
# [the image, the present, data file]
# [threshold value, threshold value]
# [The present, computer program, computer program]
# []
# [video signal, first data, video signal]
# []
# [display device, cathode ray, liquid crystal display]
# [computer program, the present, program code]
# []
# [position information, image information, field of vision]
# [the original]
# [palm print]
# [a vehicle, vehicle model]
# []
# []
# []
# [electrical resistance, the resistance, electrical resistance]
# [control unit]
# [real image, location information, the image]
# []
# [autonomous vehicle, the environment, object detection]
# [the shapes]
# [Defective pixel, image processing, Defective pixel]
# [central processing unit, digital signal processor, programmable logic controller]
# [electronic device, virtual image, electronic device]
# [driver circuit, touch sensor, fingerprint sensor]
# []
# [the computer]
# [video signal, video signal]
# []
# []
# [image processing]
# [electronic device, biometric authentication]
# [the following]
# [VR headset, VR headset]
# [the following, steering wheel]
# []
# [medical imaging, the system, medical imaging]
# []
# []
# []
# [The image, lowest density, lowest density]
# []
# [data retrieval, geographic database, geographic database]
# [the present, fluid flow, fluid flow]
# []
# [front end, hard copy, front end]
# [mobile phone, display screen, iris recognition]
# [fingerprint sensor, touch sensor, fingerprint sensor]
# []
# []
# [number of, the present, more than]
# [fingerprint identification, power consumption, fingerprint identification]
# [user interface, wireless communication, user interface]
# []
# [welding power supply, the computer, image processing]
# [information processing]
# [optimal solution]
# []
# []
# [element 100, element 100, element 100]
# [computer program]
# [touch panel]
# []
# [the present, the height, road surface]
# [the image, data extraction, angular speed]
# []
# []
# [block diagram, flow diagram, flow diagram]
# [facial expression, facial expression, facial expression]
# [autonomous driving, the following, autonomous driving]
# [the present]
# [computer program, driver monitoring system, a vehicle]
# [time zone]
# []
# []
# [user interface, operating system]
# [the present, line width]
# [smart phone]
# [Online training]
# [The system]
# [electronic device, external device, electronic device]
# [graphic element, graphic element, graphic element]
# [face recognition, the present, storage device]
# [the present, fingerprint sensor, fingerprint sensor]
# [prior art, the present, prior art]
# [the present]
# [information processing system, information processing system]
# [number of]
# [number of]
# [facial detection, the image, facial detection]
# [optical system, optical system, reference table]
# []
# [seismic survey, surface density, number of]
# [personal information]
# [the window, the window, the window]
# [the image, object detection, feature extraction]
# [The image, the image]
# [the system, the present, the system]
# [field of view, imaging system, light source]
# []
# []
# [electrical communication, electronic device]
# []
# [infrared light, infrared light, infrared light]
# [user interface]
# []
# [control unit]
# [sensor drive, the image, the image]
# [storage medium, computer program, the computer]
# []
# []
# [start point, line of sight, optical axis]
# [the system, number of, the system]
# [volatile memory, volatile memory, random access]
# [expert system, force plate]
# [brain activity, sigmoid function, inflection point]
# []
# []
# [The units, physical units, the units]
# []
# []
# [time signal, time signal]
# [the general]
# [information processing, control unit, control unit]
# [drowsiness detection system, drowsiness detection system, drowsiness detection system]
# [the present, The image, the image]
# [Markov chain, State Transition]
# [optical flow, optical flow, optical flow]
# [The artificial intelligence, real time, knowledge graph]
# [integrated circuits]
# [The present, personal information, user experience]
# [solar radiation, wind speed, atmospheric pressure]
# [display device, Liquid Crystal Display, input device]
# []
# [The present, the present, computer program]
# [the computer]
# [data feed, data feed, machine vision]
# [the present, the present]
# []
# []
# [the weather, the weather, the environment]
# [the present, biometric authentication, square wave]
# []
# [the image]
# [prior art, program files, program files]
# []
# [electronic device, iris recognition, the following]
# [display device]
# [fingerprint identification, fingerprint identification]
# [second stage, the image, the image]
# [computing resource]
# []
# [electronic device, light source]
# [the image, number of, the image]
# [neural network, the image, more than]
# [random access, near real-time, frames per second]
# [vehicle brand, vehicle brand, list ranking]
# []
# []
# [a vehicle, the environment, the environment]
# [geographical information]
# []
# [coordinate system, virtual space, coordinate system]
# []
# []
# []
# [The system]
# [the following, electronic device, check mark]
# [the system]
# [The image, data processing, position information]
# [optical filter, image sensor, optical filter]
# [the present, the image, the image]
# []
# []
# [a vehicle, to be determined, more than]
# [the present, a vehicle]
# [fingerprint recognition]
# [a vehicle, a vehicle, a vehicle]
# []
# [the present]
# [motor vehicle, scene graph, the motor]
# [object based]
# [the image]
# [iris recognition, the present, mobile terminal]
# []
# [digital camera]
# []
# [maximum speed, maximum speed, maximum speed]
# [number of, the present time, number of]
# []
# [low power, electrical energy, battery life]
# [memory device, hard coded, the present]
# [the present, computer readable, storage medium]
# [the present, the image, smart mirror]
# [liquid nitrogen]
# []
# []
# [results of, object detection]
# [the computer, the present, deep machine learning]
# []
# [the present]
# [schematic diagram, the present, parasitic capacitance]
# [geometric structure, object detection]
# [number of, number of, number of]
# [display device]
# [the traffic, traffic light, traffic control]
# []
# [the present]
# [smart phone, electronic device, smart phone]
# []
# [number of, number of, number of]
# [probability density function]
# [image information, display screen, display screen]
# [control module, travel drive]
# [deep learning, machine learning, deep learning]
# [electronic device, electronic device, the present]
# [Network device, network device, label switching router]
# [image processing, the image, readable code]
# []
# [the height, map generator, the height]
# []
# []
# []
# [the present, piston rod, piston rod]
# [the present, success rate, electronic device]
# [A vehicle, tire tread, the system]
# [the image, point in time]
# []
# [results of, raw material]
# []
# [period of time, period of time, period of time]
# []
# []
# []
# [through holes]
# [the height, the height, road surface]
# [transfer learning, medical images, the order]
# [registered trade name, the image, the computer]
# [location information, optical communication, Intelligent Transport Systems]
# [audio processing, the present, studio recording]
# [The system]
# [the present, the following, the present]
# [mobile terminal, the present]
# []
# [contour line, the image, contour line]
# [control unit]
# [the present, the present, the present]
# [The system]
# [baby's head]
# []
# []
# []
# []
# [point group, point group, point group]
# []
# [schematic diagram, the environment, temperature sensor]
# []
# [space between]
# []
# []
# [the present, the present]
# [motion video]
# [infrared light]
# [first system]
# [smart card, the present, smart card]
# [block diagram, mobile robot, mobile robot]
# []
# [second processor]
# [road sign, road sign]
# [the present, night vision]
# [The culture, management system, mixing ratio]
# [the image, the image]
# [the system, the image, user interface]
# [electronic device, electronic device, electronic device]
# []
# []
# [information table, number of, is missing]
# [video signal, real time, the present]
# [recording medium, flash memory, hard disk]
# [high resolution, exposure time, spectral sensitivity]
# []
# [packaging material, packaging material, packaging material]
# [the image, the present, the image]
# [Liquid Crystal Display, Thin Film, Liquid Crystal Display]
# [mobile terminal, terrestrial magnetism, mobile terminal]
# [accumulation of errors]
# [augmented reality display, video stream, image recognition]
# [imaging system, optical system, view angle]
# [user information, pattern matching]
# [computer processor, The computer, the image]
# [straight line, descending order, straight line]
# []
# [pixel count, vehicle to vehicle, stereo cameras]
# [world space, 6 degrees of freedom, world space]
# [fingerprint recognition, fingerprint recognition, computing device]
# [computer database, interaction information]
# []
# [the present]
# [the present]
# [data structure, Exchangeable image file format, the image]
# []
# [margin of error, motion sensors, the environment]
# [the system, information storage, information storage]
# []
# [computer readable, computer program, the independent]
# [data processing]
# [active layer, active layer]
# [the present, the present, the present]
# [time series, time series forecasting]
# [computing device, the image]
# [input data, database table, database table]
# [touch sensor]
# []
# []
# []
# []
# []
# [point transformation, point transformation, the image]
# []
# [digital logic, discrete transistor, programmable logic]
# []
# [authentication server, authentication server, wide area network]
# [schematic diagram, the present, schematic diagram]
# []
# [the present, fingerprint sensor, light source]
# [monitoring system, monitoring system, the image]
# [server computers, data structures, server computers]
# [electronic device]
# []
# [mobile terminal, user information, mobile terminal]
# [moving image, the image, the image]
# [the present, electronic device, electronic device]
# [storage medium, secure communication]
# [current time]
# [time interval, time value, time interval]
# [pedestrian detection, Pietro Perona, Pedestrian Detection]
# []
# []
# [the image]
# []
# []
# []
# []
# []
# [the image, display device]
# [The image]
# [warning message]
# [the computer]
# [card reader]
# [electronic device, electronic device, electronic device]
# [number of, hierarchical structure, threshold value]
# [A vehicle, the present]
# [a vehicle]
# [The image]
# [robot hand]
# [Coverage Data]
# []
# [Working Time]
# [the spirit]
# [digital picture]
# [electronic device, fingerprint recognition]
# [the present, parasitic capacitance, schematic diagram]
# [horizontal direction, vertical direction]
# [fingerprint sensor]
# [template matching]
# [moving average, number of, number of]
# [biometric authentication, the present, biometric authentication]
# []
# [the computer, the present, the order]
# [point in time, resonance frequency, the image]
# [the present, the image, the image]
# [optical scanner]
# [Deep Learning]
# []
# [the following]
# [the image, the image, the register]
# [the heater]
# [neural network, modes of operation, input data]
# []
# [the image, the image]
# []
# []
# [fourth generation]
# [optical axis, optical axis, number of]
# [inkjet printing]
# [the image]
# [electronic identification, external device]
# [power supply unit, mobile terminal, power supply unit]
# [data integration, the present, Data Model]
# []
# [radio tag, a conversion, error detection]
# [the present, pulse sequence, pulse sequence]
# [forensic video, region of interest]
# [moving images, the image, video call]
# [the present]
# []
# [real time]
# [Chinese character, state transition]
# []
# [The report, the report]
# [point cloud, laser scanner, start point]
# [10 seconds]
# []
# [period of time]
# [the signal, the signal]
# [shutter speed, shutter speed]
# []
# []
# [the present, state transition, computer readable]
# [computing device]
# [the present]
# [artificial agents]
# [object detection, object detection, blind spot]
# []
# [position information]
# [neural networks, low power, dot product]
# [The image]
# []
# [the environment, the environment]
# [the rescue, the present, the rescue]
# [the following]
# [The breast, cancer patient, breast cancer]
# [specular reflection, strong material, control unit]
# [automated vehicle, the height]
# [fingerprint sensor]
# [data structure, data structure]
# [deep neural network, object recognition, deep neural network]
# []
# [second duration, approximately equal to]
# [oral cavity, oral cavity]
# [floating power, floating power, floating ground]
# []
# []
# [machine learning algorithm, feature extraction, machine learning algorithm]
# []
# [input and output, electrical signal, light sensor]
# []
# [control unit, control unit, the image]
# []
# []
# [The present, the present, number of]
# []
# []
# []
# [liquid crystal display, EL display, control unit]
# [fingerprint sensor, fingerprint sensor, fingerprint sensor]
# [failure mode, data storage, data storage]
# []
# []
# []
# [the image]
# [vertical line]
# [Optical Character Recognition, character recognition]
# [first system, first system, system resource]
# []
# [more than, the normal, information processing]
# [fingerprint sensor, fingerprint sensor]
# [straight line, focal length]
# []
# [The image, data storage, spectral sensitivity]
# [number of, running out]
# [center of mass, in contact, sensory perception]
# []
# []
# [image analysis, digital memory, digital memory]
# []
# [fingerprint sensor, first difference]
# [storage device, storage device, storage device]
# [location information, axially symmetric, flipped image]
# [number of]
# []
# [a vehicle, a vehicle]
# []
# []
# []
# []
# [touch panel]
# [data integrity]
# [tactile dome, fingerprint recognition, the button]
# []
# [machine learning, neural network, deep learning]
# [VR glasses]
# [functional unit, the image, the image]
# [curved lens]
# [communication network, wireless transmission, communication network]
# [baggage claim, electronic paper, baggage claim]
# [bright spot, number of, number of]
# [time-series data, hour unit, time-series data]
# []
# [gait cycle]
# [user interface, coordinate system, virtual space]
# [user input, user interface]
# []
# []
# [surface area]
# [smart phone, smart phone]
# [electronic device, electronic device, personal cloud]
# [field of view, number of, number of]
# [mobile robot, travel drive, the image]
# [remote control, remote control]
# [The present, the field]
# []
# []
# [The following]
# [the image, the original]
# [wireless communication]
# []
# []
# [The system, software components, human verification]
# [object recognition, object model, object recognition]
# [the image, the image, the image]
# []
# [data verification]
# [fingerprint sensor, fingerprint sensor, fingerprint sensor]
# [in parallel]
# [upper limit, the image]
# []
# [display device, code generation, code generation]
# [the present, mobile device, input interface]
# [axis of symmetry, process parameter, mathematical model]
# [information processing]
# [information processing, the image, edge detection]
# [electronic devices, pattern recognition, fingerprint recognition]
# [communication network, communication network]
# [the present, the following]
# [door switch, door switch]
# [cell counting]
# [Electronic devices, mobile wallets, Mobile wallets]
# [the present]
# []
# [pedestrian crossing]
# [from the top, ultrasonic welding, ultrasonic welding]
# []
# [the present]
# []
# [credit cards, user interface, cell phone]
# [The image, mixing ratio]
# [control flow, control flow]
# [the present, the present, the security]
# [location information, the following]
# [one piece, one piece, one piece]
# [information processing, measurement device]
# [operating system, graphics acceleration, linked list]
# [neural network, artificial intelligence, machine learning]
# [semiconductor memory, hard disk, numerical data]
# []
# [color space, color space]
# [the present, storage medium]
# [combine harvester, combine harvester]
# [fingerprint sensor, fingerprint sensor]
# []
# [portable device, wireless connection, domestic appliance]
# [virtual function, function model, function model]
# [first generation]
# []
# [radar sensor, the following, radar sensor]
# [text area]
# [is missing, is missing, information table]
# [data sharing, real-time information, real-time data]
# [the present, number of, coil spring]
# [feature data, object based, user input]
# []
# [vice versa, external device]
# [virtual object, virtual object]
# [data processing unit, the present, the present]
# [The present, The computer, the computer]
# [the image, blocked state, blocked state]
# []
# []
# []
# []
# []
# [control unit]
# [the image]
# []
# []
# [the present, schematic diagram, the present]
# []
# []
# []
# []
# [feature extraction, object detection, object detection]
# [deep learning]
# [data recording, two-dimensional code]
# [license plate, license plate, license plate]
# [object detection, input device, computer system]
# [electronic device, smart card, electromagnetic field]
# [first system]
# [first light, information processing, first light]
# [mobile terminal, light filter, light filter]
# [neural network, neural network]
# [the image, the image, the image]
# [relative orientation, the image, the image]
# [intelligent terminal, the computer]
# [the power, analog circuits, digital circuits]
# [the present, more than, more than]
# [storage medium, program code]
# [the present, processing power, processing power]
# [capacitive touch, self capacitance, fingerprint recognition]
# [the present, electronic device, camera module]
# []
# [the image]
# []
# [data rate]
# []
# [electromagnetic wave, light source, electromagnetic wave]
# [complementary metal oxide semiconductor, RAW image, image processing]
# []
# [video stream]
# [the following]
# [the present]
# [data acquisition]
# [the computer, print media, the image]
# [fingerprint sensor, fingerprint sensor]
# [light source]
# [the present, the image, the image]
# [stereo camera, laser radar, object detection]
# [number of]
# [the image, the image, information analysis]
# [number of, number of, the system]
# [reference distance, reference distance]
# [file system, file system, first state]
# [wireless communication]
# [text image, text image, text image]
# [object recognition, the image, point in time]
# [integrated circuits, digital signal, digital signal processing]
# [fingerprint identification]
# []
# []
# [the present, the following]
# [point of sale, cellular network, first cellular]
# [monitoring system]
# [block diagram]
# []
# [signal processing, noise reduction, analog-to-digital conversion]
# [the present, fingerprint identification, fingerprint identification]
# [number of]
# []
# [the blade, light source, the blade]
# [unit weight]
# [distance measurement]
# [Image processing]
# [mobile device, cell phone, product packaging]
# [smart phone, control unit, control unit]
# [the present, direct coupling]
# []
# []
# []
# [the present, high pressure]
# []
# [the image, video encoding, the sound]
# [the computer, user input, user input]
# []
# [the computer, electronic device]
# [data transmission, first data, control module]
# []
# []
# [the present, schematic diagram, the present]
# [two-dimensional code, two-dimensional code, two-dimensional code]
# [threshold value]
# [schematic diagram, schematic diagram, schematic diagram]
# [face detection]
# [TV programs, the original]
# [display device, fingerprint sensor, fingerprint sensor]
# [mobile robot, mobile computing device, the image]
# [the following]
# []
# [the present, the image, sensor drive]
# [blind spot]
# [the change, state change, state change]
# []
# []
# []
# [spatial audio, impulse response, digital signal processor]
# [observation point, the present]
# [electronic device, of components, electronic device]
# [information processing, blind spot, blind spot]
# [control module]
# [quality score, number of, identity verification]
# [a vehicle, two-lane road, travel lane]
# [horizontal plane, vertical plane]
# []
# [fingerprint sensor, fingerprint sensor, fingerprint sensor]
# [wafer dicing]
# [rail transit]
# [the present, remote control, remote control]
# [diffuse reflection, one color, color image]
# []
# [the system, light emitting diode, contact image sensor]
# []
# [display screen, the present, display screen]
# [the culture]
# []
# []
# [LED light, laser light, laser light]
# [The system, the normal, design of experiments]
# []
# [navigation map, simultaneous localization and mapping, learning map]
# [radio tag, radio tag, gaming chip]
# [The features, the present, the following]
# [control unit, control unit, control unit]
# [the normal, the normal]
# [external device, the image, external device]
# []
# [the image, major and minor, image processing]
# [movement mechanism, vertical direction, movement mechanism]
# [the image]
# [the message]
# [indoor environment, earth atmosphere, space vehicle]
# []
# []
# [multiple images, multiple images, the image]
# []
# [electronic device, monochromatic light, The signal]
# []
# [the image]
# []
# [autonomous vehicle]
# []
# [optical sensing, location information, optical sensor]
# [external device]
# [infrared light]
# [real-time data, real time, data processing unit]
# [the alarm]
# [eye tracking, eye tracker]
# [the following]
# []
# [head-up display]
# []
# [display screen, time difference, the power]
# [optical sensor, optical system, optical system]
# []
# [ray tracing, RF signal, RF signal]
# []
# [electronic device, electronic component]
# [Industrial Automation, vision sensors, Range imaging]
# [a vehicle, the present]
# [location data]
# [audio fingerprint, audio fingerprint, copyright library]
# []
# [flexible screen]
# []
# [acrylic resin, epoxy resin, acrylic resin]
# [Environmental Conditions]
# [convolutional neural network, neural network, neural network]
# [information collection]
# [biometric identification, the present, display screen]
# []
# []
# [unmanned aerial vehicle, unmanned aerial vehicle, electronic device]
# []
# [the image, control device, image processing]
# []
# [computer system, computer system, number of]
# []
# [leuco dye, pharmaceutical packaging, leuco dye]
# [index finger, index finger]
# []
# []
# [voice recognition]
# [optical device, the image, the image]
# []
# [location information, location information, location information]
# []
# []
# [computer storage, computer programs, data exchange]
# [user input]
# [the image]
# [digital camera, hash value]
# [electronic device, electronic device, the speaker]
# [the present, the present, the present]
# [Digital printing]
# [angular speed, steering angle, steering wheel]
# []
# [number of]
# []
# []
# [progress indicator, progress indicator, progress indicator]
# [information processing, geographical location information, geographical location information]
# [frequency domain, wavelet packet decomposition]
# [The image]
# []
# []
# [QWERTY keyboard, numeric keypad]
# [stereo reconstruction]
# [The artificial intelligence, the voice, The features]
# [automated welding, arc welding, welding rod]
# []
# [touch panel, touch panel, touch panel]
# [the present, position information, license plate]
# []
# []
# []
# [registered trademark, number of, number of]
# [circuit board, circuit board, the other side]
# []
# [The image]
# [object detection, object detection]
# [flat surface]
# [The present, display device, signature recognition]
# [indium tin oxide, indium gallium zinc oxide, piezoelectric material]
# [the present, feature selection, feature extraction]
# [white balance, the image, the image]
# [natural language, natural language, recurrent neural network]
# [the image, the present]
# [The plant, the plant, the plant]
# [light source, diffraction grating, light source]
# []
# []
# [CONTENT MODERATION]
# []
# [The image, data management system, the image]
# [object detection]
# [the present, the following]
# [angle of view]
# [the present, user experience]
# [the present, transfer method]
# [wearable device, license plate, traffic management]
# [user input, external force, more than]
# [state transition]
# [Mobile Device]
# [medical image analysis, automated driving]
# [threshold value]
# [electronic device, electronic device, light source]
# []
# [Traffic Signs]
# [process management, start signal, stereo photography]
# [luminous flux, laser light, horizontal direction]
# [vertical direction, road surface, the image]
# [printing system, the system, printing system]
# []
# [information processing system]
# []
# [Polarizing Filters]
# []
# []
# [The speaker]
# [OLED display, thermal conductivity]
# []
# [mobile device, mobile device, image sensor]
# [vice versa, external device]
# []
# [fingerprint sensor, fingerprint sensor, fingerprint sensor]
# [the field, computer technology]
# [storage media, main memory, main memory]
# [user interface, user interface]
# []
# []
# [state-space representation]
# [menu button, left to right, the image]
# [input device, touch panel, input device]
# [biometric authentication, security level, the present]
# []
# [monitoring system, the train, a vehicle]
# []
# [object recognition]
# []
# [feature detection, feature detection]
# [falling edge]
# [user interface]
# [the present, the present]
# [the system, the system, the system]
# [the following]
# []
# [computer model, the computer, the computer]
# []
# []
# [flow diagram]
# []
# [imaging system]
# []
# [input device, output device, The computer]
# [plane of rotation, horizontal plane, control system]
# [or circuit]
# [element 1, the present]
# [the present, remote control, remote control]
# [recommendation system]
# []
# [first gap]
# [programming model, graphics acceleration, graphics acceleration]
# []
# [second position, stationary point, the horizon]
# [threshold value, threshold value, threshold value]
# []
# []
# [electronic device, biometric authentication, electronic device]
# [road surface]
# []
# [The present, the crack]
# []
# [electric energy, the power, the power]
# [horizontal space, number of, horizontal space]
# []
# [number of, digital signal processor, integrated circuits]
# [parking assist]
# [the following, activation function, activation function]
# [management system, motion data, received data]
# [the ratio, the ratio, the ratio]
# [threshold value]
# [the present, optical system, image sensor]
# [game arcade, the present]
# []
# []
# []
# [the image, output device]
# [radio tag]
# [the following]
# [information processing system, the present]
# [network service, network service provider, network service provider]
# []
# []
# [Image Recognition]
# []
# [the artificial intelligence, mobile terminal]
# [number of]
# []
# [moving picture]
# [data processing, external device]
# [straight line, the following]
# [processing technologies]
# [The counter, The counter, POS terminal]
# [the present, the image, the image]
# []
# [neural network model]
# [electronic device, password hint, password hint]
# [right lane, left lane, right lane]
# []
# [control unit, DC voltage]
# []
# []
# [data analysis, hyperspectral imaging, image sensor]
# []
# []
# [number of, electronic control unit]
# []
# [information storage, electronic pen]
# [measured radiation]
# []
# [wireless communication, touch sensor, numeric keypad]
# []
# [radio tag, radio tag]
# [quality management, quality management, with high probability]
# [convolution operation, convolution operation, results of]
# [three-dimensional model]
# [object recognition, object recognition]
# [data processing, data processing, composite image]
# [the following, digital signal processor]
# [the present, machine learning, deep learning]
# []
# [cover glass, cover glass, fingerprint sensor]
# [control unit, control unit, phone number]
# []
# [social software, communications device]
# []
# [information processing]
# [digital surface model, picture element, the image]
# [number of, threshold value, more than]
# [user input, electronic device, personal cloud]
# [the score, number of, number of]
# []
# [the present, color filter, the height]
# [the signal, the signal, the signal]
# []
# [control unit, control unit]
# []
# [a vehicle, weather conditions, vehicle license]
# [electrical signal, fingerprint sensor, signal processing]
# []
# [second difference, threshold value, second difference]
# [vector graphic]
# [threshold value]
# []
# [moving picture, moving picture, moving picture]
# [optical flow, epipolar geometry, Euclidean distance]
# [humidity control, humidity control, control unit]
# [the image, number of, the image]
# []
# [mass movement, mass movement, the image]
# []
# [the following, the image]
# [machine learning, the system, ground truth]
# [The present, image processing, the filter]
# []
# [The power]
# [the image, memory system]
# [personal computer, tablet PC, angle of view]
# [the present]
# [wireless communication, wireless fidelity, Wi-Fi direct]
# [near field, mobile phones, host card emulation]
# []
# [The image, the image]
# [the master]
# [image processing, line of sight, electrostatic potential]
# [the present, plan view, the present]
# [the present]
# [wireless communication]
# [registered trademark]
# [version number, version number, version number]
# [integrated circuits]
# [the present, processing power]
# [Deep learning, artificial intelligence, human thinking]
# [of the air, the present, design change]
# []
# [The present, problem of being, reference data]
# [data acquisition, set of data, set of data]
# [control unit, heart rate, threshold value]
# [field of view]
# [the present, angular position]
# [the present, the present, the image]
# [regular expression, regular expression, regular expression]
# [the present]
# [mobile terminal, feature data, feature data]
# []
# []
# []
# [operating frequency]
# [skin color, aspect ratio, skin color]
# []
# [image processing, the present, image processing]
# [growing media, the system, growing media]
# [the present]
# []
# [reflected light, reflected light]
# [the present, physical existence, storage medium]
# [the present, people flow, people flow]
# []
# [intelligent terminal, finger touch, fingerprint sensor]
# [coordinate system, field of view, direction of travel]
# []
# [diesel engine, rotational speed]
# []
# [computing device, data manipulation, number of]
# [the window]
# [infrared camera]
# [generative adversarial network, the computer, computing device]
# []
# [control unit, the image, control unit]
# [face recognition]
# []
# [video screen, mobile communication, driver assistance]
# []
# [the environment]
# [electronic device, electronic device]
# [aerial images, highly efficient, electronic map]
# [skin color, skin colors]
# []
# [electronic device, seat pitch, body measurements]
# []
# []
# []
# [artificial intelligence, The artificial intelligence, artificial intelligence]
# []
# []
# [from the outside]
# [the change]
# []
# []
# [point cloud]
# []
# [the following]
# [injection molding, Epoxy Molding Compound]
# []
# []
# [the source, audio content, the source]
# [start point, mobile robot, start point]
# [neural network, the features, road marking]
# [Location information, touch panel]
# [the security, the security]
# [the image, the image]
# [reference point, reference point]
# []
# [touch panel, the following]
# [facial expression, facial expression, facial expression]
# [cross section, metal element, touch panel]
# [polyethylene terephthalate, polyethylene naphthalate, plan view]
# [non-volatile memory, volatile memory, Hard Disk Drive]
# []
# []
# [binary image, red color, binary image]
# [image quality]
# [transparent plastic, control device, image forming device]
# [the image, the image, the image]
# []
# [storage device, flash memory, the power]
# []
# [near field, wireless communication]
# [storage device, storage device, the present]
# []
# [remote control, mobile terminal, remote controller]
# []
# [the change, the movement]
# []
# [start point, start point, start point]
# []
# []
# [the present]
# []
# [the counter, The counter]
# [vertical line, the horizon, road marking]
# []
# []
# []
# []
# [liquid crystal display, light-emitting diode, organic LED]
# []
# [sound signal, remote controller, sound signal]
# [the image]
# [coordinate system, coordinate system, coordinate transformation]
# [synchronous communication, information device, number of]
# []
# [heart rate, heart rate, heart rate]
# [front end, first position, second position]
# [wireless communications, Vehicle to Vehicle, RF circuit]
# []
# []
# [facial expression]
# [image sensor, the worker, the worker]
# [emergency stop]
# []
# []
# [electronic device, the following]
# [number of, number of, number of]
# [the present, computer readable]
# [period of time, period of time]
# []
# [block diagram, the environment]
# [optical system, signal processing, optical system]
# []
# [mobile terminal, user input]
# [schematic diagram, schematic diagram]
# [mobile device, user input, output device]
# [3 Degrees]
# [display device]
# [the present, position sensor, computer system]
# [The present, the field]
# []
# [information processing]
# [electronic device]
# []
# [the factory]
# []
# [game token, game token]
# [the present, the present]
# [user interface, user interface, more than]
# []
# [physical quantity, electronic device, barometric pressure]
# [mobile robot, moving on, freedom to]
# [The present, the present, electronic device]
# [monitoring system]
# []
# []
# [autonomous vehicle]
# [the future]
# [neural network, neural network, neural network]
# [in parallel, the order]
# [color temperature, light source, color temperature]
# []
# [fuel consumption, fuel consumption]
# []
# []
# [lane markings, image quality, lane markings]
# [computer programs, computer storage devices]
# []
# [similarity matrix, similarity matrix, similarity matrix]
# []
# []
# [mobile terminal, the window, hermetically seal]
# [The present]
# [Young's modulus]
# [The image]
# []
# [the present, the following]
# [stereo images, stereo camera]
# []
# [control unit, the system, control unit]
# [computationally expensive]
# [the signal, the system]
# [ice hockey, of components]
# [hierarchical structure, the system]
# []
# [video feed, onboard camera]
# []
# []
# []
# [through the lens, number of, the image]
# [the following]
# []
# []
# [fingerprint recognition, reflected light, fingerprint recognition]
# [low voltage, high voltage, high voltage]
# []
# [the present, the library, The library]
# [yet another, computer readable, computer system]
# [index matrix, index matrix, index matrix]
# [the present, the present, the present]
# [digital image]
# [low level]
# [hydroponic systems, the flood, path of least resistance]
# []
# [the image, the image, the image]
# [the image, the image]
# []
# []
# [The present, information analysis]
# [the present, first light]
# [timing diagram, image quality, the image]
# [The image, complementary metal-oxide semiconductor, skin care]
# []
# []
# [wearable device, information processing system, reference symbol]
# []
# [vertical axis, white noise, The following]
# [schematic diagram, the present, pixel buffer]
# [a vehicle, pneumatic tires, pneumatic tires]
# [light sources, element 20, element 20]
# [biometric authentication, biometric authentication, biometric authentication]
# [object based, the image]
# [the present, object recognition, augmented reality]
# [the street, this place, multiple users]
# []
# [recording medium, recording medium, recording medium]
# [Gaussian filter, bilateral filter, luminance value]
# [measurement system, telescoping boom, telescoping boom]
# []
# []
# [vector space, number of, vector space]
# [two-dimensional array]
# [computer system, computer readable, unmanned aircraft]
# [the present, in contact, in contact]
# []
# [display device, HDR image, display device]
# [artificial intelligence]
# []
# []
# []
# [the present]
# [the present]
# [the present, magnetic field, resonant circuit]
# [level shifter, level shifter, level shifter]
# [dust collector, dust collector, dust collector]
# [electronic device, infrared ray, infrared sensor]
# [number of, number of]
# [classification system, classification system]
# [the present]
# [injection molding, ultrasonic welding]
# [stereo camera, physical object, real space]
# []
# [more than, biometric identification]
# []
# []
# [digital image]
# []
# [signal strength]
# [coordinate system, coordinate system, coordinate system]
# []
# [solid electrolyte, transition metal oxide]
# []
# [The system, surgical navigation]
# []
# [the image, the image]
# [image processing, vertical direction, coordinate axis]
# [pattern matching, the image]
# [the iPhone, cell phone, the iPhone]
# [LED headlights, the monitor, infrared sensors]
# []
# [the image]
# [the present]
# [data model, the present]
# [the present]
# [The image, image information, the image]
# [the present]
# []
# [communication network, external device, external device]
# []
# [temporal difference, temporal difference]
# [operating system, operating system, Microsoft Corporation]
# []
# [welding helmet, the image, welding helmet]
# [The present, face recognition, face recognition]
# [right hand, right hand, right hand]
# []
# []
# [image processing, the image, the image]
# [artificial neural networks, prior art]
# []
# [road surface]
# []
# []
# [wireless communication, mobile terminal, crime prevention]
# []
# []
# []
# [storage memory, print job, print job]
# []
# [contactless smart card]
# [to be determined]
# [the image, number of]
# [front end, front end, parking area]
# []
# [external device, control unit, number of]
# []
# []
# [environmental conditions, tracking system]
# [in contact]
# [dining chair, the image, dining chair]
# []
# [body system, object detection, body system]
# [processing mode, processing mode]
# [principal components, principal components]
# [mobile terminal, training data, mobile terminal]
# [near field, near field, circuit board]
# [personal computers, server computers, consumer electronics]
# [color measurement, color correction, the order]
# []
# [mobile terminal, fingerprint recognition]
# [terminal equipment]
# []
# [the present, touch panel, touch event]
# [vertical direction, fingerprint recognition, horizontal direction]
# [mobile terminal, the general, the image]
# [user interface, user interface, user interface]
# [the envelope]
# [envelope detector]
# []
# [the image]
# [the present]
# [the library, image enhancement, the original]
# [more than]
# [electric energy, the power, the power]
# []
# [the image, external device]
# []
# [the image]
# []
# [The present, image processing]
# [the normal, coordinate system, coordinate system]
# [input device, the present, digital image]
# []
# []
# []
# []
# []
# [a vehicle, received data]
# []
# [the environment]
# [the circle, the present, ambient light sensor]
# [the present, user information, user information]
# [printing system]
# [degrees of freedom, rigid body, free space]
# []
# [more than, more than, the following]
# [upper limit]
# []
# []
# [hard disk]
# [the following]
# [the movement, the movement]
# []
# []
# [the present, mobile terminal, transportation system]
# []
# [computer program, the computer, computer readable]
# [the present, breast cancer, atomic force microscope]
# [parking space]
# [The transition, the transition, probability distribution]
# [input data, convolution operation, convolution operation]
# [mobile terminal, mobile terminal, mobile terminal]
# []
# [number of]
# [key switch, key switch, key switch]
# [equivalent circuit]
# [more than]
# [POS terminal, payment card, data channel]
# [the following]
# [object recognition, object recognition]
# [the heart, heart rate, heart rate]
# [reference frames, reference frames]
# [functional block diagram]
# []
# [the image, the image, the image]
# [resonant frequency]
# [source program]
# [start button]
# []
# [the image, a vehicle, number of]
# [license plate, license plate, a collision]
# [the security, data format, data quality]
# [identity provider, identity provider, number of]
# [user identifier, user identifier, user identifier]
# [dark current]
# [social networking, Amazon Prime, application server]
# [electronic device, number of, reference data]
# [the present, computer readable, storage medium]
# []
# [automatic identification and data capture, the filter, magnetic stripe]
# []
# []
# [automated teller machine]
# []
# [The following, cathode ray, liquid crystal display]
# [enterprise network, the enterprise, the enterprise]
# []
# [the image, the image]
# [smart card, electronic device, electronic device]
# [the service, the service]
# [the system, computerized tomography]
# [piezoelectric actuator, potential difference, potential difference]
# []
# []
# [number of, gray levels, spatial frequency]
# [vertical synchronization]
# [image compression, the original, point after]
# [the present]
# []
# [personal cloud, personal cloud, personal cloud]
# []
# []
# []
# []
# ...
# [stationary state]
# [electronic device, the present, personal computers]
# [artificial intelligence, artificial intelligence]
# [number of, the night]
# [the present, user experience]
# []
# [Computer system, network interface, computer system]
# []
# [secondary antibodies, target protein, target protein]
# []
# [the image, the image, coming out]
# [measuring device, the present]
# [computing device, The computer, storage device]
# [the ratio, number of]
# [deep learning, the window, the window]
# [The power, basic input/output system, electronic device]
# [two-dimensional code, two-dimensional code]
# [the image, the image, the image]
# [the image, mobile terminal, mobile terminal]
# [proximity sensors, proximity sensing, parking sensor]
# [medical image processing, neural network, medical images]
# [the image, region of interest, the following]
# [conveyor belt]
# [the image]
# []
# [first data]
# [Machine learning, computer vision, autonomous driving]
# []
# [display device]
# [mobile phone, power supply, the power]
# [camera module, still image, camera module]
# []
# [surveillance video, surveillance video, the present]
# [electronic device]
# [control unit, control unit, touch panel]
# [the normal]
# [The system, real time, The computer]
# []
# [time series, time series, time series]
# [data acquisition, relational DB, relational DB]
# []
# [computer program code, computer program code, computer program code]
# [in contact, vector sum, the movement]
# []
# [data management]
# [the image, video object, the image]
# [number of, number of, identification card]
# [driving force, rotating motion]
# [logged in, number of]
# [the image, light emission, light emission]
# [position information, position information, position information]
# [the image, digital wallet, mobile device]
# [facial expression, video stream, facial expression]
# []
# [cellular phones, user equipment, laptop computers]
# [geometric center]
# [plastic film]
# [error detection, error detection, error detection]
# [air conditioning]
# [information processing, control unit, control unit]
# []
# [the image, threshold value, threshold value]
# [the present, the present, the present]
# []
# [touch event, touch panel, received data]
# []
# []
# [document processing system, number of, right hand]
# [control unit]
# [electronic device, the image, transparent display]
# [storage device, computer readable, the image]
# [information analysis, vertical line]
# [biometric authentication, electronic device, biometric authentication]
# []
# [geographical information system]
# [The present, real time, results of]
# [The connection between, the image, the image]
# [network service, network service provider]
# []
# [the present, number of, number of]
# [data integration, data conversion, data conversion]
# [fingerprint sensor, fingerprint sensor, transparent plastic]
# [silicon oxide, silicon nitride, silicon oxynitride]
# [electrical energy, mobile terminal, mobile terminal]
# []
# [mobile device, smartphone camera, the present]
# [control unit, control unit, control unit]
# [threshold value, threshold value, threshold value]
# [number of, convolution operation, number of]
# [The system, the system]
# [application stores, classification system, not exactly]
# [mobile device]
# []
# []
# []
# []
# [user information]
# [security system, presence sensing device, the system]
# []
# [display size, user information, the environment]
# [The image]
# [the present, the present, the present]
# [The features, fingerprint sensor, the present]
# [thin film, thin film, thin film]
# []
# [real time, grid cell, grid cell]
# []
# []
# []
# []
# [electronic device, electronic device]
# [the system, the image]
# [the computer, computer readable, storage medium]
# [reference point, point group, reference point]
# []
# [block diagram, electronic device]
# [COMPUTER PROGRAM]
# []
# [classification system, master control, control unit]
# [depth of field, image sensor, collimating lens]
# []
# [image sensor, image sensor, the movement]
# [control device]
# [mixing ratio, average speed, the normal]
# []
# []
# []
# [the image]
# [point of interest, augmented reality]
# [The following, the following]
# []
# [event monitoring, event monitoring, number of]
# [parking lot, still image, high resolution]
# []
# []
# [second position]
# [safe driving, the future, safe driving]
# [the times, the times]
# []
# [battery power, data transmission, data transmission]
# []
# []
# []
# []
# [the features, the features]
# [semiconductor device]
# []
# [intelligent terminal, two-dimensional code]
# []
# []
# []
# [information processing, moving image, time series]
# [vertical space, vertical space]
# [electronic device, portable phone, game player]
# []
# [ascending order]
# [the present, the image, visual field]
# [color vision]
# [object detection]
# []
# []
# [the computer, the image, the movement]
# [character recognition, character recognition, state transition]
# [the plant, the plant, control function]
# [the following]
# [the present, vertical plate, vertical plate]
# []
# [the present, the image, consciousness level]
# [fingerprint recognition, tactile dome, image information]
# []
# []
# [Machine learning, Machine learning, neural networks]
# []
# [printing system, the image, printing system]
# []
# [in motion, seat belt, seat belt]
# [navigation system, navigation system, position and orientation]
# [unit of measurement, magnetic field, the image]
# []
# [number of, frequency domain, wavelet packet decomposition]
# []
# []
# []
# [the present]
# [production processes]
# [printed circuit board, printed circuit board]
# []
# [the following, road surface, the weather]
# [the following]
# []
# []
# [the following]
# [electrical connection, operating frequency, electrical connection]
# []
# [resonance frequency]
# [neural network, the environment, training system]
# [the power, the power, remote computer]
# [the following, machine learning, The social network]
# []
# []
# [number of, control unit, the stage]
# [mobile terminal, the present]
# [face tracking, driver software, recording session]
# []
# []
# [street light, traffic light, the height]
# [optical sensing, optical sensing, optical sensing]
# [the circle]
# [steering angle, steering wheel, frame rate]
# []
# [ala of the nose, ala of the nose]
# []
# [a vehicle, computing device, the environment]
# []
# [shopping basket, shopping basket]
# [mobile terminal, fingerprint recognition]
# []
# []
# [the present, the following]
# [the image, the present, mobile terminal]
# [playing cards, results of]
# [electronic device, electronic device]
# []
# [the following, laser cut, vacuum forming]
# [data capture, the present, the order]
# [ultrasonic sensor, the image]
# []
# [the infinite]
# []
# [control unit]
# [processing speed, processing speed, number of]
# [light sources, light sources, light sources]
# [virtual object, focal point, focal point]
# []
# []
# [left-side traffic, right-side traffic]
# []
# [time capture]
# [the image, the image, the present]
# [the image, print media, print media]
# [mobile terminal, information collection]
# []
# [Voyage Data Recorder]
# []
# [proximity sensors, global positioning, Proximity sensors]
# [The stage, the stage, liquid crystal]
# []
# []
# [external storage device, body image, body image]
# []
# [noise reduction, audio signal, noise reduction]
# [the present]
# [optical communication, external device, optical communication]
# [image processing]
# [probability density function, probability density function, field of view]
# [Markov chain, deterministic model, number of]
# [information processing, the environment, the environment]
# [the present, lane line]
# []
# [electric current, electric current, electric current]
# []
# [the mirror, smart mirror]
# [the following, dielectric constant, light transmittance]
# [control device]
# [facial detection, video stream, video stream]
# []
# [the present, a vehicle, electronic devices]
# [mobile terminal, facial expression, the image]
# [welding helmet, display device, display device]
# [quality management]
# [external device, external device, mobile terminal]
# [the image, the image]
# [information device]
# []
# [refractive index, optical filter, the filter]
# [back cover, back cover, fingerprint sensor]
# [mobile terminal, image processing, the image]
# [time offset]
# []
# [password hint, electronic device, display screen]
# [the image]
# [computing device, computing device, the software]
# [composite image]
# [parallel processing, input data, number of]
# []
# [selection algorithm, selection algorithm, number of]
# [light source, light source, laser diode]
# []
# [the traffic]
# [The order]
# [the present, the following, the present]
# [biometric identification, OLED display, biometric identification]
# []
# [blind spot, blind spot monitor, blind spot monitor]
# [feature selection]
# []
# []
# [the image, region of interest]
# [a vehicle, wireless access point, wireless communication]
# [Yet another, mobile telephones, personal emergency response system]
# [The button, touch panel, the button]
# [a vehicle, the traffic, a vehicle]
# []
# [halftone process, the image, image quality]
# [sleep mode]
# [digital image]
# [clustering algorithm, surface texture, surface texture]
# []
# [the original, depth of field, depth of field]
# [data warehouse, data repository, data warehouse]
# []
# [the computer, mutual information, numerical data]
# [the present, information system, the message]
# []
# [data processor, coordinate system]
# []
# [the image, the image, the image]
# [object detection, object detection]
# [audio content, audio content, number of]
# []
# [prior art]
# [flow diagram, optical system, effective aperture]
# [moving picture]
# [the general, mobile terminal, mobile terminal]
# []
# []
# [control data, flash drive, hard drive]
# []
# []
# []
# [The following, the image, the image]
# [registered user, registered user]
# []
# [optical axis, focal plane array]
# [medical image, medical imaging, medical image]
# []
# [analog signal, the normal, control unit]
# []
# [the filter]
# [electronic device, electronic device, touch sensor]
# [infrared dye, sodium acetate, Silica gel]
# [bagging area, bagging area, bagging area]
# [a vehicle, vehicle safety]
# []
# [optically pumped, semiconductor laser]
# [a vehicle, motor car]
# [road surface, road surface]
# [electronic device, data card, data card]
# [long distance, more than, long distance]
# [display device, virtual object, the present]
# [the present, computing device, computing device]
# [the image]
# []
# [first light, first light, iris recognition]
# [block diagram]
# [auxiliary storage, the image, main storage]
# []
# []
# [power supply]
# [user identifier, user identifier, user information]
# [always on]
# [control device, virtual object, control device]
# []
# []
# []
# [The computer]
# []
# [traffic signal, explanatory diagram, upper limit]
# []
# []
# [the filter, the filter]
# []
# []
# [data storage, cloud database, wireless communication]
# [relational database]
# []
# []
# []
# []
# [the present, the order, the present]
# [storage medium, magnetic storage, floppy disk]
# [hardware platform, prior art, software product]
# [the night, Electronic sign, electronic sign]
# [context management, context management, context switch]
# [number of]
# [acknowledgement of receipt, acknowledgement of receipt, computing device]
# [storage medium, rules engine, machine-readable form]
# []
# [object based, more than]
# [electronic device, electronic device, electronic device]
# [printed circuit board assembly, circuit board, backwards compatible]
# [face recognition, local binary patterns]
# [first dimension, second dimension]
# [breast cancer, breast cancer, breast cancer]
# [body image, image search]
# [schematic diagram, blind spot]
# [autonomous vehicle, autonomous vehicle, autonomous vehicle]
# [document classification]
# []
# [contour line]
# [the sound, real time]
# [the image]
# []
# [electronic device, color image, infrared ray]
# []
# []
# [The present, the system, the computer]
# [The present]
# [machine learning, linear classifier]
# [The system]
# []
# [Region of Interest, on the road]
# [FINGERPRINT IDENTIFICATION]
# []
# [the present, the pitch, the pitch]
# [ankle joint, the present]
# [service provider, service provider, the service]
# [schematic diagram, schematic diagram, schematic diagram]
# []
# [The present, machine-readable medium, Hard Disk Drive]
# []
# [video encoding, video encoding]
# [wave radar, wave radar, radar system]
# []
# [proximity sensors, proximity sensor, proximity sensor]
# []
# [object detection]
# [data transmission, wireless charging, electromagnetic induction]
# [The image]
# [security label, digital authentication, law enforcement]
# [mobile platforms, display monitor, frame of reference]
# []
# [neural network model]
# []
# [wireless communications, mobile device, PCB trace]
# [control system, control system, measuring device]
# [mobile device]
# [the image]
# [of components, electronic device, Female Connector]
# [control menu, control menu]
# [the present, the image]
# [the system, the computer, the system]
# [camera module]
# [content delivery network]
# [Stereo Vision, Pattern Analysis, Machine Intelligence]
# [vertical stabilizer, field of view, field of view]
# [the following, the following, the following]
# [Markov model]
# [the present, the following, the following]
# [information collection, data transmission]
# []
# []
# [neural network, training set, neural network]
# [signal lamp]
# [information display, position and orientation, focal distance]
# [IR radiation, IR radiation]
# [display device]
# [the present, The present, the spirit]
# [The forms]
# []
# []
# []
# [deep learning, convolutional neural network, deep neural network]
# [air quality, air quality]
# []
# [head unit]
# []
# []
# [the present, wide dynamic range, low dynamic range]
# [moire pattern, fingerprint sensor, moire pattern]
# [The present, electronic device]
# [the present, LED light, LED light]
# [The following, the present, the present]
# [the environment, the environment, the environment]
# [smart home, smart device]
# [information processing system, information processing]
# [road vehicle, road vehicle, The flash]
# []
# []
# [training data, the present, supervised learning]
# [imaging sensor, image sensor, imaging sensor]
# [The present]
# [mobile phone, mobile phone, mobile phone]
# []
# []
# [signal processing, the signal]
# [personal cloud, personal cloud, personal cloud]
# []
# [linear search, linear search, linear search]
# []
# []
# []
# [character recognition]
# [the image, the image, linear filter]
# [information processing, touch panel, input device]
# [dynamic range]
# [the original, the following, compression ratio]
# [road surface, the system, functional units]
# [the following]
# [number of]
# [cross section, fingerprint recognition, display device]
# [recording medium, recording medium, semiconductor memory]
# []
# [face recognition]
# []
# [moving unit]
# [data structure, the worker, the worker]
# []
# [the present]
# [light source]
# []
# [the present, data communication]
# [the present]
# [the image, the voice, input interface]
# [first data]
# [blind spot, lane change, lane change]
# [the present, mobile terminal, data processing]
# []
# []
# [computer vision, number of]
# [control device, the present, user interface]
# [recording head, recording head, recording head]
# [the present, object recognition]
# [electronic system, read-only memory, the system]
# []
# []
# []
# [electronic device, rotation angle, number of]
# [fingerprint identification, input and output]
# [storage medium, computer programs]
# [high voltage, MOS transistor, high voltage]
# [point cloud data]
# [electronic system, electronic device, electronic device]
# []
# [data item, mobile robot]
# []
# [position information, the movement]
# [battery power, threshold value, power saving]
# [code generation, physical quantity, element 111]
# []
# [the system, the system, the system]
# [number of, number of, number of]
# []
# [virtual SIM, The system, mobile terminal]
# [information processing, control unit, virtual object]
# [training data, feedback loop, the system]
# []
# [gradient vector, eigen vector, gradient vector]
# [block diagram, data conversion]
# [information collection, the environment, the environment]
# [the present, the following, the following]
# [mobile terminal, the present, circuit board]
# [information processing system, virtual space, control unit]
# [Convolutional Neural Network]
# []
# [laser scanner, light source, point cloud data]
# []
# [the present, fingerprint sensor, fingerprint sensor]
# [the signal, the signal, the signal]
# [control unit, the window]
# [remote control, remote control, motion control]
# []
# []
# [level shift, first shift, high voltage]
# []
# [electrical connection, optical sensing, electrical connection]
# [number of]
# []
# []
# []
# []
# []
# [same color]
# []
# [grid coordinates, vertical coordinate, grid coordinates]
# []
# []
# []

# %% [markdown]
# Save data

# %%
doc_bin_train.to_disk("training_data.spacy") # save the docbin object
doc_bin_valid.to_disk("valid_data.spacy") # save the docbin object
doc_bin_test.to_disk("test_data.spacy") # save the docbin object

# save train_lines to txt file
with open('train_lines.txt', 'w') as f:
    for line in train_lines:
        f.write(line)
        f.write('\n')
f.close()

# save train_lines to txt file
with open('valid_lines.txt', 'w') as f:
    for line in test_lines[:12000]:
        f.write(line)
        f.write('\n')
f.close()

# save test_lines to txt file
with open('test_lines.txt', 'w') as f:
    for line in test_lines[12000:24000]:
        f.write(line)
        f.write('\n')
f.close()

# %% [markdown]
# ### Configuration

# %% [markdown]
# Donwnload __base_config.cfg__ for your system at https://spacy.io/usage/training#quickstart

# %%
# Run to generate full training config
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# /home/gaetan_serre93_gmail_com/miniconda3/bin/python: No module named spacy

# %% [markdown]
# ### Training

# %% [markdown]
# Run training. All results are stored into __./spacy_output__

# %%
# !python -m spacy train config.cfg --output ./spacy_output --paths.train ./training_data.spacy --paths.dev ./valid_data.spacy
# Out:
# ✔ Created output directory: spacy_output
# ℹ Saving to output directory: spacy_output
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# =========================== Initializing pipeline ===========================
# [2022-04-15 17:13:09,327] [INFO] Set up nlp object from config
# [2022-04-15 17:13:09,340] [INFO] Pipeline: ['tok2vec', 'ner']
# [2022-04-15 17:13:09,344] [INFO] Created vocabulary
# [2022-04-15 17:13:09,345] [INFO] Finished initializing nlp object
# [2022-04-15 17:13:50,927] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     45.50    0.28    0.36    0.24    0.00
#   0     200         41.48   2334.34   36.93   72.23   24.81    0.37
#   0     400         48.97   1330.87   52.86   58.68   48.09    0.53
#   0     600         84.40   1282.17   57.12   71.30   47.65    0.57
#   0     800         72.84   1190.72   55.41   84.50   41.22    0.55
#   0    1000         98.04   1546.55   60.87   81.99   48.41    0.61
#   0    1200        100.56   1560.48   63.58   78.87   53.25    0.64
#   0    1400        157.06   1659.39   66.15   79.52   56.64    0.66
#   0    1600        145.92   1966.43   68.07   77.33   60.79    0.68
#   0    1800        291.33   2509.35   67.82   87.51   55.37    0.68
#   0    2000        324.22   3053.98   69.60   87.75   57.67    0.70
#   0    2200        313.73   3583.64   72.91   84.75   63.97    0.73
#   0    2400        367.28   4167.67   73.76   86.66   64.20    0.74
#   0    2600        464.36   4648.46   76.08   83.50   69.87    0.76
#   0    2800        474.34   4750.97   76.13   85.50   68.62    0.76
#   0    3000        385.85   4031.21   77.83   87.14   70.31    0.78
#   0    3200        454.80   3479.71   79.95   87.89   73.33    0.80
#   0    3400        740.78   3759.14   80.46   87.08   74.77    0.80
#   0    3600        759.33   3698.84   81.34   87.51   75.99    0.81
#   0    3800        440.39   3402.72   81.50   88.31   75.66    0.81
#   0    4000        424.57   3415.91   82.35   89.78   76.05    0.82
#   0    4200        643.00   3364.08   82.40   88.10   77.39    0.82
#   0    4400        494.66   3292.80   83.50   91.14   77.04    0.83
#   1    4600        461.16   2801.34   83.85   90.05   78.45    0.84
#   1    4800        801.17   2760.19   83.56   89.12   78.66    0.84
#   1    5000        543.64   2714.26   84.12   91.99   77.49    0.84
#   1    5200        635.64   2833.54   85.17   90.68   80.29    0.85
#   1    5400        604.47   2715.12   85.15   88.99   81.62    0.85
#   1    5600        705.59   2622.04   85.11   89.41   81.22    0.85
#   1    5800        519.38   2617.52   85.49   91.15   80.50    0.85
#   1    6000        913.43   2666.56   85.81   89.97   82.03    0.86
#   1    6200        667.38   2781.66   85.87   89.76   82.30    0.86
#   1    6400        634.84   2371.72   86.47   91.38   82.07    0.86
#   1    6600        440.74   2651.48   86.16   93.75   79.71    0.86
#   1    6800        833.43   2508.85   86.55   90.97   82.53    0.87
#   1    7000        621.69   2468.02   86.82   91.03   82.97    0.87
#   1    7200        422.65   2483.36   86.37   94.03   79.86    0.86
#   2    7400        940.12   2430.51   87.32   89.90   84.88    0.87
#   2    7600        774.66   2123.50   87.40   90.65   84.37    0.87
#   2    7800        421.23   1970.46   87.79   89.93   85.74    0.88
#   2    8000        484.66   2041.71   87.75   90.42   85.23    0.88
#   2    8200        667.70   2081.14   88.23   90.15   86.40    0.88
#   2    8400        994.28   2097.74   88.55   91.74   85.58    0.89
#   2    8600       1033.14   1953.59   88.37   88.89   87.84    0.88
#   2    8800        488.07   2014.44   88.37   91.61   85.36    0.88
#   2    9000        975.29   1832.08   88.80   92.10   85.73    0.89
#   2    9200        721.80   2129.28   88.23   92.12   84.65    0.88
#   2    9400       1460.96   1996.36   89.12   91.98   86.43    0.89
#   2    9600        526.95   1940.29   88.81   91.38   86.39    0.89
#   2    9800        684.62   1996.06   88.76   92.49   85.32    0.89
#   2   10000        685.24   2058.05   89.24   92.01   86.64    0.89
#   3   10200       1051.33   2031.24   89.38   90.66   88.13    0.89
#   3   10400        617.63   1589.00   89.79   93.25   86.59    0.90
#   3   10600        507.37   1596.00   89.44   92.45   86.61    0.89
#   3   10800       1461.40   1551.83   89.72   93.28   86.43    0.90
#   3   11000       1143.02   1739.25   89.90   92.50   87.45    0.90
#   3   11200        722.60   1682.95   90.08   93.55   86.87    0.90
#   3   11400        622.11   1689.20   89.84   92.57   87.26    0.90
#   3   11600        845.58   1643.97   89.90   92.69   87.26    0.90
#   3   11800        852.06   1727.38   89.99   91.61   88.42    0.90
#   3   12000       1402.63   1711.47   89.78   92.75   87.00    0.90
#   3   12200        653.68   1677.51   89.40   93.25   85.86    0.89
#   3   12400        835.12   1704.77   90.60   93.51   87.85    0.91
#   3   12600       1478.35   1732.35   90.00   94.08   86.25    0.90
#   3   12800       1134.15   1699.59   90.09   93.42   86.99    0.90
#   3   13000       2583.86   1728.98   90.23   92.09   88.45    0.90
#   4   13200       1784.37   1619.92   90.25   91.37   89.17    0.90
#   4   13400       1181.06   1416.14   90.70   94.02   87.61    0.91
#   4   13600       1239.08   1398.39   90.76   92.43   89.15    0.91
#   4   13800       1785.69   1512.34   90.77   92.22   89.37    0.91
#   4   14000       1473.58   1415.68   91.08   92.72   89.49    0.91
#   4   14200       2523.24   1394.59   90.78   93.44   88.27    0.91
#   4   14400       1341.91   1421.46   90.80   92.58   89.09    0.91
#   4   14600       2511.29   1421.49   91.08   93.32   88.94    0.91
#   4   14800       2214.26   1421.59   90.34   91.60   89.12    0.90
#   4   15000       1705.80   1597.20   90.94   94.97   87.24    0.91
#   4   15200       1947.97   1452.36   91.28   92.85   89.77    0.91
#   4   15400       1513.36   1407.03   91.40   93.36   89.53    0.91
#   4   15600       1849.03   1409.35   91.43   93.94   89.05    0.91
#   4   15800       1526.41   1438.32   91.32   95.05   87.88    0.91
#   5   16000       4094.89   1609.16   91.28   92.81   89.81    0.91
#   5   16200       2192.65   1137.84   91.24   92.57   89.94    0.91
#   5   16400       1848.36   1211.33   91.26   94.99   87.82    0.91
#   5   16600       3619.57   1249.45   91.23   94.39   88.27    0.91
#   5   16800       3521.19   1430.22   91.55   93.55   89.63    0.92
#   5   17000       4809.09   1346.26   91.30   92.30   90.32    0.91
#   5   17200       3075.12   1229.02   91.16   92.60   89.77    0.91
#   5   17400       3423.65   1231.34   91.26   92.32   90.23    0.91
#   5   17600       3393.84   1278.23   91.43   93.66   89.30    0.91
#   5   17800        975.58   1213.54   91.54   94.23   89.00    0.92
#   5   18000       2570.12   1265.20   92.03   94.28   89.87    0.92
#   5   18200       2144.12   1445.84   91.33   91.80   90.87    0.91
#   5   18400       4269.27   1337.52   91.92   94.26   89.69    0.92
#   5   18600       3293.24   1343.51   91.93   94.22   89.75    0.92
#   5   18800       4307.83   1417.45   91.93   94.88   89.15    0.92
#   6   19000       5254.17   1151.71   92.13   94.88   89.53    0.92
#   6   19200       4466.18   1123.91   91.16   93.05   89.35    0.91
#   6   19400       4886.45   1158.45   91.96   93.04   90.91    0.92
#   6   19600       2404.14   1099.87   92.06   94.08   90.12    0.92
#   6   19800       3563.15   1144.94   92.03   94.01   90.13    0.92
#   6   20000       3882.79   1226.39   91.76   93.12   90.43    0.92
# ✔ Saved pipeline to output directory
# spacy_output/model-last

# %% [markdown]
# ### Testing

# %%
nlp_ner = spacy.load("./spacy_output/model-best")

colors = {"TECH": "#7DF6D9", "MEDICALCONDITION":"#FFFFFF"}
options = {"colors": colors} 

for line in test_lines[10000:10005]:
    doc = nlp_ner(line)
    spacy.displacy.render(doc, style="ent", options= options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">It is obvious that an
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     image processing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  filter that filters out
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     image structures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  having k_obj, k_r and k_ls, respectively, can distinguish between these groups of structures. Especially a filter adapted to keep only structures having k_obj by discarding structures having k &gt;= k_r will also easily remove structure with k_ls.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">4.
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The system
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  of any of previous claims, wherein the
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     surgical navigation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  image (142A) further comprises a set of orthogonal (axial 172, sagittal 173, and coronal 174) and/or arbitrary  planes of the patient anatomy data (163).</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">VR/AR presentation system 302- which resides on plant network 116 in the example architecture depicted in FIG. 5, but which may also reside on office network 108, on an external network, on a
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web server
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
# , or on a
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cloud platform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  as a cloud-based
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     service provider
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  - collects data from
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the diverse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  set of industrial devices via network 116. In some configurations, the presentation system 302 can also collect selected items of plant data from one or more devices or systems on office network 108, including but not limited to the
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MES system
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  526, ERP system 528,
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     business intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  systems, or other such assets. Presentation system 302 formats the data for rendering in virtual and
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     augmented reality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  presentations. One or more plant models 524 stored on the presentation system 302 can define three-dimensional views of areas within an industrial facility (e.g., production lines or work areas), and presentation system 302 can generate three-dimensional virtual or
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     augmented reality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  presentations of the areas - including machines, control cabinets, conveyors, industrial devices, etc. - based on
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the plant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  models 524. The presentation system 302 can also superimpose selected subsets of the collected industrial data on the virtual or
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     augmented reality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  presentations on or near graphical representations of the industrial asset (e.g., machine, control cabinet,
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     industrial controller
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
# , etc.) to which the data relates. Other interactive features of the virtual and
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     augmented reality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  presentations will be described in more detail herein.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In some implementations, an instruction may include information instructing a user of user device 210 to capture an image of a receipt related to a transaction, an image of an individual related to a transaction, transaction card 220 related to a transaction, and/or the like. Additionally, or alternatively, an instruction may include information instructing a user of user device 210 to capture an image of a barcode, a
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quick Response
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  (QR) code, and/or the like on a receipt associated with a transaction.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In this embodiment, as mentioned above, the communication mode adopted between the first terminal and the second terminal may be short-range
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wireless communication
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
# , and may include multiple communication modes. Moreover, the maximum communication distance supported by each communication mode is different, for example, the working frequency of NFC is 13.56 MHz, and the supported communication distance is within 20 cm, while the working frequency of Bluetooth is 2.4 GHz, and the supported communication distance can reach 20 m, and WiFi can reach 100 m. ΔS can be understood as the value required for the maximum communication distance supported by the communication mode adopted between the first terminal and the second terminal, for example, the duration required to transmit the
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TECH</span>
# </mark>
#  through the maximum communication distance, etc. Since the maximum communication distance supported by each communication mode is different, the value of the corresponding ΔS will also be different, of course, ΔS may also include other meanings, as described in detail below.</div></span>

# %% [markdown]
# ## 🦄 Prodigy: Make it even better
#
# For this part i have used this tutorial: https://newscatcherapi.com/blog/train-custom-named-entity-recognition-ner-model-with-spacy-v3
# and official documentation: https://spacy.io/usage/training#custom-ner-model

# %% [markdown]
# ### 📖 Teach it!

# %% [markdown]
# One of the besst feature of Prodigy is that you can focus annotation on the most uncertain enitties.
# For this one we use __ner.teach__

# %% [markdown]
# As a dataset, used valid_data.txt, since model is already fitter on the training data

# %%
# !prodigy ner.teach ner_tech  ./spacy_output/model-best  valid_lines.txt --label TECH

# %% [markdown]
# <img src="./img/binary.png" height=400>

# %% [markdown]
# Also, instead of binary judging, we can correct model prediction manualy by using __ner.correct__

# %%
# !prodigy ner.correct gold_tech  ./spacy_output/model-best  valid_lines.txt --label TECH

# %% [markdown]
# <img src="./img/annotation.png" height=420>

# %% [markdown]
# ### 🤝 Merge it!

# %% [markdown]
# Now, we need to merge our binary annotation into the __gold dataset__
# This means that now we are fixing annotation manually in the text which we are rejected during __ner.teach__
#
# Those annotation can be directly merged into already created dataset(by ner.correct)

# %%
# !prodigy ner.silver-to-gold gold_tech ner_tech ./spacy_output/model-best --label TECH

# %% [markdown]
# ### 🏋️‍♀️ .. or train it with Prodigy

# %% [markdown]
# We can finetune\ train our existing SpaCy model(pipeline) inside prodigy
#
# Here we train existing `/model_best` and output our finte-tuned model into `spacy_output`

# %%
# !prodigy train ./prodigy_output --ner gold_tech --eval-split 0.3 --base-model ./spacy_output/model-best

# %% [markdown]
# <img src="./img/terminal_training.png" height=400>

# %% [markdown]
# ### ✍️ Evaluation
# - Let's evaluate on the test-lines. They are already randomized, so it's a good place to start.

# %%
nlp_ner = spacy.load("./prodigy_output/model-best")

colors = {"TECH": "#7DF6D9", "MEDICALCONDITION":"#FFFFFF"}
options = {"colors": colors} 

for line in test_lines[10000:10010]:
    doc = nlp_ner(line)
    spacy.displacy.render(doc, style="ent", options= options, jupyter=True)

# %% [markdown]
# ## TODO: Hearst Patterns

# %% [markdown]
# PhraseMatcher, etc...
